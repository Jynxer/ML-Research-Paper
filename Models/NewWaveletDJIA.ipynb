# %% [markdown]
# # DJIA Price Prediction LSTM with New Input using Wavelet Transforms

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/DJIA.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingDataNormalised.shape[0]):
    X_train.append(np.concatenate([trainingDataNormalised[i-exposureSize:i], trainingData[i-exposureSize:i]], axis=1))
    y_train.append(trainingDataNormalised[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (4414, 365, 10)
# (4414,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)
testInputsTransformed = np.array(WaveletTransform(testInputsNormalised, 3))

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(np.concatenate([testInputsNormalised[i-exposureSize:i], testInputsTransformed[i-exposureSize:i]], axis=1))
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (125, 365, 10)
# (125,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res = K.sum(K.square(y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./WaveletDJIAModel.png', show_shapes=True)
# Out:
# 2022-08-18 13:50:55.040174: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                12200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 12,251
# Trainable params: 12,251
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
historyOne = model.fit(X_train, y_train, epochs=16, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=12, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=8, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 138/138 [==============================] - 19s 126ms/step - loss: 0.0229 - mean_absolute_error: 0.0229 - mean_squared_error: 0.0043 - root_mean_squared_error: 0.0656 - coefficient_of_determination: 0.9216 - val_loss: 0.0083 - val_mean_absolute_error: 0.0083 - val_mean_squared_error: 1.1122e-04 - val_root_mean_squared_error: 0.0105 - val_coefficient_of_determination: 0.6904
# Epoch 2/16
# 138/138 [==============================] - 11s 77ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - mean_squared_error: 8.9763e-05 - root_mean_squared_error: 0.0095 - coefficient_of_determination: 0.9981 - val_loss: 0.0321 - val_mean_absolute_error: 0.0321 - val_mean_squared_error: 0.0011 - val_root_mean_squared_error: 0.0331 - val_coefficient_of_determination: -2.6389
# Epoch 3/16
# 138/138 [==============================] - 10s 76ms/step - loss: 0.0092 - mean_absolute_error: 0.0092 - mean_squared_error: 1.5052e-04 - root_mean_squared_error: 0.0123 - coefficient_of_determination: 0.9967 - val_loss: 0.0359 - val_mean_absolute_error: 0.0359 - val_mean_squared_error: 0.0014 - val_root_mean_squared_error: 0.0367 - val_coefficient_of_determination: -3.2649
# Epoch 4/16
# 138/138 [==============================] - 11s 80ms/step - loss: 0.0085 - mean_absolute_error: 0.0085 - mean_squared_error: 1.2995e-04 - root_mean_squared_error: 0.0114 - coefficient_of_determination: 0.9972 - val_loss: 0.0105 - val_mean_absolute_error: 0.0105 - val_mean_squared_error: 1.5039e-04 - val_root_mean_squared_error: 0.0123 - val_coefficient_of_determination: 0.5331
# Epoch 5/16
# 138/138 [==============================] - 10s 76ms/step - loss: 0.0064 - mean_absolute_error: 0.0064 - mean_squared_error: 7.4639e-05 - root_mean_squared_error: 0.0086 - coefficient_of_determination: 0.9984 - val_loss: 0.0422 - val_mean_absolute_error: 0.0422 - val_mean_squared_error: 0.0018 - val_root_mean_squared_error: 0.0429 - val_coefficient_of_determination: -4.8418
# Epoch 6/16
# 138/138 [==============================] - 11s 80ms/step - loss: 0.0060 - mean_absolute_error: 0.0060 - mean_squared_error: 6.7554e-05 - root_mean_squared_error: 0.0082 - coefficient_of_determination: 0.9986 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051 - val_mean_squared_error: 5.2743e-05 - val_root_mean_squared_error: 0.0073 - val_coefficient_of_determination: 0.8846
# Epoch 7/16
# 138/138 [==============================] - 11s 81ms/step - loss: 0.0046 - mean_absolute_error: 0.0046 - mean_squared_error: 3.9108e-05 - root_mean_squared_error: 0.0063 - coefficient_of_determination: 0.9992 - val_loss: 0.0076 - val_mean_absolute_error: 0.0076 - val_mean_squared_error: 8.5735e-05 - val_root_mean_squared_error: 0.0093 - val_coefficient_of_determination: 0.7457
# Epoch 8/16
# 138/138 [==============================] - 11s 78ms/step - loss: 0.0046 - mean_absolute_error: 0.0046 - mean_squared_error: 3.7966e-05 - root_mean_squared_error: 0.0062 - coefficient_of_determination: 0.9992 - val_loss: 0.0087 - val_mean_absolute_error: 0.0087 - val_mean_squared_error: 1.0757e-04 - val_root_mean_squared_error: 0.0104 - val_coefficient_of_determination: 0.7049
# Epoch 9/16
# 138/138 [==============================] - 11s 77ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - mean_squared_error: 3.0601e-05 - root_mean_squared_error: 0.0055 - coefficient_of_determination: 0.9994 - val_loss: 0.0166 - val_mean_absolute_error: 0.0166 - val_mean_squared_error: 3.1768e-04 - val_root_mean_squared_error: 0.0178 - val_coefficient_of_determination: 0.0417
# Epoch 10/16
# 138/138 [==============================] - 11s 81ms/step - loss: 0.0065 - mean_absolute_error: 0.0065 - mean_squared_error: 8.7734e-05 - root_mean_squared_error: 0.0094 - coefficient_of_determination: 0.9981 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060 - val_mean_squared_error: 6.1683e-05 - val_root_mean_squared_error: 0.0079 - val_coefficient_of_determination: 0.8326
# Epoch 11/16
# 138/138 [==============================] - 11s 83ms/step - loss: 0.0043 - mean_absolute_error: 0.0043 - mean_squared_error: 3.8588e-05 - root_mean_squared_error: 0.0062 - coefficient_of_determination: 0.9992 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104 - val_mean_squared_error: 1.4006e-04 - val_root_mean_squared_error: 0.0118 - val_coefficient_of_determination: 0.6044
# Epoch 12/16
# 138/138 [==============================] - 12s 90ms/step - loss: 0.0033 - mean_absolute_error: 0.0033 - mean_squared_error: 2.1354e-05 - root_mean_squared_error: 0.0046 - coefficient_of_determination: 0.9996 - val_loss: 0.0099 - val_mean_absolute_error: 0.0099 - val_mean_squared_error: 1.2585e-04 - val_root_mean_squared_error: 0.0112 - val_coefficient_of_determination: 0.6389
# Epoch 13/16
# 138/138 [==============================] - 12s 89ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - mean_squared_error: 8.8245e-05 - root_mean_squared_error: 0.0094 - coefficient_of_determination: 0.9982 - val_loss: 0.0127 - val_mean_absolute_error: 0.0127 - val_mean_squared_error: 1.8969e-04 - val_root_mean_squared_error: 0.0138 - val_coefficient_of_determination: 0.4052
# Epoch 14/16
# 138/138 [==============================] - 12s 86ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 5.4468e-05 - root_mean_squared_error: 0.0074 - coefficient_of_determination: 0.9989 - val_loss: 0.0064 - val_mean_absolute_error: 0.0064 - val_mean_squared_error: 6.4470e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.8333
# Epoch 15/16
# 138/138 [==============================] - 11s 81ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - mean_squared_error: 3.0930e-05 - root_mean_squared_error: 0.0056 - coefficient_of_determination: 0.9994 - val_loss: 0.0147 - val_mean_absolute_error: 0.0147 - val_mean_squared_error: 2.4371e-04 - val_root_mean_squared_error: 0.0156 - val_coefficient_of_determination: 0.2203
# Epoch 16/16
# 138/138 [==============================] - 11s 81ms/step - loss: 0.0034 - mean_absolute_error: 0.0034 - mean_squared_error: 2.2973e-05 - root_mean_squared_error: 0.0048 - coefficient_of_determination: 0.9995 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054 - val_mean_squared_error: 5.0117e-05 - val_root_mean_squared_error: 0.0071 - val_coefficient_of_determination: 0.8667
# Epoch 1/12
# 138/138 [==============================] - 11s 81ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 4.4424e-06 - root_mean_squared_error: 0.0021 - coefficient_of_determination: 0.9999 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047 - val_mean_squared_error: 4.0114e-05 - val_root_mean_squared_error: 0.0063 - val_coefficient_of_determination: 0.9046
# Epoch 2/12
# 138/138 [==============================] - 11s 82ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.7530e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 3.4517e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9213
# Epoch 3/12
# 138/138 [==============================] - 12s 84ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.2797e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 3.3134e-05 - val_root_mean_squared_error: 0.0058 - val_coefficient_of_determination: 0.9239
# Epoch 4/12
# 138/138 [==============================] - 11s 83ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.2514e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045 - val_mean_squared_error: 3.6584e-05 - val_root_mean_squared_error: 0.0060 - val_coefficient_of_determination: 0.9148
# Epoch 5/12
# 138/138 [==============================] - 12s 88ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.4017e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 3.1942e-05 - val_root_mean_squared_error: 0.0057 - val_coefficient_of_determination: 0.9246
# Epoch 6/12
# 138/138 [==============================] - 12s 90ms/step - loss: 9.9900e-04 - mean_absolute_error: 9.9900e-04 - mean_squared_error: 3.0995e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 3.2227e-05 - val_root_mean_squared_error: 0.0057 - val_coefficient_of_determination: 0.9253
# Epoch 7/12
# 138/138 [==============================] - 20s 145ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.1826e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 3.1147e-05 - val_root_mean_squared_error: 0.0056 - val_coefficient_of_determination: 0.9276
# Epoch 8/12
# 138/138 [==============================] - 25s 179ms/step - loss: 9.7410e-04 - mean_absolute_error: 9.7410e-04 - mean_squared_error: 2.9749e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 3.0393e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9289
# Epoch 9/12
# 138/138 [==============================] - 13s 94ms/step - loss: 9.3216e-04 - mean_absolute_error: 9.3216e-04 - mean_squared_error: 2.8447e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 3.1367e-05 - val_root_mean_squared_error: 0.0056 - val_coefficient_of_determination: 0.9230
# Epoch 10/12
# 138/138 [==============================] - 12s 88ms/step - loss: 9.6280e-04 - mean_absolute_error: 9.6280e-04 - mean_squared_error: 2.9493e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 3.3501e-05 - val_root_mean_squared_error: 0.0058 - val_coefficient_of_determination: 0.9150
# Epoch 11/12
# 138/138 [==============================] - 13s 93ms/step - loss: 9.2499e-04 - mean_absolute_error: 9.2499e-04 - mean_squared_error: 2.8122e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 3.0286e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9294
# Epoch 12/12
# 138/138 [==============================] - 20s 142ms/step - loss: 9.4320e-04 - mean_absolute_error: 9.4320e-04 - mean_squared_error: 2.7852e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 2.9689e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9311
# Epoch 1/8
# 138/138 [==============================] - 15s 105ms/step - loss: 7.9187e-04 - mean_absolute_error: 7.9187e-04 - mean_squared_error: 2.3817e-06 - root_mean_squared_error: 0.0015 - coefficient_of_determination: 1.0000 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 3.0006e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9302
# Epoch 2/8
# 138/138 [==============================] - 12s 85ms/step - loss: 7.8789e-04 - mean_absolute_error: 7.8789e-04 - mean_squared_error: 2.4025e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 1.0000 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 2.9319e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9310
# Epoch 3/8
# 138/138 [==============================] - 11s 83ms/step - loss: 7.7848e-04 - mean_absolute_error: 7.7848e-04 - mean_squared_error: 2.3719e-06 - root_mean_squared_error: 0.0015 - coefficient_of_determination: 1.0000 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 3.0413e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9246
# Epoch 4/8
# 138/138 [==============================] - 11s 83ms/step - loss: 7.9006e-04 - mean_absolute_error: 7.9006e-04 - mean_squared_error: 2.4049e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 1.0000 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 2.9559e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9287
# Epoch 5/8
# 138/138 [==============================] - 12s 85ms/step - loss: 7.7679e-04 - mean_absolute_error: 7.7679e-04 - mean_squared_error: 2.3743e-06 - root_mean_squared_error: 0.0015 - coefficient_of_determination: 1.0000 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 2.9296e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9311
# Epoch 6/8
# 138/138 [==============================] - 12s 87ms/step - loss: 7.6134e-04 - mean_absolute_error: 7.6134e-04 - mean_squared_error: 2.3227e-06 - root_mean_squared_error: 0.0015 - coefficient_of_determination: 1.0000 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 2.9321e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9300
# Epoch 7/8
# 138/138 [==============================] - 12s 86ms/step - loss: 7.9102e-04 - mean_absolute_error: 7.9102e-04 - mean_squared_error: 2.4069e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 1.0000 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 2.9497e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9309
# Epoch 8/8
# 138/138 [==============================] - 12s 87ms/step - loss: 7.6760e-04 - mean_absolute_error: 7.6760e-04 - mean_squared_error: 2.3334e-06 - root_mean_squared_error: 0.0015 - coefficient_of_determination: 1.0000 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 2.9930e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9301

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 4/4 [==============================] - 1s 23ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted DJIA Open Price ($)")
plt.plot(y_test, color='blue', label="Actual DJIA Open Price ($)")
plt.title('DJIA Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('DJIA Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.000767595018260181
# Mean Squared Error (MSE): 2.333372094653896e-06
# Root Mean Squared Error (RMSE): 0.0015275379410013556
# Coefficient of Determination (R2): 0.9999533295631409

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.003959303721785545
# Validation Mean Squared Error (MSE): 2.992968620674219e-05
# Validation Root Mean Squared Error (RMSE): 0.005470803007483482
# Validation Coefficient of Determination (R2): 0.9300936460494995

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 125 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $160787.3189686963
# Balance Percentage Change: 16.078731896869627%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $162509.80005976406
# Balance Percentage Change: 16.250980005976405%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $242470.48052807827
# Balance Percentage Change: 24.247048052807827%
# ----------------------------------------------------------------
