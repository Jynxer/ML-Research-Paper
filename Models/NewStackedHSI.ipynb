# %% [markdown]
# # HSI Price Prediction Stacked LSTM with Wavelet Transforms and an Attention Mechanism

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from attention import Attention
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/HSI.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingDataNormalised.shape[0]):
    X_train.append(np.concatenate([trainingDataNormalised[i-exposureSize:i], trainingData[i-exposureSize:i]], axis=1))
    y_train.append(trainingDataNormalised[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (3820, 365, 10)
# (3820,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)
testInputsTransformed = np.array(WaveletTransform(testInputsNormalised, 3))

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(np.concatenate([testInputsNormalised[i-exposureSize:i], testInputsTransformed[i-exposureSize:i]], axis=1))
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (119, 365, 10)
# (119,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(50, return_sequences=True))
model.add(Attention(units=16))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./StackedHSIModel.png', show_shapes=True)
# Out:
# 2022-08-18 15:17:37.892612: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 365, 50)           12200
#
#  lstm_1 (LSTM)               (None, 365, 50)           20200
#
#  attention (Attention)       (None, 16)                4100
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 36,517
# Trainable params: 36,517
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
numEpochsOne = 16
numEpochsTwo = 12
numEpochsThree = 8

historyOne = model.fit(X_train, y_train, epochs=numEpochsOne, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=numEpochsTwo, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=numEpochsThree, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 2022-08-18 15:17:55.459572: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 120/120 [==============================] - ETA: 0s - loss: 0.0598 - mean_absolute_error: 0.0598 - mean_squared_error: 0.0321 - root_mean_squared_error: 0.1792 - coefficient_of_determination: 0.1957
# 2022-08-18 15:18:54.847224: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 120/120 [==============================] - 74s 465ms/step - loss: 0.0598 - mean_absolute_error: 0.0598 - mean_squared_error: 0.0321 - root_mean_squared_error: 0.1792 - coefficient_of_determination: 0.1957 - val_loss: 0.0211 - val_mean_absolute_error: 0.0211 - val_mean_squared_error: 6.2431e-04 - val_root_mean_squared_error: 0.0250 - val_coefficient_of_determination: 0.0381
# Epoch 2/16
# 120/120 [==============================] - 54s 448ms/step - loss: 0.0202 - mean_absolute_error: 0.0202 - mean_squared_error: 7.0843e-04 - root_mean_squared_error: 0.0266 - coefficient_of_determination: 0.9805 - val_loss: 0.0135 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 2.6951e-04 - val_root_mean_squared_error: 0.0164 - val_coefficient_of_determination: 0.5592
# Epoch 3/16
# 120/120 [==============================] - 51s 421ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - mean_squared_error: 6.8136e-04 - root_mean_squared_error: 0.0261 - coefficient_of_determination: 0.9806 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183 - val_mean_squared_error: 4.2122e-04 - val_root_mean_squared_error: 0.0205 - val_coefficient_of_determination: 0.3979
# Epoch 4/16
# 120/120 [==============================] - 53s 444ms/step - loss: 0.0197 - mean_absolute_error: 0.0197 - mean_squared_error: 6.4615e-04 - root_mean_squared_error: 0.0254 - coefficient_of_determination: 0.9821 - val_loss: 0.0239 - val_mean_absolute_error: 0.0239 - val_mean_squared_error: 6.6338e-04 - val_root_mean_squared_error: 0.0258 - val_coefficient_of_determination: -0.0440
# Epoch 5/16
# 120/120 [==============================] - 55s 457ms/step - loss: 0.0148 - mean_absolute_error: 0.0148 - mean_squared_error: 3.9955e-04 - root_mean_squared_error: 0.0200 - coefficient_of_determination: 0.9881 - val_loss: 0.0142 - val_mean_absolute_error: 0.0142 - val_mean_squared_error: 2.6061e-04 - val_root_mean_squared_error: 0.0161 - val_coefficient_of_determination: 0.5863
# Epoch 6/16
# 120/120 [==============================] - 57s 473ms/step - loss: 0.0143 - mean_absolute_error: 0.0143 - mean_squared_error: 3.4160e-04 - root_mean_squared_error: 0.0185 - coefficient_of_determination: 0.9906 - val_loss: 0.0105 - val_mean_absolute_error: 0.0105 - val_mean_squared_error: 1.6063e-04 - val_root_mean_squared_error: 0.0127 - val_coefficient_of_determination: 0.7588
# Epoch 7/16
# 120/120 [==============================] - 56s 463ms/step - loss: 0.0112 - mean_absolute_error: 0.0112 - mean_squared_error: 2.0779e-04 - root_mean_squared_error: 0.0144 - coefficient_of_determination: 0.9943 - val_loss: 0.0135 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 2.3445e-04 - val_root_mean_squared_error: 0.0153 - val_coefficient_of_determination: 0.6586
# Epoch 8/16
# 120/120 [==============================] - 62s 521ms/step - loss: 0.0129 - mean_absolute_error: 0.0129 - mean_squared_error: 2.8994e-04 - root_mean_squared_error: 0.0170 - coefficient_of_determination: 0.9918 - val_loss: 0.0108 - val_mean_absolute_error: 0.0108 - val_mean_squared_error: 1.6684e-04 - val_root_mean_squared_error: 0.0129 - val_coefficient_of_determination: 0.7545
# Epoch 9/16
# 120/120 [==============================] - 57s 473ms/step - loss: 0.0149 - mean_absolute_error: 0.0149 - mean_squared_error: 3.9599e-04 - root_mean_squared_error: 0.0199 - coefficient_of_determination: 0.9888 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060 - val_mean_squared_error: 6.3208e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.8992
# Epoch 10/16
# 120/120 [==============================] - 57s 471ms/step - loss: 0.0130 - mean_absolute_error: 0.0130 - mean_squared_error: 2.9438e-04 - root_mean_squared_error: 0.0172 - coefficient_of_determination: 0.9917 - val_loss: 0.0067 - val_mean_absolute_error: 0.0067 - val_mean_squared_error: 7.4332e-05 - val_root_mean_squared_error: 0.0086 - val_coefficient_of_determination: 0.8798
# Epoch 11/16
# 120/120 [==============================] - 56s 464ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 1.9035e-04 - root_mean_squared_error: 0.0138 - coefficient_of_determination: 0.9947 - val_loss: 0.0169 - val_mean_absolute_error: 0.0169 - val_mean_squared_error: 3.4018e-04 - val_root_mean_squared_error: 0.0184 - val_coefficient_of_determination: 0.4597
# Epoch 12/16
# 120/120 [==============================] - 53s 438ms/step - loss: 0.0091 - mean_absolute_error: 0.0091 - mean_squared_error: 1.4649e-04 - root_mean_squared_error: 0.0121 - coefficient_of_determination: 0.9957 - val_loss: 0.0071 - val_mean_absolute_error: 0.0071 - val_mean_squared_error: 7.7973e-05 - val_root_mean_squared_error: 0.0088 - val_coefficient_of_determination: 0.8736
# Epoch 13/16
# 120/120 [==============================] - 50s 416ms/step - loss: 0.0137 - mean_absolute_error: 0.0137 - mean_squared_error: 3.0547e-04 - root_mean_squared_error: 0.0175 - coefficient_of_determination: 0.9913 - val_loss: 0.0178 - val_mean_absolute_error: 0.0178 - val_mean_squared_error: 3.7308e-04 - val_root_mean_squared_error: 0.0193 - val_coefficient_of_determination: 0.4057
# Epoch 14/16
# 120/120 [==============================] - 47s 388ms/step - loss: 0.0094 - mean_absolute_error: 0.0094 - mean_squared_error: 1.5476e-04 - root_mean_squared_error: 0.0124 - coefficient_of_determination: 0.9955 - val_loss: 0.0108 - val_mean_absolute_error: 0.0108 - val_mean_squared_error: 1.6392e-04 - val_root_mean_squared_error: 0.0128 - val_coefficient_of_determination: 0.7648
# Epoch 15/16
# 120/120 [==============================] - 47s 391ms/step - loss: 0.0088 - mean_absolute_error: 0.0088 - mean_squared_error: 1.3725e-04 - root_mean_squared_error: 0.0117 - coefficient_of_determination: 0.9961 - val_loss: 0.0277 - val_mean_absolute_error: 0.0277 - val_mean_squared_error: 8.3023e-04 - val_root_mean_squared_error: 0.0288 - val_coefficient_of_determination: -0.3081
# Epoch 16/16
# 120/120 [==============================] - 41s 341ms/step - loss: 0.0096 - mean_absolute_error: 0.0096 - mean_squared_error: 1.6502e-04 - root_mean_squared_error: 0.0128 - coefficient_of_determination: 0.9954 - val_loss: 0.0068 - val_mean_absolute_error: 0.0068 - val_mean_squared_error: 7.4510e-05 - val_root_mean_squared_error: 0.0086 - val_coefficient_of_determination: 0.8808
# Epoch 1/12
# 120/120 [==============================] - 29s 239ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - mean_squared_error: 6.3859e-05 - root_mean_squared_error: 0.0080 - coefficient_of_determination: 0.9982 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 5.7265e-05 - val_root_mean_squared_error: 0.0076 - val_coefficient_of_determination: 0.9099
# Epoch 2/12
# 120/120 [==============================] - 30s 254ms/step - loss: 0.0055 - mean_absolute_error: 0.0055 - mean_squared_error: 6.5037e-05 - root_mean_squared_error: 0.0081 - coefficient_of_determination: 0.9982 - val_loss: 0.0076 - val_mean_absolute_error: 0.0076 - val_mean_squared_error: 9.3111e-05 - val_root_mean_squared_error: 0.0096 - val_coefficient_of_determination: 0.8625
# Epoch 3/12
# 120/120 [==============================] - 29s 245ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 6.7205e-05 - root_mean_squared_error: 0.0082 - coefficient_of_determination: 0.9981 - val_loss: 0.0066 - val_mean_absolute_error: 0.0066 - val_mean_squared_error: 6.9578e-05 - val_root_mean_squared_error: 0.0083 - val_coefficient_of_determination: 0.8875
# Epoch 4/12
# 120/120 [==============================] - 32s 267ms/step - loss: 0.0055 - mean_absolute_error: 0.0055 - mean_squared_error: 6.3669e-05 - root_mean_squared_error: 0.0080 - coefficient_of_determination: 0.9982 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.5467e-05 - val_root_mean_squared_error: 0.0074 - val_coefficient_of_determination: 0.9130
# Epoch 5/12
# 120/120 [==============================] - 31s 256ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 6.6846e-05 - root_mean_squared_error: 0.0082 - coefficient_of_determination: 0.9981 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 5.7871e-05 - val_root_mean_squared_error: 0.0076 - val_coefficient_of_determination: 0.9115
# Epoch 6/12
# 120/120 [==============================] - 30s 251ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - mean_squared_error: 6.4222e-05 - root_mean_squared_error: 0.0080 - coefficient_of_determination: 0.9981 - val_loss: 0.0062 - val_mean_absolute_error: 0.0062 - val_mean_squared_error: 6.4565e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.9025
# Epoch 7/12
# 120/120 [==============================] - 30s 251ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - mean_squared_error: 6.2395e-05 - root_mean_squared_error: 0.0079 - coefficient_of_determination: 0.9982 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.5886e-05 - val_root_mean_squared_error: 0.0075 - val_coefficient_of_determination: 0.9136
# Epoch 8/12
# 120/120 [==============================] - 30s 253ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - mean_squared_error: 6.2472e-05 - root_mean_squared_error: 0.0079 - coefficient_of_determination: 0.9982 - val_loss: 0.0063 - val_mean_absolute_error: 0.0063 - val_mean_squared_error: 6.6091e-05 - val_root_mean_squared_error: 0.0081 - val_coefficient_of_determination: 0.9008
# Epoch 9/12
# 120/120 [==============================] - 27s 229ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 6.4892e-05 - root_mean_squared_error: 0.0081 - coefficient_of_determination: 0.9981 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.5100e-05 - val_root_mean_squared_error: 0.0074 - val_coefficient_of_determination: 0.9140
# Epoch 10/12
# 120/120 [==============================] - 29s 245ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - mean_squared_error: 6.1933e-05 - root_mean_squared_error: 0.0079 - coefficient_of_determination: 0.9982 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.5477e-05 - val_root_mean_squared_error: 0.0074 - val_coefficient_of_determination: 0.9138
# Epoch 11/12
# 120/120 [==============================] - 28s 231ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - mean_squared_error: 6.0821e-05 - root_mean_squared_error: 0.0078 - coefficient_of_determination: 0.9982 - val_loss: 0.0072 - val_mean_absolute_error: 0.0072 - val_mean_squared_error: 8.2043e-05 - val_root_mean_squared_error: 0.0091 - val_coefficient_of_determination: 0.8665
# Epoch 12/12
# 120/120 [==============================] - 30s 249ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - mean_squared_error: 6.1826e-05 - root_mean_squared_error: 0.0079 - coefficient_of_determination: 0.9982 - val_loss: 0.0067 - val_mean_absolute_error: 0.0067 - val_mean_squared_error: 7.2112e-05 - val_root_mean_squared_error: 0.0085 - val_coefficient_of_determination: 0.8839
# Epoch 1/8
# 120/120 [==============================] - 30s 253ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - mean_squared_error: 5.8493e-05 - root_mean_squared_error: 0.0076 - coefficient_of_determination: 0.9983 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.4769e-05 - val_root_mean_squared_error: 0.0074 - val_coefficient_of_determination: 0.9151
# Epoch 2/8
# 120/120 [==============================] - 31s 260ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - mean_squared_error: 5.7792e-05 - root_mean_squared_error: 0.0076 - coefficient_of_determination: 0.9984 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.4678e-05 - val_root_mean_squared_error: 0.0074 - val_coefficient_of_determination: 0.9150
# Epoch 3/8
# 120/120 [==============================] - 63s 529ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - mean_squared_error: 5.7904e-05 - root_mean_squared_error: 0.0076 - coefficient_of_determination: 0.9983 - val_loss: 0.0063 - val_mean_absolute_error: 0.0063 - val_mean_squared_error: 6.7527e-05 - val_root_mean_squared_error: 0.0082 - val_coefficient_of_determination: 0.8997
# Epoch 4/8
# 120/120 [==============================] - 57s 474ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - mean_squared_error: 5.7831e-05 - root_mean_squared_error: 0.0076 - coefficient_of_determination: 0.9984 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.4624e-05 - val_root_mean_squared_error: 0.0074 - val_coefficient_of_determination: 0.9150
# Epoch 5/8
# 120/120 [==============================] - 61s 505ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - mean_squared_error: 5.7864e-05 - root_mean_squared_error: 0.0076 - coefficient_of_determination: 0.9984 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.4821e-05 - val_root_mean_squared_error: 0.0074 - val_coefficient_of_determination: 0.9142
# Epoch 6/8
# 120/120 [==============================] - 62s 516ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - mean_squared_error: 5.7422e-05 - root_mean_squared_error: 0.0076 - coefficient_of_determination: 0.9984 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 5.7833e-05 - val_root_mean_squared_error: 0.0076 - val_coefficient_of_determination: 0.9123
# Epoch 7/8
# 120/120 [==============================] - 60s 499ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - mean_squared_error: 5.8116e-05 - root_mean_squared_error: 0.0076 - coefficient_of_determination: 0.9983 - val_loss: 0.0061 - val_mean_absolute_error: 0.0061 - val_mean_squared_error: 6.2187e-05 - val_root_mean_squared_error: 0.0079 - val_coefficient_of_determination: 0.9067
# Epoch 8/8
# 120/120 [==============================] - 62s 514ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - mean_squared_error: 5.7400e-05 - root_mean_squared_error: 0.0076 - coefficient_of_determination: 0.9983 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.4669e-05 - val_root_mean_squared_error: 0.0074 - val_coefficient_of_determination: 0.9153

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 2022-08-18 15:45:13.416866: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 4/4 [==============================] - 3s 125ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted HSI Open Price ($)")
plt.plot(y_test, color='blue', label="Actual HSI Open Price ($)")
plt.title('HSI Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('HSI Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, numEpochsOne, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(numEpochsOne, numEpochsOne+numEpochsTwo, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(numEpochsOne+numEpochsTwo, numEpochsOne+numEpochsTwo+numEpochsThree, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, numEpochsOne+numEpochsTwo+numEpochsThree-1)
plt.xticks([2*i for i in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)], [(2*j)+1 for j in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, numEpochsOne, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(numEpochsOne, numEpochsOne+numEpochsTwo, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(numEpochsOne+numEpochsTwo, numEpochsOne+numEpochsTwo+numEpochsThree, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, numEpochsOne+numEpochsTwo+numEpochsThree-1)
plt.xticks([2*i for i in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)], [(2*j)+1 for j in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.005055533722043037
# Mean Squared Error (MSE): 5.739999687648378e-05
# Root Mean Squared Error (RMSE): 0.007576278410851955
# Coefficient of Determination (R2): 0.9983463287353516

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.005659576039761305
# Validation Mean Squared Error (MSE): 5.466911170515232e-05
# Validation Root Mean Squared Error (RMSE): 0.007393856532871723
# Validation Coefficient of Determination (R2): 0.9153043031692505

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 119 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $114383.08199359174
# Balance Percentage Change: 11.438308199359174%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $97911.12813486453
# Balance Percentage Change: 9.791112813486452%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $236654.79094117624
# Balance Percentage Change: 23.66547909411762%
# ----------------------------------------------------------------
