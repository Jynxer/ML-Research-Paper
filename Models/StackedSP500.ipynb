# %% [markdown]
# # S&P 500 Price Prediction Stacked LSTM with Wavelet Transforms and an Attention Mechanism

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from attention import Attention
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/S&P500.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingData.shape[0]):
    X_train.append(trainingData[i-exposureSize:i])
    y_train.append(trainingData[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (4415, 365, 5)
# (4415,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(testInputsNormalised[i-exposureSize:i])
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (125, 365, 5)
# (125,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res = K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return (1 - SS_res/(SS_tot + K.epsilon()))

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(50, return_sequences=True))
model.add(Attention(units=16))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./StackedSP500Model.png', show_shapes=True)
# Out:
# 2022-08-17 17:04:41.077575: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 365, 50)           11200
#
#  lstm_1 (LSTM)               (None, 365, 50)           20200
#
#  attention (Attention)       (None, 16)                4100
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 35,517
# Trainable params: 35,517
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
numEpochsOne = 16
numEpochsTwo = 12
numEpochsThree = 8

historyOne = model.fit(X_train, y_train, epochs=numEpochsOne, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=numEpochsTwo, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=numEpochsThree, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 2022-08-17 17:04:45.521251: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 138/138 [==============================] - ETA: 0s - loss: 0.0466 - mean_absolute_error: 0.0466 - mean_squared_error: 0.0105 - root_mean_squared_error: 0.1026 - coefficient_of_determination: 0.8117
# 2022-08-17 17:05:16.842746: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 138/138 [==============================] - 35s 217ms/step - loss: 0.0466 - mean_absolute_error: 0.0466 - mean_squared_error: 0.0105 - root_mean_squared_error: 0.1026 - coefficient_of_determination: 0.8117 - val_loss: 0.0216 - val_mean_absolute_error: 0.0216 - val_mean_squared_error: 6.1284e-04 - val_root_mean_squared_error: 0.0248 - val_coefficient_of_determination: -0.8418
# Epoch 2/16
# 138/138 [==============================] - 25s 179ms/step - loss: 0.0187 - mean_absolute_error: 0.0187 - mean_squared_error: 7.7273e-04 - root_mean_squared_error: 0.0278 - coefficient_of_determination: 0.9846 - val_loss: 0.0086 - val_mean_absolute_error: 0.0086 - val_mean_squared_error: 1.1764e-04 - val_root_mean_squared_error: 0.0108 - val_coefficient_of_determination: 0.7009
# Epoch 3/16
# 138/138 [==============================] - 26s 191ms/step - loss: 0.0138 - mean_absolute_error: 0.0138 - mean_squared_error: 3.6715e-04 - root_mean_squared_error: 0.0192 - coefficient_of_determination: 0.9930 - val_loss: 0.0329 - val_mean_absolute_error: 0.0329 - val_mean_squared_error: 0.0012 - val_root_mean_squared_error: 0.0343 - val_coefficient_of_determination: -2.4702
# Epoch 4/16
# 138/138 [==============================] - 26s 186ms/step - loss: 0.0112 - mean_absolute_error: 0.0112 - mean_squared_error: 2.6656e-04 - root_mean_squared_error: 0.0163 - coefficient_of_determination: 0.9947 - val_loss: 0.0616 - val_mean_absolute_error: 0.0616 - val_mean_squared_error: 0.0039 - val_root_mean_squared_error: 0.0622 - val_coefficient_of_determination: -10.5498
# Epoch 5/16
# 138/138 [==============================] - 26s 191ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - mean_squared_error: 2.5025e-04 - root_mean_squared_error: 0.0158 - coefficient_of_determination: 0.9951 - val_loss: 0.0068 - val_mean_absolute_error: 0.0068 - val_mean_squared_error: 7.4247e-05 - val_root_mean_squared_error: 0.0086 - val_coefficient_of_determination: 0.8135
# Epoch 6/16
# 138/138 [==============================] - 27s 193ms/step - loss: 0.0092 - mean_absolute_error: 0.0092 - mean_squared_error: 1.8483e-04 - root_mean_squared_error: 0.0136 - coefficient_of_determination: 0.9964 - val_loss: 0.0146 - val_mean_absolute_error: 0.0146 - val_mean_squared_error: 2.6802e-04 - val_root_mean_squared_error: 0.0164 - val_coefficient_of_determination: 0.3064
# Epoch 7/16
# 138/138 [==============================] - 28s 200ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - mean_squared_error: 2.5060e-04 - root_mean_squared_error: 0.0158 - coefficient_of_determination: 0.9952 - val_loss: 0.0170 - val_mean_absolute_error: 0.0170 - val_mean_squared_error: 3.3495e-04 - val_root_mean_squared_error: 0.0183 - val_coefficient_of_determination: 0.0467
# Epoch 8/16
# 138/138 [==============================] - 26s 190ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - mean_squared_error: 1.4924e-04 - root_mean_squared_error: 0.0122 - coefficient_of_determination: 0.9971 - val_loss: 0.0690 - val_mean_absolute_error: 0.0690 - val_mean_squared_error: 0.0048 - val_root_mean_squared_error: 0.0695 - val_coefficient_of_determination: -13.5653
# Epoch 9/16
# 138/138 [==============================] - 27s 195ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - mean_squared_error: 2.1279e-04 - root_mean_squared_error: 0.0146 - coefficient_of_determination: 0.9959 - val_loss: 0.0430 - val_mean_absolute_error: 0.0430 - val_mean_squared_error: 0.0019 - val_root_mean_squared_error: 0.0436 - val_coefficient_of_determination: -4.6966
# Epoch 10/16
# 138/138 [==============================] - 29s 212ms/step - loss: 0.0079 - mean_absolute_error: 0.0079 - mean_squared_error: 1.2241e-04 - root_mean_squared_error: 0.0111 - coefficient_of_determination: 0.9977 - val_loss: 0.0167 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 3.1561e-04 - val_root_mean_squared_error: 0.0178 - val_coefficient_of_determination: 0.0769
# Epoch 11/16
# 138/138 [==============================] - 31s 223ms/step - loss: 0.0064 - mean_absolute_error: 0.0064 - mean_squared_error: 8.3146e-05 - root_mean_squared_error: 0.0091 - coefficient_of_determination: 0.9984 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.3268e-05 - val_root_mean_squared_error: 0.0073 - val_coefficient_of_determination: 0.8483
# Epoch 12/16
# 138/138 [==============================] - 27s 193ms/step - loss: 0.0063 - mean_absolute_error: 0.0063 - mean_squared_error: 7.5189e-05 - root_mean_squared_error: 0.0087 - coefficient_of_determination: 0.9985 - val_loss: 0.0090 - val_mean_absolute_error: 0.0090 - val_mean_squared_error: 1.0757e-04 - val_root_mean_squared_error: 0.0104 - val_coefficient_of_determination: 0.7032
# Epoch 13/16
# 138/138 [==============================] - 28s 201ms/step - loss: 0.0063 - mean_absolute_error: 0.0063 - mean_squared_error: 8.3085e-05 - root_mean_squared_error: 0.0091 - coefficient_of_determination: 0.9985 - val_loss: 0.0302 - val_mean_absolute_error: 0.0302 - val_mean_squared_error: 9.6342e-04 - val_root_mean_squared_error: 0.0310 - val_coefficient_of_determination: -1.8936
# Epoch 14/16
# 138/138 [==============================] - 29s 213ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - mean_squared_error: 9.3850e-05 - root_mean_squared_error: 0.0097 - coefficient_of_determination: 0.9982 - val_loss: 0.0120 - val_mean_absolute_error: 0.0120 - val_mean_squared_error: 1.7919e-04 - val_root_mean_squared_error: 0.0134 - val_coefficient_of_determination: 0.4869
# Epoch 15/16
# 138/138 [==============================] - 31s 222ms/step - loss: 0.0077 - mean_absolute_error: 0.0077 - mean_squared_error: 1.0895e-04 - root_mean_squared_error: 0.0104 - coefficient_of_determination: 0.9979 - val_loss: 0.0206 - val_mean_absolute_error: 0.0206 - val_mean_squared_error: 4.7061e-04 - val_root_mean_squared_error: 0.0217 - val_coefficient_of_determination: -0.3749
# Epoch 16/16
# 138/138 [==============================] - 29s 208ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 7.3293e-05 - root_mean_squared_error: 0.0086 - coefficient_of_determination: 0.9986 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060 - val_mean_squared_error: 6.4020e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.8327
# Epoch 1/12
# 138/138 [==============================] - 26s 186ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 3.8409e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0064 - val_mean_absolute_error: 0.0064 - val_mean_squared_error: 6.0969e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.8373
# Epoch 2/12
# 138/138 [==============================] - 26s 188ms/step - loss: 9.5098e-04 - mean_absolute_error: 9.5098e-04 - mean_squared_error: 2.6544e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 0.9999 - val_loss: 0.0063 - val_mean_absolute_error: 0.0063 - val_mean_squared_error: 5.9743e-05 - val_root_mean_squared_error: 0.0077 - val_coefficient_of_determination: 0.8412
# Epoch 3/12
# 138/138 [==============================] - 30s 219ms/step - loss: 8.3514e-04 - mean_absolute_error: 8.3514e-04 - mean_squared_error: 2.1368e-06 - root_mean_squared_error: 0.0015 - coefficient_of_determination: 1.0000 - val_loss: 0.0063 - val_mean_absolute_error: 0.0063 - val_mean_squared_error: 6.1437e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.8366
# Epoch 4/12
# 138/138 [==============================] - 30s 219ms/step - loss: 8.6110e-04 - mean_absolute_error: 8.6110e-04 - mean_squared_error: 2.1572e-06 - root_mean_squared_error: 0.0015 - coefficient_of_determination: 1.0000 - val_loss: 0.0070 - val_mean_absolute_error: 0.0070 - val_mean_squared_error: 7.2737e-05 - val_root_mean_squared_error: 0.0085 - val_coefficient_of_determination: 0.8039
# Epoch 5/12
# 138/138 [==============================] - 27s 198ms/step - loss: 8.0204e-04 - mean_absolute_error: 8.0204e-04 - mean_squared_error: 1.9647e-06 - root_mean_squared_error: 0.0014 - coefficient_of_determination: 1.0000 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060 - val_mean_squared_error: 5.8278e-05 - val_root_mean_squared_error: 0.0076 - val_coefficient_of_determination: 0.8450
# Epoch 6/12
# 138/138 [==============================] - 28s 200ms/step - loss: 8.0430e-04 - mean_absolute_error: 8.0430e-04 - mean_squared_error: 1.9502e-06 - root_mean_squared_error: 0.0014 - coefficient_of_determination: 1.0000 - val_loss: 0.0068 - val_mean_absolute_error: 0.0068 - val_mean_squared_error: 7.5553e-05 - val_root_mean_squared_error: 0.0087 - val_coefficient_of_determination: 0.7899
# Epoch 7/12
# 138/138 [==============================] - 29s 207ms/step - loss: 9.8310e-04 - mean_absolute_error: 9.8310e-04 - mean_squared_error: 2.5874e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 0.9999 - val_loss: 0.0061 - val_mean_absolute_error: 0.0061 - val_mean_squared_error: 6.0327e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.8404
# Epoch 8/12
# 138/138 [==============================] - 30s 216ms/step - loss: 9.7485e-04 - mean_absolute_error: 9.7485e-04 - mean_squared_error: 2.4875e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 1.0000 - val_loss: 0.0073 - val_mean_absolute_error: 0.0073 - val_mean_squared_error: 7.9522e-05 - val_root_mean_squared_error: 0.0089 - val_coefficient_of_determination: 0.7863
# Epoch 9/12
# 138/138 [==============================] - 32s 230ms/step - loss: 8.8574e-04 - mean_absolute_error: 8.8574e-04 - mean_squared_error: 2.1575e-06 - root_mean_squared_error: 0.0015 - coefficient_of_determination: 1.0000 - val_loss: 0.0063 - val_mean_absolute_error: 0.0063 - val_mean_squared_error: 6.3098e-05 - val_root_mean_squared_error: 0.0079 - val_coefficient_of_determination: 0.8331
# Epoch 10/12
# 138/138 [==============================] - 28s 203ms/step - loss: 8.9398e-04 - mean_absolute_error: 8.9398e-04 - mean_squared_error: 2.1020e-06 - root_mean_squared_error: 0.0014 - coefficient_of_determination: 1.0000 - val_loss: 0.0066 - val_mean_absolute_error: 0.0066 - val_mean_squared_error: 6.8082e-05 - val_root_mean_squared_error: 0.0083 - val_coefficient_of_determination: 0.8196
# Epoch 11/12
# 138/138 [==============================] - 27s 196ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 2.7235e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0068 - val_mean_absolute_error: 0.0068 - val_mean_squared_error: 7.7344e-05 - val_root_mean_squared_error: 0.0088 - val_coefficient_of_determination: 0.7879
# Epoch 12/12
# 138/138 [==============================] - 30s 220ms/step - loss: 8.0273e-04 - mean_absolute_error: 8.0273e-04 - mean_squared_error: 1.7534e-06 - root_mean_squared_error: 0.0013 - coefficient_of_determination: 1.0000 - val_loss: 0.0080 - val_mean_absolute_error: 0.0080 - val_mean_squared_error: 9.5881e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.7414
# Epoch 1/8
# 138/138 [==============================] - 31s 228ms/step - loss: 5.8306e-04 - mean_absolute_error: 5.8306e-04 - mean_squared_error: 1.1997e-06 - root_mean_squared_error: 0.0011 - coefficient_of_determination: 1.0000 - val_loss: 0.0066 - val_mean_absolute_error: 0.0066 - val_mean_squared_error: 6.9561e-05 - val_root_mean_squared_error: 0.0083 - val_coefficient_of_determination: 0.8159
# Epoch 2/8
# 138/138 [==============================] - 29s 214ms/step - loss: 5.5597e-04 - mean_absolute_error: 5.5597e-04 - mean_squared_error: 1.1330e-06 - root_mean_squared_error: 0.0011 - coefficient_of_determination: 1.0000 - val_loss: 0.0067 - val_mean_absolute_error: 0.0067 - val_mean_squared_error: 7.1419e-05 - val_root_mean_squared_error: 0.0085 - val_coefficient_of_determination: 0.8114
# Epoch 3/8
# 138/138 [==============================] - 28s 205ms/step - loss: 5.3688e-04 - mean_absolute_error: 5.3688e-04 - mean_squared_error: 1.0763e-06 - root_mean_squared_error: 0.0010 - coefficient_of_determination: 1.0000 - val_loss: 0.0067 - val_mean_absolute_error: 0.0067 - val_mean_squared_error: 7.0900e-05 - val_root_mean_squared_error: 0.0084 - val_coefficient_of_determination: 0.8128
# Epoch 4/8
# 138/138 [==============================] - 29s 213ms/step - loss: 5.4224e-04 - mean_absolute_error: 5.4224e-04 - mean_squared_error: 1.0912e-06 - root_mean_squared_error: 0.0010 - coefficient_of_determination: 1.0000 - val_loss: 0.0067 - val_mean_absolute_error: 0.0067 - val_mean_squared_error: 7.1167e-05 - val_root_mean_squared_error: 0.0084 - val_coefficient_of_determination: 0.8121
# Epoch 5/8
# 138/138 [==============================] - 29s 213ms/step - loss: 5.4858e-04 - mean_absolute_error: 5.4858e-04 - mean_squared_error: 1.1060e-06 - root_mean_squared_error: 0.0011 - coefficient_of_determination: 1.0000 - val_loss: 0.0067 - val_mean_absolute_error: 0.0067 - val_mean_squared_error: 7.1811e-05 - val_root_mean_squared_error: 0.0085 - val_coefficient_of_determination: 0.8104
# Epoch 6/8
# 138/138 [==============================] - 31s 222ms/step - loss: 5.4567e-04 - mean_absolute_error: 5.4567e-04 - mean_squared_error: 1.0826e-06 - root_mean_squared_error: 0.0010 - coefficient_of_determination: 1.0000 - val_loss: 0.0068 - val_mean_absolute_error: 0.0068 - val_mean_squared_error: 7.2641e-05 - val_root_mean_squared_error: 0.0085 - val_coefficient_of_determination: 0.8083
# Epoch 7/8
# 138/138 [==============================] - 30s 219ms/step - loss: 5.3908e-04 - mean_absolute_error: 5.3908e-04 - mean_squared_error: 1.0765e-06 - root_mean_squared_error: 0.0010 - coefficient_of_determination: 1.0000 - val_loss: 0.0067 - val_mean_absolute_error: 0.0067 - val_mean_squared_error: 7.0801e-05 - val_root_mean_squared_error: 0.0084 - val_coefficient_of_determination: 0.8129
# Epoch 8/8
# 138/138 [==============================] - 32s 230ms/step - loss: 5.3404e-04 - mean_absolute_error: 5.3404e-04 - mean_squared_error: 1.0767e-06 - root_mean_squared_error: 0.0010 - coefficient_of_determination: 1.0000 - val_loss: 0.0067 - val_mean_absolute_error: 0.0067 - val_mean_squared_error: 7.1640e-05 - val_root_mean_squared_error: 0.0085 - val_coefficient_of_determination: 0.8109

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 2022-08-17 17:21:54.802936: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 4/4 [==============================] - 1s 69ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]

# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
numTicks = 10
xTicks = []
tickDifference = dates.shape[0] // numTicks
for i in range(numTicks):
    xTicks.append(dates.iloc[i*tickDifference])
xTicks.append(dates.iloc[-1])

xTickLocations = np.arange(0, dates.shape[0], tickDifference)

plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted S&P 500 Open Price ($)")
plt.plot(y_test, color='blue', label="Actual S&P 500 Open Price ($)")
plt.title('S&P 500 Open Price Prediction')
plt.xticks(xTickLocations, xTicks)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('S&P 500 Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, numEpochsOne, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(numEpochsOne, numEpochsOne+numEpochsTwo, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(numEpochsOne+numEpochsTwo, numEpochsOne+numEpochsTwo+numEpochsThree, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, numEpochsOne+numEpochsTwo+numEpochsThree-1)
plt.xticks([2*i for i in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)], [(2*j)+1 for j in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, numEpochsOne, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(numEpochsOne, numEpochsOne+numEpochsTwo, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(numEpochsOne+numEpochsTwo, numEpochsOne+numEpochsTwo+numEpochsThree, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, numEpochsOne+numEpochsTwo+numEpochsThree-1)
plt.xticks([2*i for i in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)], [(2*j)+1 for j in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.0005340432398952544
# Mean Squared Error (MSE): 1.0766666491690557e-06
# Root Mean Squared Error (RMSE): 0.0010376254795119166
# Coefficient of Determination (R2): 0.9999798536300659

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.006714216433465481
# Validation Mean Squared Error (MSE): 7.164016278693452e-05
# Validation Root Mean Squared Error (RMSE): 0.00846405141055584
# Validation Coefficient of Determination (R2): 0.8109195232391357

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 125 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $152710.7924872064
# Balance Percentage Change: 15.271079248720639%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $199619.67847085418
# Balance Percentage Change: 19.96196784708542%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $260859.438211238
# Balance Percentage Change: 26.085943821123802%
# ----------------------------------------------------------------
