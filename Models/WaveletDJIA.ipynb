# %% [markdown]
# # DJIA Price Prediction LSTM with Wavelet Transforms

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/DJIA.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingData.shape[0]):
    X_train.append(trainingData[i-exposureSize:i])
    y_train.append(trainingData[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (4415, 365, 5)
# (4415,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(testInputsNormalised[i-exposureSize:i])
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (125, 365, 5)
# (125,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res = K.sum(K.square(y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./WaveletDJIAModel.png', show_shapes=True)
# Out:
# 2022-08-17 14:59:49.913415: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                11200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 11,251
# Trainable params: 11,251
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
historyOne = model.fit(X_train, y_train, epochs=16, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=12, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=8, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 138/138 [==============================] - 20s 130ms/step - loss: 0.0220 - mean_absolute_error: 0.0220 - mean_squared_error: 0.0029 - root_mean_squared_error: 0.0535 - coefficient_of_determination: 0.9260 - val_loss: 0.0077 - val_mean_absolute_error: 0.0077 - val_mean_squared_error: 9.4519e-05 - val_root_mean_squared_error: 0.0097 - val_coefficient_of_determination: 0.6987
# Epoch 2/16
# 138/138 [==============================] - 11s 79ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 2.1035e-04 - root_mean_squared_error: 0.0145 - coefficient_of_determination: 0.9955 - val_loss: 0.0080 - val_mean_absolute_error: 0.0080 - val_mean_squared_error: 9.9642e-05 - val_root_mean_squared_error: 0.0100 - val_coefficient_of_determination: 0.6680
# Epoch 3/16
# 138/138 [==============================] - 10s 73ms/step - loss: 0.0087 - mean_absolute_error: 0.0087 - mean_squared_error: 1.5985e-04 - root_mean_squared_error: 0.0126 - coefficient_of_determination: 0.9966 - val_loss: 0.0425 - val_mean_absolute_error: 0.0425 - val_mean_squared_error: 0.0019 - val_root_mean_squared_error: 0.0432 - val_coefficient_of_determination: -4.9594
# Epoch 4/16
# 138/138 [==============================] - 10s 74ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - mean_squared_error: 1.1629e-04 - root_mean_squared_error: 0.0108 - coefficient_of_determination: 0.9974 - val_loss: 0.0227 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 5.5750e-04 - val_root_mean_squared_error: 0.0236 - val_coefficient_of_determination: -0.7316
# Epoch 5/16
# 138/138 [==============================] - 10s 76ms/step - loss: 0.0046 - mean_absolute_error: 0.0046 - mean_squared_error: 4.6967e-05 - root_mean_squared_error: 0.0069 - coefficient_of_determination: 0.9990 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050 - val_mean_squared_error: 3.9502e-05 - val_root_mean_squared_error: 0.0063 - val_coefficient_of_determination: 0.8907
# Epoch 6/16
# 138/138 [==============================] - 20s 142ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 6.9261e-05 - root_mean_squared_error: 0.0083 - coefficient_of_determination: 0.9985 - val_loss: 0.0107 - val_mean_absolute_error: 0.0107 - val_mean_squared_error: 1.4739e-04 - val_root_mean_squared_error: 0.0121 - val_coefficient_of_determination: 0.5583
# Epoch 7/16
# 138/138 [==============================] - 13s 92ms/step - loss: 0.0048 - mean_absolute_error: 0.0048 - mean_squared_error: 5.0577e-05 - root_mean_squared_error: 0.0071 - coefficient_of_determination: 0.9989 - val_loss: 0.0080 - val_mean_absolute_error: 0.0080 - val_mean_squared_error: 9.0765e-05 - val_root_mean_squared_error: 0.0095 - val_coefficient_of_determination: 0.7325
# Epoch 8/16
# 138/138 [==============================] - 12s 83ms/step - loss: 0.0043 - mean_absolute_error: 0.0043 - mean_squared_error: 3.7868e-05 - root_mean_squared_error: 0.0062 - coefficient_of_determination: 0.9992 - val_loss: 0.0093 - val_mean_absolute_error: 0.0093 - val_mean_squared_error: 1.1394e-04 - val_root_mean_squared_error: 0.0107 - val_coefficient_of_determination: 0.6316
# Epoch 9/16
# 138/138 [==============================] - 11s 81ms/step - loss: 0.0047 - mean_absolute_error: 0.0047 - mean_squared_error: 4.1496e-05 - root_mean_squared_error: 0.0064 - coefficient_of_determination: 0.9991 - val_loss: 0.0335 - val_mean_absolute_error: 0.0335 - val_mean_squared_error: 0.0012 - val_root_mean_squared_error: 0.0340 - val_coefficient_of_determination: -2.7176
# Epoch 10/16
# 138/138 [==============================] - 12s 87ms/step - loss: 0.0060 - mean_absolute_error: 0.0060 - mean_squared_error: 6.3638e-05 - root_mean_squared_error: 0.0080 - coefficient_of_determination: 0.9987 - val_loss: 0.0067 - val_mean_absolute_error: 0.0067 - val_mean_squared_error: 6.8816e-05 - val_root_mean_squared_error: 0.0083 - val_coefficient_of_determination: 0.7891
# Epoch 11/16
# 138/138 [==============================] - 12s 88ms/step - loss: 0.0044 - mean_absolute_error: 0.0044 - mean_squared_error: 3.5029e-05 - root_mean_squared_error: 0.0059 - coefficient_of_determination: 0.9993 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 4.6101e-05 - val_root_mean_squared_error: 0.0068 - val_coefficient_of_determination: 0.8772
# Epoch 12/16
# 138/138 [==============================] - 12s 86ms/step - loss: 0.0042 - mean_absolute_error: 0.0042 - mean_squared_error: 3.4071e-05 - root_mean_squared_error: 0.0058 - coefficient_of_determination: 0.9993 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 4.4483e-05 - val_root_mean_squared_error: 0.0067 - val_coefficient_of_determination: 0.8851
# Epoch 13/16
# 138/138 [==============================] - 12s 86ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - mean_squared_error: 5.1501e-05 - root_mean_squared_error: 0.0072 - coefficient_of_determination: 0.9988 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092 - val_mean_squared_error: 1.2072e-04 - val_root_mean_squared_error: 0.0110 - val_coefficient_of_determination: 0.6247
# Epoch 14/16
# 138/138 [==============================] - 12s 88ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - mean_squared_error: 5.2158e-05 - root_mean_squared_error: 0.0072 - coefficient_of_determination: 0.9989 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060 - val_mean_squared_error: 5.2716e-05 - val_root_mean_squared_error: 0.0073 - val_coefficient_of_determination: 0.8608
# Epoch 15/16
# 138/138 [==============================] - 12s 89ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - mean_squared_error: 2.9688e-05 - root_mean_squared_error: 0.0054 - coefficient_of_determination: 0.9994 - val_loss: 0.0089 - val_mean_absolute_error: 0.0089 - val_mean_squared_error: 1.2264e-04 - val_root_mean_squared_error: 0.0111 - val_coefficient_of_determination: 0.6193
# Epoch 16/16
# 138/138 [==============================] - 12s 89ms/step - loss: 0.0042 - mean_absolute_error: 0.0042 - mean_squared_error: 3.8789e-05 - root_mean_squared_error: 0.0062 - coefficient_of_determination: 0.9992 - val_loss: 0.0226 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 5.7023e-04 - val_root_mean_squared_error: 0.0239 - val_coefficient_of_determination: -0.7870
# Epoch 1/12
# 138/138 [==============================] - 22s 162ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 6.9213e-06 - root_mean_squared_error: 0.0026 - coefficient_of_determination: 0.9999 - val_loss: 0.0064 - val_mean_absolute_error: 0.0064 - val_mean_squared_error: 6.3734e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.8286
# Epoch 2/12
# 138/138 [==============================] - 15s 106ms/step - loss: 6.6993e-04 - mean_absolute_error: 6.6993e-04 - mean_squared_error: 2.0245e-06 - root_mean_squared_error: 0.0014 - coefficient_of_determination: 1.0000 - val_loss: 0.0066 - val_mean_absolute_error: 0.0066 - val_mean_squared_error: 6.7827e-05 - val_root_mean_squared_error: 0.0082 - val_coefficient_of_determination: 0.8183
# Epoch 3/12
# 138/138 [==============================] - 12s 88ms/step - loss: 6.5389e-04 - mean_absolute_error: 6.5389e-04 - mean_squared_error: 1.9025e-06 - root_mean_squared_error: 0.0014 - coefficient_of_determination: 1.0000 - val_loss: 0.0069 - val_mean_absolute_error: 0.0069 - val_mean_squared_error: 7.2965e-05 - val_root_mean_squared_error: 0.0085 - val_coefficient_of_determination: 0.8026
# Epoch 4/12
# 138/138 [==============================] - 12s 89ms/step - loss: 6.2225e-04 - mean_absolute_error: 6.2225e-04 - mean_squared_error: 1.8119e-06 - root_mean_squared_error: 0.0013 - coefficient_of_determination: 1.0000 - val_loss: 0.0071 - val_mean_absolute_error: 0.0071 - val_mean_squared_error: 8.0197e-05 - val_root_mean_squared_error: 0.0090 - val_coefficient_of_determination: 0.7767
# Epoch 5/12
# 138/138 [==============================] - 12s 88ms/step - loss: 6.6485e-04 - mean_absolute_error: 6.6485e-04 - mean_squared_error: 1.8283e-06 - root_mean_squared_error: 0.0014 - coefficient_of_determination: 1.0000 - val_loss: 0.0074 - val_mean_absolute_error: 0.0074 - val_mean_squared_error: 8.2464e-05 - val_root_mean_squared_error: 0.0091 - val_coefficient_of_determination: 0.7748
# Epoch 6/12
# 138/138 [==============================] - 12s 90ms/step - loss: 6.6253e-04 - mean_absolute_error: 6.6253e-04 - mean_squared_error: 1.8308e-06 - root_mean_squared_error: 0.0014 - coefficient_of_determination: 1.0000 - val_loss: 0.0074 - val_mean_absolute_error: 0.0074 - val_mean_squared_error: 8.5021e-05 - val_root_mean_squared_error: 0.0092 - val_coefficient_of_determination: 0.7662
# Epoch 7/12
# 138/138 [==============================] - 12s 90ms/step - loss: 6.9405e-04 - mean_absolute_error: 6.9405e-04 - mean_squared_error: 1.9434e-06 - root_mean_squared_error: 0.0014 - coefficient_of_determination: 1.0000 - val_loss: 0.0080 - val_mean_absolute_error: 0.0080 - val_mean_squared_error: 9.5593e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.7369
# Epoch 8/12
# 138/138 [==============================] - 14s 98ms/step - loss: 6.9853e-04 - mean_absolute_error: 6.9853e-04 - mean_squared_error: 1.8943e-06 - root_mean_squared_error: 0.0014 - coefficient_of_determination: 1.0000 - val_loss: 0.0077 - val_mean_absolute_error: 0.0077 - val_mean_squared_error: 9.0729e-05 - val_root_mean_squared_error: 0.0095 - val_coefficient_of_determination: 0.7489
# Epoch 9/12
# 138/138 [==============================] - 13s 92ms/step - loss: 6.7672e-04 - mean_absolute_error: 6.7672e-04 - mean_squared_error: 1.8139e-06 - root_mean_squared_error: 0.0013 - coefficient_of_determination: 1.0000 - val_loss: 0.0079 - val_mean_absolute_error: 0.0079 - val_mean_squared_error: 9.4173e-05 - val_root_mean_squared_error: 0.0097 - val_coefficient_of_determination: 0.7418
# Epoch 10/12
# 138/138 [==============================] - 12s 88ms/step - loss: 7.3001e-04 - mean_absolute_error: 7.3001e-04 - mean_squared_error: 1.8598e-06 - root_mean_squared_error: 0.0014 - coefficient_of_determination: 1.0000 - val_loss: 0.0080 - val_mean_absolute_error: 0.0080 - val_mean_squared_error: 9.6426e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.7365
# Epoch 11/12
# 138/138 [==============================] - 19s 137ms/step - loss: 6.5723e-04 - mean_absolute_error: 6.5723e-04 - mean_squared_error: 1.7594e-06 - root_mean_squared_error: 0.0013 - coefficient_of_determination: 1.0000 - val_loss: 0.0080 - val_mean_absolute_error: 0.0080 - val_mean_squared_error: 9.7343e-05 - val_root_mean_squared_error: 0.0099 - val_coefficient_of_determination: 0.7345
# Epoch 12/12
# 138/138 [==============================] - 19s 134ms/step - loss: 6.7608e-04 - mean_absolute_error: 6.7608e-04 - mean_squared_error: 1.7131e-06 - root_mean_squared_error: 0.0013 - coefficient_of_determination: 1.0000 - val_loss: 0.0079 - val_mean_absolute_error: 0.0079 - val_mean_squared_error: 9.8085e-05 - val_root_mean_squared_error: 0.0099 - val_coefficient_of_determination: 0.7329
# Epoch 1/8
# 138/138 [==============================] - 14s 101ms/step - loss: 5.5093e-04 - mean_absolute_error: 5.5093e-04 - mean_squared_error: 1.4518e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0080 - val_mean_absolute_error: 0.0080 - val_mean_squared_error: 9.7011e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.7402
# Epoch 2/8
# 138/138 [==============================] - 12s 88ms/step - loss: 5.3412e-04 - mean_absolute_error: 5.3412e-04 - mean_squared_error: 1.4105e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0079 - val_mean_absolute_error: 0.0079 - val_mean_squared_error: 9.6933e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.7394
# Epoch 3/8
# 138/138 [==============================] - 12s 85ms/step - loss: 5.3462e-04 - mean_absolute_error: 5.3462e-04 - mean_squared_error: 1.4105e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0079 - val_mean_absolute_error: 0.0079 - val_mean_squared_error: 9.6796e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.7409
# Epoch 4/8
# 138/138 [==============================] - 12s 86ms/step - loss: 5.3583e-04 - mean_absolute_error: 5.3583e-04 - mean_squared_error: 1.4143e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0079 - val_mean_absolute_error: 0.0079 - val_mean_squared_error: 9.6564e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.7423
# Epoch 5/8
# 138/138 [==============================] - 12s 85ms/step - loss: 5.3362e-04 - mean_absolute_error: 5.3362e-04 - mean_squared_error: 1.4085e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0079 - val_mean_absolute_error: 0.0079 - val_mean_squared_error: 9.6473e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.7428
# Epoch 6/8
# 138/138 [==============================] - 12s 85ms/step - loss: 5.3563e-04 - mean_absolute_error: 5.3563e-04 - mean_squared_error: 1.3985e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0079 - val_mean_absolute_error: 0.0079 - val_mean_squared_error: 9.6257e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.7443
# Epoch 7/8
# 138/138 [==============================] - 12s 86ms/step - loss: 5.3791e-04 - mean_absolute_error: 5.3791e-04 - mean_squared_error: 1.3991e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0079 - val_mean_absolute_error: 0.0079 - val_mean_squared_error: 9.6161e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.7457
# Epoch 8/8
# 138/138 [==============================] - 12s 89ms/step - loss: 5.3345e-04 - mean_absolute_error: 5.3345e-04 - mean_squared_error: 1.3956e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0079 - val_mean_absolute_error: 0.0079 - val_mean_squared_error: 9.6237e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.7466

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 4/4 [==============================] - 1s 26ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted DJIA Open Price ($)")
plt.plot(y_test, color='blue', label="Actual DJIA Open Price ($)")
plt.title('DJIA Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('DJIA Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.0005334527813829482
# Mean Squared Error (MSE): 1.3956384918856202e-06
# Root Mean Squared Error (RMSE): 0.0011813713936135173
# Coefficient of Determination (R2): 0.9999611973762512

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.007888841442763805
# Validation Mean Squared Error (MSE): 9.623748337617144e-05
# Validation Root Mean Squared Error (RMSE): 0.009810070507228374
# Validation Coefficient of Determination (R2): 0.7466006278991699

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 125 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $91887.12217754754
# Balance Percentage Change: 9.188712217754755%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $16250980.005976405
# Balance Percentage Change: 16.250980005976405%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $235561.83083637082
# Balance Percentage Change: 23.556183083637084%
# ----------------------------------------------------------------
