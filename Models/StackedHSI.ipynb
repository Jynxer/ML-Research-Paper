# %% [markdown]
# # HSI Price Prediction Stacked LSTM with Wavelet Transforms and an Attention Mechanism

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from attention import Attention
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/HSI.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingDataNormalised.shape[0]):
    X_train.append(trainingData[i-exposureSize:i])
    y_train.append(trainingDataNormalised[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (3820, 365, 5)
# (3820,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(testInputsNormalised[i-exposureSize:i])
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (119, 365, 5)
# (119,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(50, return_sequences=True))
model.add(Attention(units=16))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./StackedHSIModel.png', show_shapes=True)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 365, 50)           11200
#
#  lstm_11 (LSTM)              (None, 365, 50)           20200
#
#  attention_5 (Attention)     (None, 16)                4100
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 35,517
# Trainable params: 35,517
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
numEpochsOne = 16
numEpochsTwo = 12
numEpochsThree = 8

historyOne = model.fit(X_train, y_train, epochs=numEpochsOne, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=numEpochsTwo, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=numEpochsThree, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 2022-08-18 00:38:03.557449: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 120/120 [==============================] - ETA: 0s - loss: 0.0568 - mean_absolute_error: 0.0568 - mean_squared_error: 0.0195 - root_mean_squared_error: 0.1398 - coefficient_of_determination: 0.4026
# 2022-08-18 00:38:42.096902: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 120/120 [==============================] - 44s 304ms/step - loss: 0.0568 - mean_absolute_error: 0.0568 - mean_squared_error: 0.0195 - root_mean_squared_error: 0.1398 - coefficient_of_determination: 0.4026 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591 - val_mean_squared_error: 0.0038 - val_root_mean_squared_error: 0.0614 - val_coefficient_of_determination: -5.0082
# Epoch 2/16
# 120/120 [==============================] - 20s 169ms/step - loss: 0.0215 - mean_absolute_error: 0.0215 - mean_squared_error: 7.7517e-04 - root_mean_squared_error: 0.0278 - coefficient_of_determination: 0.9777 - val_loss: 0.0302 - val_mean_absolute_error: 0.0302 - val_mean_squared_error: 0.0011 - val_root_mean_squared_error: 0.0335 - val_coefficient_of_determination: -0.7962
# Epoch 3/16
# 120/120 [==============================] - 20s 163ms/step - loss: 0.0206 - mean_absolute_error: 0.0206 - mean_squared_error: 8.4078e-04 - root_mean_squared_error: 0.0290 - coefficient_of_determination: 0.9774 - val_loss: 0.0671 - val_mean_absolute_error: 0.0671 - val_mean_squared_error: 0.0047 - val_root_mean_squared_error: 0.0683 - val_coefficient_of_determination: -6.3268
# Epoch 4/16
# 120/120 [==============================] - 19s 159ms/step - loss: 0.0154 - mean_absolute_error: 0.0154 - mean_squared_error: 4.1361e-04 - root_mean_squared_error: 0.0203 - coefficient_of_determination: 0.9877 - val_loss: 0.0276 - val_mean_absolute_error: 0.0276 - val_mean_squared_error: 8.8898e-04 - val_root_mean_squared_error: 0.0298 - val_coefficient_of_determination: -0.4469
# Epoch 5/16
# 120/120 [==============================] - 20s 168ms/step - loss: 0.0139 - mean_absolute_error: 0.0139 - mean_squared_error: 3.3621e-04 - root_mean_squared_error: 0.0183 - coefficient_of_determination: 0.9905 - val_loss: 0.0168 - val_mean_absolute_error: 0.0168 - val_mean_squared_error: 3.7307e-04 - val_root_mean_squared_error: 0.0193 - val_coefficient_of_determination: 0.3760
# Epoch 6/16
# 120/120 [==============================] - 20s 168ms/step - loss: 0.0159 - mean_absolute_error: 0.0159 - mean_squared_error: 4.4731e-04 - root_mean_squared_error: 0.0211 - coefficient_of_determination: 0.9863 - val_loss: 0.0141 - val_mean_absolute_error: 0.0141 - val_mean_squared_error: 2.7335e-04 - val_root_mean_squared_error: 0.0165 - val_coefficient_of_determination: 0.5505
# Epoch 7/16
# 120/120 [==============================] - 21s 174ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - mean_squared_error: 2.6173e-04 - root_mean_squared_error: 0.0162 - coefficient_of_determination: 0.9928 - val_loss: 0.0146 - val_mean_absolute_error: 0.0146 - val_mean_squared_error: 2.9056e-04 - val_root_mean_squared_error: 0.0170 - val_coefficient_of_determination: 0.5292
# Epoch 8/16
# 120/120 [==============================] - 20s 171ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - mean_squared_error: 2.8172e-04 - root_mean_squared_error: 0.0168 - coefficient_of_determination: 0.9920 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 9.7546e-04 - val_root_mean_squared_error: 0.0312 - val_coefficient_of_determination: -0.4202
# Epoch 9/16
# 120/120 [==============================] - 21s 174ms/step - loss: 0.0148 - mean_absolute_error: 0.0148 - mean_squared_error: 3.7046e-04 - root_mean_squared_error: 0.0192 - coefficient_of_determination: 0.9895 - val_loss: 0.0458 - val_mean_absolute_error: 0.0458 - val_mean_squared_error: 0.0022 - val_root_mean_squared_error: 0.0469 - val_coefficient_of_determination: -2.3811
# Epoch 10/16
# 120/120 [==============================] - 22s 182ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - mean_squared_error: 2.4170e-04 - root_mean_squared_error: 0.0155 - coefficient_of_determination: 0.9931 - val_loss: 0.0191 - val_mean_absolute_error: 0.0191 - val_mean_squared_error: 4.7243e-04 - val_root_mean_squared_error: 0.0217 - val_coefficient_of_determination: 0.2814
# Epoch 11/16
# 120/120 [==============================] - 22s 182ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - mean_squared_error: 2.0136e-04 - root_mean_squared_error: 0.0142 - coefficient_of_determination: 0.9944 - val_loss: 0.0096 - val_mean_absolute_error: 0.0096 - val_mean_squared_error: 1.5167e-04 - val_root_mean_squared_error: 0.0123 - val_coefficient_of_determination: 0.7671
# Epoch 12/16
# 120/120 [==============================] - 21s 172ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 2.0382e-04 - root_mean_squared_error: 0.0143 - coefficient_of_determination: 0.9943 - val_loss: 0.0309 - val_mean_absolute_error: 0.0309 - val_mean_squared_error: 0.0011 - val_root_mean_squared_error: 0.0327 - val_coefficient_of_determination: -0.6454
# Epoch 13/16
# 120/120 [==============================] - 21s 175ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - mean_squared_error: 2.1030e-04 - root_mean_squared_error: 0.0145 - coefficient_of_determination: 0.9939 - val_loss: 0.0156 - val_mean_absolute_error: 0.0156 - val_mean_squared_error: 3.4491e-04 - val_root_mean_squared_error: 0.0186 - val_coefficient_of_determination: 0.4747
# Epoch 14/16
# 120/120 [==============================] - 21s 179ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - mean_squared_error: 2.4774e-04 - root_mean_squared_error: 0.0157 - coefficient_of_determination: 0.9929 - val_loss: 0.0135 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 2.7212e-04 - val_root_mean_squared_error: 0.0165 - val_coefficient_of_determination: 0.5912
# Epoch 15/16
# 120/120 [==============================] - 21s 178ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - mean_squared_error: 2.0894e-04 - root_mean_squared_error: 0.0145 - coefficient_of_determination: 0.9940 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104 - val_mean_squared_error: 1.6498e-04 - val_root_mean_squared_error: 0.0128 - val_coefficient_of_determination: 0.7505
# Epoch 16/16
# 120/120 [==============================] - 22s 181ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - mean_squared_error: 2.2193e-04 - root_mean_squared_error: 0.0149 - coefficient_of_determination: 0.9939 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208 - val_mean_squared_error: 5.4550e-04 - val_root_mean_squared_error: 0.0234 - val_coefficient_of_determination: 0.1763
# Epoch 1/12
# 120/120 [==============================] - 22s 182ms/step - loss: 0.0085 - mean_absolute_error: 0.0085 - mean_squared_error: 1.4270e-04 - root_mean_squared_error: 0.0119 - coefficient_of_determination: 0.9959 - val_loss: 0.0105 - val_mean_absolute_error: 0.0105 - val_mean_squared_error: 1.8139e-04 - val_root_mean_squared_error: 0.0135 - val_coefficient_of_determination: 0.7240
# Epoch 2/12
# 120/120 [==============================] - 22s 182ms/step - loss: 0.0083 - mean_absolute_error: 0.0083 - mean_squared_error: 1.4018e-04 - root_mean_squared_error: 0.0118 - coefficient_of_determination: 0.9961 - val_loss: 0.0099 - val_mean_absolute_error: 0.0099 - val_mean_squared_error: 1.5384e-04 - val_root_mean_squared_error: 0.0124 - val_coefficient_of_determination: 0.7651
# Epoch 3/12
# 120/120 [==============================] - 22s 183ms/step - loss: 0.0082 - mean_absolute_error: 0.0082 - mean_squared_error: 1.3759e-04 - root_mean_squared_error: 0.0117 - coefficient_of_determination: 0.9961 - val_loss: 0.0134 - val_mean_absolute_error: 0.0134 - val_mean_squared_error: 2.7092e-04 - val_root_mean_squared_error: 0.0165 - val_coefficient_of_determination: 0.5881
# Epoch 4/12
# 120/120 [==============================] - 22s 183ms/step - loss: 0.0084 - mean_absolute_error: 0.0084 - mean_squared_error: 1.4220e-04 - root_mean_squared_error: 0.0119 - coefficient_of_determination: 0.9961 - val_loss: 0.0112 - val_mean_absolute_error: 0.0112 - val_mean_squared_error: 1.8728e-04 - val_root_mean_squared_error: 0.0137 - val_coefficient_of_determination: 0.7132
# Epoch 5/12
# 120/120 [==============================] - 23s 188ms/step - loss: 0.0082 - mean_absolute_error: 0.0082 - mean_squared_error: 1.3793e-04 - root_mean_squared_error: 0.0117 - coefficient_of_determination: 0.9961 - val_loss: 0.0110 - val_mean_absolute_error: 0.0110 - val_mean_squared_error: 1.9797e-04 - val_root_mean_squared_error: 0.0141 - val_coefficient_of_determination: 0.6985
# Epoch 6/12
# 120/120 [==============================] - 22s 187ms/step - loss: 0.0082 - mean_absolute_error: 0.0082 - mean_squared_error: 1.3835e-04 - root_mean_squared_error: 0.0118 - coefficient_of_determination: 0.9961 - val_loss: 0.0103 - val_mean_absolute_error: 0.0103 - val_mean_squared_error: 1.6542e-04 - val_root_mean_squared_error: 0.0129 - val_coefficient_of_determination: 0.7467
# Epoch 7/12
# 120/120 [==============================] - 22s 187ms/step - loss: 0.0084 - mean_absolute_error: 0.0084 - mean_squared_error: 1.4407e-04 - root_mean_squared_error: 0.0120 - coefficient_of_determination: 0.9960 - val_loss: 0.0108 - val_mean_absolute_error: 0.0108 - val_mean_squared_error: 1.7785e-04 - val_root_mean_squared_error: 0.0133 - val_coefficient_of_determination: 0.7267
# Epoch 8/12
# 120/120 [==============================] - 23s 194ms/step - loss: 0.0083 - mean_absolute_error: 0.0083 - mean_squared_error: 1.4118e-04 - root_mean_squared_error: 0.0119 - coefficient_of_determination: 0.9961 - val_loss: 0.0106 - val_mean_absolute_error: 0.0106 - val_mean_squared_error: 1.7332e-04 - val_root_mean_squared_error: 0.0132 - val_coefficient_of_determination: 0.7349
# Epoch 9/12
# 120/120 [==============================] - 23s 190ms/step - loss: 0.0082 - mean_absolute_error: 0.0082 - mean_squared_error: 1.3858e-04 - root_mean_squared_error: 0.0118 - coefficient_of_determination: 0.9959 - val_loss: 0.0127 - val_mean_absolute_error: 0.0127 - val_mean_squared_error: 2.5191e-04 - val_root_mean_squared_error: 0.0159 - val_coefficient_of_determination: 0.6169
# Epoch 10/12
# 120/120 [==============================] - 23s 188ms/step - loss: 0.0085 - mean_absolute_error: 0.0085 - mean_squared_error: 1.4646e-04 - root_mean_squared_error: 0.0121 - coefficient_of_determination: 0.9958 - val_loss: 0.0117 - val_mean_absolute_error: 0.0117 - val_mean_squared_error: 2.0548e-04 - val_root_mean_squared_error: 0.0143 - val_coefficient_of_determination: 0.6852
# Epoch 11/12
# 120/120 [==============================] - 21s 175ms/step - loss: 0.0084 - mean_absolute_error: 0.0084 - mean_squared_error: 1.4272e-04 - root_mean_squared_error: 0.0119 - coefficient_of_determination: 0.9959 - val_loss: 0.0106 - val_mean_absolute_error: 0.0106 - val_mean_squared_error: 1.7560e-04 - val_root_mean_squared_error: 0.0133 - val_coefficient_of_determination: 0.7328
# Epoch 12/12
# 120/120 [==============================] - 21s 177ms/step - loss: 0.0083 - mean_absolute_error: 0.0083 - mean_squared_error: 1.4074e-04 - root_mean_squared_error: 0.0119 - coefficient_of_determination: 0.9958 - val_loss: 0.0109 - val_mean_absolute_error: 0.0109 - val_mean_squared_error: 1.8809e-04 - val_root_mean_squared_error: 0.0137 - val_coefficient_of_determination: 0.7132
# Epoch 1/8
# 120/120 [==============================] - 21s 178ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - mean_squared_error: 1.3348e-04 - root_mean_squared_error: 0.0116 - coefficient_of_determination: 0.9963 - val_loss: 0.0109 - val_mean_absolute_error: 0.0109 - val_mean_squared_error: 1.8475e-04 - val_root_mean_squared_error: 0.0136 - val_coefficient_of_determination: 0.7180
# Epoch 2/8
# 120/120 [==============================] - 21s 173ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - mean_squared_error: 1.3313e-04 - root_mean_squared_error: 0.0115 - coefficient_of_determination: 0.9962 - val_loss: 0.0109 - val_mean_absolute_error: 0.0109 - val_mean_squared_error: 1.8433e-04 - val_root_mean_squared_error: 0.0136 - val_coefficient_of_determination: 0.7186
# Epoch 3/8
# 120/120 [==============================] - 21s 179ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - mean_squared_error: 1.3260e-04 - root_mean_squared_error: 0.0115 - coefficient_of_determination: 0.9962 - val_loss: 0.0109 - val_mean_absolute_error: 0.0109 - val_mean_squared_error: 1.8688e-04 - val_root_mean_squared_error: 0.0137 - val_coefficient_of_determination: 0.7151
# Epoch 4/8
# 120/120 [==============================] - 22s 180ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - mean_squared_error: 1.3262e-04 - root_mean_squared_error: 0.0115 - coefficient_of_determination: 0.9962 - val_loss: 0.0110 - val_mean_absolute_error: 0.0110 - val_mean_squared_error: 1.8684e-04 - val_root_mean_squared_error: 0.0137 - val_coefficient_of_determination: 0.7144
# Epoch 5/8
# 120/120 [==============================] - 24s 196ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - mean_squared_error: 1.3315e-04 - root_mean_squared_error: 0.0115 - coefficient_of_determination: 0.9962 - val_loss: 0.0110 - val_mean_absolute_error: 0.0110 - val_mean_squared_error: 1.8714e-04 - val_root_mean_squared_error: 0.0137 - val_coefficient_of_determination: 0.7140
# Epoch 6/8
# 120/120 [==============================] - 24s 197ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - mean_squared_error: 1.3257e-04 - root_mean_squared_error: 0.0115 - coefficient_of_determination: 0.9962 - val_loss: 0.0110 - val_mean_absolute_error: 0.0110 - val_mean_squared_error: 1.8822e-04 - val_root_mean_squared_error: 0.0137 - val_coefficient_of_determination: 0.7127
# Epoch 7/8
# 120/120 [==============================] - 22s 182ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - mean_squared_error: 1.3333e-04 - root_mean_squared_error: 0.0115 - coefficient_of_determination: 0.9962 - val_loss: 0.0110 - val_mean_absolute_error: 0.0110 - val_mean_squared_error: 1.8836e-04 - val_root_mean_squared_error: 0.0137 - val_coefficient_of_determination: 0.7127
# Epoch 8/8
# 120/120 [==============================] - 23s 187ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - mean_squared_error: 1.3425e-04 - root_mean_squared_error: 0.0116 - coefficient_of_determination: 0.9963 - val_loss: 0.0110 - val_mean_absolute_error: 0.0110 - val_mean_squared_error: 1.8978e-04 - val_root_mean_squared_error: 0.0138 - val_coefficient_of_determination: 0.7104

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 2022-08-18 00:51:17.175882: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 4/4 [==============================] - 1s 47ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted HSI Open Price ($)")
plt.plot(y_test, color='blue', label="Actual HSI Open Price ($)")
plt.title('HSI Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('HSI Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, numEpochsOne, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(numEpochsOne, numEpochsOne+numEpochsTwo, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(numEpochsOne+numEpochsTwo, numEpochsOne+numEpochsTwo+numEpochsThree, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, numEpochsOne+numEpochsTwo+numEpochsThree-1)
plt.xticks([2*i for i in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)], [(2*j)+1 for j in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, numEpochsOne, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(numEpochsOne, numEpochsOne+numEpochsTwo, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(numEpochsOne+numEpochsTwo, numEpochsOne+numEpochsTwo+numEpochsThree, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, numEpochsOne+numEpochsTwo+numEpochsThree-1)
plt.xticks([2*i for i in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)], [(2*j)+1 for j in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.008010626770555973
# Mean Squared Error (MSE): 0.00013424589997157454
# Root Mean Squared Error (RMSE): 0.011586452834308147
# Coefficient of Determination (R2): 0.9962618947029114

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.011019953526556492
# Validation Mean Squared Error (MSE): 0.00018977680883836
# Validation Root Mean Squared Error (RMSE): 0.01377595029771328
# Validation Coefficient of Determination (R2): 0.7103508710861206

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 119 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $508.45563668501563
# Balance Percentage Change: 0.05084556366850157%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $97911.12813486453
# Balance Percentage Change: 9.791112813486452%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $129582.95410078671
# Balance Percentage Change: 12.958295410078671%
# ----------------------------------------------------------------
