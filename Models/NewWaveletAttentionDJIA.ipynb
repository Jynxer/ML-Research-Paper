# %% [markdown]
# # DJIA Price Prediction LSTM with New Input using Wavelet Transforms and an Attention Mechanism

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from attention import Attention
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/DJIA.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingDataNormalised.shape[0]):
    X_train.append(np.concatenate([trainingDataNormalised[i-exposureSize:i], trainingData[i-exposureSize:i]], axis=1))
    y_train.append(trainingDataNormalised[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (4414, 365, 10)
# (4414,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)
testInputsTransformed = np.array(WaveletTransform(testInputsNormalised, 3))

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(np.concatenate([testInputsNormalised[i-exposureSize:i], testInputsTransformed[i-exposureSize:i]], axis=1))
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (125, 365, 10)
# (125,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res = K.sum(K.square(y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(Attention(units=16))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./WaveletDJIAModel.png', show_shapes=True)
# Out:
# 2022-08-18 14:14:51.274657: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 365, 50)           12200
#
#  attention (Attention)       (None, 16)                4100
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 16,317
# Trainable params: 16,317
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
historyOne = model.fit(X_train, y_train, epochs=16, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=12, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=8, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 2022-08-18 14:14:55.187372: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 138/138 [==============================] - ETA: 0s - loss: 0.0361 - mean_absolute_error: 0.0361 - mean_squared_error: 0.0085 - root_mean_squared_error: 0.0920 - coefficient_of_determination: 0.8657
# 2022-08-18 14:15:20.595672: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 138/138 [==============================] - 28s 179ms/step - loss: 0.0361 - mean_absolute_error: 0.0361 - mean_squared_error: 0.0085 - root_mean_squared_error: 0.0920 - coefficient_of_determination: 0.8657 - val_loss: 0.0420 - val_mean_absolute_error: 0.0420 - val_mean_squared_error: 0.0019 - val_root_mean_squared_error: 0.0438 - val_coefficient_of_determination: -5.2886
# Epoch 2/16
# 138/138 [==============================] - 14s 102ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - mean_squared_error: 3.0870e-04 - root_mean_squared_error: 0.0176 - coefficient_of_determination: 0.9937 - val_loss: 0.0078 - val_mean_absolute_error: 0.0078 - val_mean_squared_error: 1.0307e-04 - val_root_mean_squared_error: 0.0102 - val_coefficient_of_determination: 0.7231
# Epoch 3/16
# 138/138 [==============================] - 14s 101ms/step - loss: 0.0092 - mean_absolute_error: 0.0092 - mean_squared_error: 1.5730e-04 - root_mean_squared_error: 0.0125 - coefficient_of_determination: 0.9968 - val_loss: 0.0408 - val_mean_absolute_error: 0.0408 - val_mean_squared_error: 0.0017 - val_root_mean_squared_error: 0.0418 - val_coefficient_of_determination: -4.4945
# Epoch 4/16
# 138/138 [==============================] - 13s 98ms/step - loss: 0.0086 - mean_absolute_error: 0.0086 - mean_squared_error: 1.4016e-04 - root_mean_squared_error: 0.0118 - coefficient_of_determination: 0.9971 - val_loss: 0.0143 - val_mean_absolute_error: 0.0143 - val_mean_squared_error: 2.6654e-04 - val_root_mean_squared_error: 0.0163 - val_coefficient_of_determination: 0.2122
# Epoch 5/16
# 138/138 [==============================] - 15s 108ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - mean_squared_error: 3.0042e-04 - root_mean_squared_error: 0.0173 - coefficient_of_determination: 0.9935 - val_loss: 0.0245 - val_mean_absolute_error: 0.0245 - val_mean_squared_error: 6.6607e-04 - val_root_mean_squared_error: 0.0258 - val_coefficient_of_determination: -1.0882
# Epoch 6/16
# 138/138 [==============================] - 15s 109ms/step - loss: 0.0067 - mean_absolute_error: 0.0067 - mean_squared_error: 8.5663e-05 - root_mean_squared_error: 0.0093 - coefficient_of_determination: 0.9982 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060 - val_mean_squared_error: 6.4753e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.8448
# Epoch 7/16
# 138/138 [==============================] - 15s 107ms/step - loss: 0.0086 - mean_absolute_error: 0.0086 - mean_squared_error: 1.6840e-04 - root_mean_squared_error: 0.0130 - coefficient_of_determination: 0.9965 - val_loss: 0.0253 - val_mean_absolute_error: 0.0253 - val_mean_squared_error: 7.0462e-04 - val_root_mean_squared_error: 0.0265 - val_coefficient_of_determination: -1.2322
# Epoch 8/16
# 138/138 [==============================] - 15s 106ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - mean_squared_error: 9.3239e-05 - root_mean_squared_error: 0.0097 - coefficient_of_determination: 0.9979 - val_loss: 0.0069 - val_mean_absolute_error: 0.0069 - val_mean_squared_error: 7.9627e-05 - val_root_mean_squared_error: 0.0089 - val_coefficient_of_determination: 0.7951
# Epoch 9/16
# 138/138 [==============================] - 16s 113ms/step - loss: 0.0063 - mean_absolute_error: 0.0063 - mean_squared_error: 7.8674e-05 - root_mean_squared_error: 0.0089 - coefficient_of_determination: 0.9984 - val_loss: 0.0080 - val_mean_absolute_error: 0.0080 - val_mean_squared_error: 9.5070e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.7320
# Epoch 10/16
# 138/138 [==============================] - 17s 121ms/step - loss: 0.0093 - mean_absolute_error: 0.0093 - mean_squared_error: 1.6195e-04 - root_mean_squared_error: 0.0127 - coefficient_of_determination: 0.9967 - val_loss: 0.0134 - val_mean_absolute_error: 0.0134 - val_mean_squared_error: 2.3273e-04 - val_root_mean_squared_error: 0.0153 - val_coefficient_of_determination: 0.2918
# Epoch 11/16
# 138/138 [==============================] - 15s 112ms/step - loss: 0.0059 - mean_absolute_error: 0.0059 - mean_squared_error: 6.8700e-05 - root_mean_squared_error: 0.0083 - coefficient_of_determination: 0.9985 - val_loss: 0.0395 - val_mean_absolute_error: 0.0395 - val_mean_squared_error: 0.0016 - val_root_mean_squared_error: 0.0404 - val_coefficient_of_determination: -4.3443
# Epoch 12/16
# 138/138 [==============================] - 14s 101ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - mean_squared_error: 4.8192e-05 - root_mean_squared_error: 0.0069 - coefficient_of_determination: 0.9990 - val_loss: 0.0320 - val_mean_absolute_error: 0.0320 - val_mean_squared_error: 0.0011 - val_root_mean_squared_error: 0.0331 - val_coefficient_of_determination: -2.5851
# Epoch 13/16
# 138/138 [==============================] - 14s 104ms/step - loss: 0.0083 - mean_absolute_error: 0.0083 - mean_squared_error: 1.2820e-04 - root_mean_squared_error: 0.0113 - coefficient_of_determination: 0.9974 - val_loss: 0.0085 - val_mean_absolute_error: 0.0085 - val_mean_squared_error: 1.1262e-04 - val_root_mean_squared_error: 0.0106 - val_coefficient_of_determination: 0.7101
# Epoch 14/16
# 138/138 [==============================] - 15s 106ms/step - loss: 0.0047 - mean_absolute_error: 0.0047 - mean_squared_error: 4.1480e-05 - root_mean_squared_error: 0.0064 - coefficient_of_determination: 0.9991 - val_loss: 0.0257 - val_mean_absolute_error: 0.0257 - val_mean_squared_error: 7.2428e-04 - val_root_mean_squared_error: 0.0269 - val_coefficient_of_determination: -1.3675
# Epoch 15/16
# 138/138 [==============================] - 15s 110ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - mean_squared_error: 6.0357e-05 - root_mean_squared_error: 0.0078 - coefficient_of_determination: 0.9987 - val_loss: 0.0061 - val_mean_absolute_error: 0.0061 - val_mean_squared_error: 5.9236e-05 - val_root_mean_squared_error: 0.0077 - val_coefficient_of_determination: 0.8550
# Epoch 16/16
# 138/138 [==============================] - 15s 111ms/step - loss: 0.0055 - mean_absolute_error: 0.0055 - mean_squared_error: 6.2457e-05 - root_mean_squared_error: 0.0079 - coefficient_of_determination: 0.9987 - val_loss: 0.0165 - val_mean_absolute_error: 0.0165 - val_mean_squared_error: 3.2424e-04 - val_root_mean_squared_error: 0.0180 - val_coefficient_of_determination: -0.0334
# Epoch 1/12
# 138/138 [==============================] - 15s 109ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - mean_squared_error: 7.4900e-06 - root_mean_squared_error: 0.0027 - coefficient_of_determination: 0.9999 - val_loss: 0.0069 - val_mean_absolute_error: 0.0069 - val_mean_squared_error: 7.0544e-05 - val_root_mean_squared_error: 0.0084 - val_coefficient_of_determination: 0.8140
# Epoch 2/12
# 138/138 [==============================] - 15s 106ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - mean_squared_error: 6.0534e-06 - root_mean_squared_error: 0.0025 - coefficient_of_determination: 0.9999 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 5.0108e-05 - val_root_mean_squared_error: 0.0071 - val_coefficient_of_determination: 0.8810
# Epoch 3/12
# 138/138 [==============================] - 15s 108ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - mean_squared_error: 5.6841e-06 - root_mean_squared_error: 0.0024 - coefficient_of_determination: 0.9999 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050 - val_mean_squared_error: 4.5029e-05 - val_root_mean_squared_error: 0.0067 - val_coefficient_of_determination: 0.8992
# Epoch 4/12
# 138/138 [==============================] - 16s 112ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - mean_squared_error: 6.0258e-06 - root_mean_squared_error: 0.0025 - coefficient_of_determination: 0.9999 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 5.1849e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.8696
# Epoch 5/12
# 138/138 [==============================] - 15s 111ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 5.3075e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050 - val_mean_squared_error: 4.1772e-05 - val_root_mean_squared_error: 0.0065 - val_coefficient_of_determination: 0.9024
# Epoch 6/12
# 138/138 [==============================] - 15s 110ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 5.1325e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048 - val_mean_squared_error: 3.9663e-05 - val_root_mean_squared_error: 0.0063 - val_coefficient_of_determination: 0.9084
# Epoch 7/12
# 138/138 [==============================] - 16s 118ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - mean_squared_error: 5.4696e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051 - val_mean_squared_error: 4.2450e-05 - val_root_mean_squared_error: 0.0065 - val_coefficient_of_determination: 0.8966
# Epoch 8/12
# 138/138 [==============================] - 16s 115ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 5.1404e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050 - val_mean_squared_error: 4.0701e-05 - val_root_mean_squared_error: 0.0064 - val_coefficient_of_determination: 0.9015
# Epoch 9/12
# 138/138 [==============================] - 16s 117ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 5.0959e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047 - val_mean_squared_error: 3.7485e-05 - val_root_mean_squared_error: 0.0061 - val_coefficient_of_determination: 0.9121
# Epoch 10/12
# 138/138 [==============================] - 19s 137ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 4.6641e-06 - root_mean_squared_error: 0.0022 - coefficient_of_determination: 0.9999 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050 - val_mean_squared_error: 3.9758e-05 - val_root_mean_squared_error: 0.0063 - val_coefficient_of_determination: 0.9016
# Epoch 11/12
# 138/138 [==============================] - 18s 128ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 4.8070e-06 - root_mean_squared_error: 0.0022 - coefficient_of_determination: 0.9999 - val_loss: 0.0052 - val_mean_absolute_error: 0.0052 - val_mean_squared_error: 4.2679e-05 - val_root_mean_squared_error: 0.0065 - val_coefficient_of_determination: 0.8919
# Epoch 12/12
# 138/138 [==============================] - 18s 131ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 4.6119e-06 - root_mean_squared_error: 0.0021 - coefficient_of_determination: 0.9999 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045 - val_mean_squared_error: 3.4548e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9182
# Epoch 1/8
# 138/138 [==============================] - 18s 130ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.7414e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048 - val_mean_squared_error: 3.7233e-05 - val_root_mean_squared_error: 0.0061 - val_coefficient_of_determination: 0.9090
# Epoch 2/8
# 138/138 [==============================] - 18s 127ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.6865e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047 - val_mean_squared_error: 3.6005e-05 - val_root_mean_squared_error: 0.0060 - val_coefficient_of_determination: 0.9131
# Epoch 3/8
# 138/138 [==============================] - 18s 130ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.6984e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047 - val_mean_squared_error: 3.5582e-05 - val_root_mean_squared_error: 0.0060 - val_coefficient_of_determination: 0.9142
# Epoch 4/8
# 138/138 [==============================] - 18s 132ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.7266e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047 - val_mean_squared_error: 3.6348e-05 - val_root_mean_squared_error: 0.0060 - val_coefficient_of_determination: 0.9115
# Epoch 5/8
# 138/138 [==============================] - 18s 133ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.6857e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050 - val_mean_squared_error: 3.9646e-05 - val_root_mean_squared_error: 0.0063 - val_coefficient_of_determination: 0.9005
# Epoch 6/8
# 138/138 [==============================] - 18s 130ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.6535e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047 - val_mean_squared_error: 3.6558e-05 - val_root_mean_squared_error: 0.0060 - val_coefficient_of_determination: 0.9106
# Epoch 7/8
# 138/138 [==============================] - 18s 128ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.6108e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046 - val_mean_squared_error: 3.4661e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9164
# Epoch 8/8
# 138/138 [==============================] - 18s 127ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.5611e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 3.3496e-05 - val_root_mean_squared_error: 0.0058 - val_coefficient_of_determination: 0.9200

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 1/4 [======>.......................] - ETA: 1s
# 2022-08-18 14:24:41.208215: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 4/4 [==============================] - 1s 50ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted DJIA Open Price ($)")
plt.plot(y_test, color='blue', label="Actual DJIA Open Price ($)")
plt.title('DJIA Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('DJIA Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.0010206080041825771
# Mean Squared Error (MSE): 3.5610530630947324e-06
# Root Mean Squared Error (RMSE): 0.0018870752537623048
# Coefficient of Determination (R2): 0.9999256134033203

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.0044245668686926365
# Validation Mean Squared Error (MSE): 3.34959986503236e-05
# Validation Root Mean Squared Error (RMSE): 0.0057875728234648705
# Validation Coefficient of Determination (R2): 0.9199671149253845

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 125 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $120151.03800337226
# Balance Percentage Change: 12.015103800337226%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $162509.80005976406
# Balance Percentage Change: 16.250980005976405%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $257258.20959120058
# Balance Percentage Change: 25.725820959120053%
# ----------------------------------------------------------------
