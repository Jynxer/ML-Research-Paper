# %% [markdown]
# # HSI Price Prediction LSTM with an Attention Mechanism

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from attention import Attention
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/HSI.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingData = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingData.shape[0]):
    X_train.append(trainingData[i-exposureSize:i])
    y_train.append(trainingData[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (3820, 365, 5)
# (3820,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(testInputsNormalised[i-exposureSize:i])
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (119, 365, 5)
# (119,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(Attention(units=16))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./AttentionHSIModel.png', show_shapes=True)
# Out:
# 2022-08-17 15:52:19.509063: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 365, 50)           11200
#
#  attention (Attention)       (None, 16)                4100
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 15,317
# Trainable params: 15,317
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
historyOne = model.fit(X_train, y_train, epochs=16, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=12, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=8, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 2022-08-17 15:52:22.268806: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 120/120 [==============================] - ETA: 0s - loss: 0.0378 - mean_absolute_error: 0.0378 - mean_squared_error: 0.0068 - root_mean_squared_error: 0.0823 - coefficient_of_determination: 0.7984
# 2022-08-17 15:52:33.935549: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 120/120 [==============================] - 13s 94ms/step - loss: 0.0378 - mean_absolute_error: 0.0378 - mean_squared_error: 0.0068 - root_mean_squared_error: 0.0823 - coefficient_of_determination: 0.7984 - val_loss: 0.0108 - val_mean_absolute_error: 0.0108 - val_mean_squared_error: 1.7303e-04 - val_root_mean_squared_error: 0.0132 - val_coefficient_of_determination: 0.7317
# Epoch 2/16
# 120/120 [==============================] - 10s 87ms/step - loss: 0.0152 - mean_absolute_error: 0.0152 - mean_squared_error: 4.0745e-04 - root_mean_squared_error: 0.0202 - coefficient_of_determination: 0.9889 - val_loss: 0.0173 - val_mean_absolute_error: 0.0173 - val_mean_squared_error: 4.0230e-04 - val_root_mean_squared_error: 0.0201 - val_coefficient_of_determination: 0.4469
# Epoch 3/16
# 120/120 [==============================] - 11s 88ms/step - loss: 0.0137 - mean_absolute_error: 0.0137 - mean_squared_error: 3.3033e-04 - root_mean_squared_error: 0.0182 - coefficient_of_determination: 0.9906 - val_loss: 0.0279 - val_mean_absolute_error: 0.0279 - val_mean_squared_error: 8.7888e-04 - val_root_mean_squared_error: 0.0296 - val_coefficient_of_determination: -0.2762
# Epoch 4/16
# 120/120 [==============================] - 11s 88ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - mean_squared_error: 2.4184e-04 - root_mean_squared_error: 0.0156 - coefficient_of_determination: 0.9931 - val_loss: 0.0106 - val_mean_absolute_error: 0.0106 - val_mean_squared_error: 1.6706e-04 - val_root_mean_squared_error: 0.0129 - val_coefficient_of_determination: 0.7261
# Epoch 5/16
# 120/120 [==============================] - 11s 88ms/step - loss: 0.0143 - mean_absolute_error: 0.0143 - mean_squared_error: 3.3795e-04 - root_mean_squared_error: 0.0184 - coefficient_of_determination: 0.9907 - val_loss: 0.0298 - val_mean_absolute_error: 0.0298 - val_mean_squared_error: 9.6868e-04 - val_root_mean_squared_error: 0.0311 - val_coefficient_of_determination: -0.4168
# Epoch 6/16
# 120/120 [==============================] - 11s 95ms/step - loss: 0.0141 - mean_absolute_error: 0.0141 - mean_squared_error: 3.5717e-04 - root_mean_squared_error: 0.0189 - coefficient_of_determination: 0.9899 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 9.5097e-04 - val_root_mean_squared_error: 0.0308 - val_coefficient_of_determination: -0.4957
# Epoch 7/16
# 120/120 [==============================] - 12s 96ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - mean_squared_error: 2.3049e-04 - root_mean_squared_error: 0.0152 - coefficient_of_determination: 0.9932 - val_loss: 0.0219 - val_mean_absolute_error: 0.0219 - val_mean_squared_error: 5.4653e-04 - val_root_mean_squared_error: 0.0234 - val_coefficient_of_determination: 0.1318
# Epoch 8/16
# 120/120 [==============================] - 13s 105ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - mean_squared_error: 2.7653e-04 - root_mean_squared_error: 0.0166 - coefficient_of_determination: 0.9919 - val_loss: 0.0211 - val_mean_absolute_error: 0.0211 - val_mean_squared_error: 5.0831e-04 - val_root_mean_squared_error: 0.0225 - val_coefficient_of_determination: 0.2579
# Epoch 9/16
# 120/120 [==============================] - 13s 111ms/step - loss: 0.0091 - mean_absolute_error: 0.0091 - mean_squared_error: 1.5180e-04 - root_mean_squared_error: 0.0123 - coefficient_of_determination: 0.9957 - val_loss: 0.0141 - val_mean_absolute_error: 0.0141 - val_mean_squared_error: 2.5122e-04 - val_root_mean_squared_error: 0.0159 - val_coefficient_of_determination: 0.6015
# Epoch 10/16
# 120/120 [==============================] - 12s 101ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - mean_squared_error: 1.8569e-04 - root_mean_squared_error: 0.0136 - coefficient_of_determination: 0.9947 - val_loss: 0.0227 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 5.8193e-04 - val_root_mean_squared_error: 0.0241 - val_coefficient_of_determination: 0.1652
# Epoch 11/16
# 120/120 [==============================] - 12s 102ms/step - loss: 0.0079 - mean_absolute_error: 0.0079 - mean_squared_error: 1.2494e-04 - root_mean_squared_error: 0.0112 - coefficient_of_determination: 0.9963 - val_loss: 0.0089 - val_mean_absolute_error: 0.0089 - val_mean_squared_error: 1.2314e-04 - val_root_mean_squared_error: 0.0111 - val_coefficient_of_determination: 0.8104
# Epoch 12/16
# 120/120 [==============================] - 12s 102ms/step - loss: 0.0097 - mean_absolute_error: 0.0097 - mean_squared_error: 1.7039e-04 - root_mean_squared_error: 0.0131 - coefficient_of_determination: 0.9952 - val_loss: 0.0099 - val_mean_absolute_error: 0.0099 - val_mean_squared_error: 1.4547e-04 - val_root_mean_squared_error: 0.0121 - val_coefficient_of_determination: 0.7989
# Epoch 13/16
# 120/120 [==============================] - 12s 100ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - mean_squared_error: 1.2474e-04 - root_mean_squared_error: 0.0112 - coefficient_of_determination: 0.9963 - val_loss: 0.0089 - val_mean_absolute_error: 0.0089 - val_mean_squared_error: 1.2197e-04 - val_root_mean_squared_error: 0.0110 - val_coefficient_of_determination: 0.8333
# Epoch 14/16
# 120/120 [==============================] - 12s 100ms/step - loss: 0.0099 - mean_absolute_error: 0.0099 - mean_squared_error: 1.7476e-04 - root_mean_squared_error: 0.0132 - coefficient_of_determination: 0.9952 - val_loss: 0.0074 - val_mean_absolute_error: 0.0074 - val_mean_squared_error: 9.1424e-05 - val_root_mean_squared_error: 0.0096 - val_coefficient_of_determination: 0.8736
# Epoch 15/16
# 120/120 [==============================] - 12s 101ms/step - loss: 0.0083 - mean_absolute_error: 0.0083 - mean_squared_error: 1.3472e-04 - root_mean_squared_error: 0.0116 - coefficient_of_determination: 0.9961 - val_loss: 0.0064 - val_mean_absolute_error: 0.0064 - val_mean_squared_error: 7.5649e-05 - val_root_mean_squared_error: 0.0087 - val_coefficient_of_determination: 0.8872
# Epoch 16/16
# 120/120 [==============================] - 13s 112ms/step - loss: 0.0088 - mean_absolute_error: 0.0088 - mean_squared_error: 1.3812e-04 - root_mean_squared_error: 0.0118 - coefficient_of_determination: 0.9962 - val_loss: 0.0111 - val_mean_absolute_error: 0.0111 - val_mean_squared_error: 1.6555e-04 - val_root_mean_squared_error: 0.0129 - val_coefficient_of_determination: 0.7423
# Epoch 1/12
# 120/120 [==============================] - 12s 100ms/step - loss: 0.0060 - mean_absolute_error: 0.0060 - mean_squared_error: 7.9122e-05 - root_mean_squared_error: 0.0089 - coefficient_of_determination: 0.9978 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060 - val_mean_squared_error: 6.6758e-05 - val_root_mean_squared_error: 0.0082 - val_coefficient_of_determination: 0.9018
# Epoch 2/12
# 120/120 [==============================] - 12s 97ms/step - loss: 0.0059 - mean_absolute_error: 0.0059 - mean_squared_error: 7.8632e-05 - root_mean_squared_error: 0.0089 - coefficient_of_determination: 0.9977 - val_loss: 0.0061 - val_mean_absolute_error: 0.0061 - val_mean_squared_error: 6.8889e-05 - val_root_mean_squared_error: 0.0083 - val_coefficient_of_determination: 0.8964
# Epoch 3/12
# 120/120 [==============================] - 12s 99ms/step - loss: 0.0059 - mean_absolute_error: 0.0059 - mean_squared_error: 7.7317e-05 - root_mean_squared_error: 0.0088 - coefficient_of_determination: 0.9978 - val_loss: 0.0064 - val_mean_absolute_error: 0.0064 - val_mean_squared_error: 7.4133e-05 - val_root_mean_squared_error: 0.0086 - val_coefficient_of_determination: 0.8881
# Epoch 4/12
# 120/120 [==============================] - 13s 108ms/step - loss: 0.0059 - mean_absolute_error: 0.0059 - mean_squared_error: 7.9352e-05 - root_mean_squared_error: 0.0089 - coefficient_of_determination: 0.9977 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 6.3915e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.9057
# Epoch 5/12
# 120/120 [==============================] - 14s 115ms/step - loss: 0.0059 - mean_absolute_error: 0.0059 - mean_squared_error: 7.8313e-05 - root_mean_squared_error: 0.0088 - coefficient_of_determination: 0.9978 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 6.3515e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.9082
# Epoch 6/12
# 120/120 [==============================] - 14s 117ms/step - loss: 0.0059 - mean_absolute_error: 0.0059 - mean_squared_error: 7.8542e-05 - root_mean_squared_error: 0.0089 - coefficient_of_determination: 0.9977 - val_loss: 0.0061 - val_mean_absolute_error: 0.0061 - val_mean_squared_error: 6.9004e-05 - val_root_mean_squared_error: 0.0083 - val_coefficient_of_determination: 0.8943
# Epoch 7/12
# 120/120 [==============================] - 13s 111ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 7.6753e-05 - root_mean_squared_error: 0.0088 - coefficient_of_determination: 0.9978 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 6.4370e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.9084
# Epoch 8/12
# 120/120 [==============================] - 14s 115ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 7.6188e-05 - root_mean_squared_error: 0.0087 - coefficient_of_determination: 0.9978 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 6.4092e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.9049
# Epoch 9/12
# 120/120 [==============================] - 14s 116ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 7.6798e-05 - root_mean_squared_error: 0.0088 - coefficient_of_determination: 0.9978 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 6.3621e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.9094
# Epoch 10/12
# 120/120 [==============================] - 13s 113ms/step - loss: 0.0059 - mean_absolute_error: 0.0059 - mean_squared_error: 7.8183e-05 - root_mean_squared_error: 0.0088 - coefficient_of_determination: 0.9978 - val_loss: 0.0069 - val_mean_absolute_error: 0.0069 - val_mean_squared_error: 8.0791e-05 - val_root_mean_squared_error: 0.0090 - val_coefficient_of_determination: 0.8730
# Epoch 11/12
# 120/120 [==============================] - 13s 111ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 7.6996e-05 - root_mean_squared_error: 0.0088 - coefficient_of_determination: 0.9978 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 6.3941e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.9034
# Epoch 12/12
# 120/120 [==============================] - 13s 110ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 7.6505e-05 - root_mean_squared_error: 0.0087 - coefficient_of_determination: 0.9978 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 6.4181e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.9094
# Epoch 1/8
# 120/120 [==============================] - 14s 113ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.2995e-05 - root_mean_squared_error: 0.0085 - coefficient_of_determination: 0.9979 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 6.3699e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.9052
# Epoch 2/8
# 120/120 [==============================] - 14s 118ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.2717e-05 - root_mean_squared_error: 0.0085 - coefficient_of_determination: 0.9979 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 6.2537e-05 - val_root_mean_squared_error: 0.0079 - val_coefficient_of_determination: 0.9106
# Epoch 3/8
# 120/120 [==============================] - 13s 110ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.3598e-05 - root_mean_squared_error: 0.0086 - coefficient_of_determination: 0.9980 - val_loss: 0.0061 - val_mean_absolute_error: 0.0061 - val_mean_squared_error: 6.8676e-05 - val_root_mean_squared_error: 0.0083 - val_coefficient_of_determination: 0.8953
# Epoch 4/8
# 120/120 [==============================] - 13s 109ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.2469e-05 - root_mean_squared_error: 0.0085 - coefficient_of_determination: 0.9980 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 6.4836e-05 - val_root_mean_squared_error: 0.0081 - val_coefficient_of_determination: 0.9029
# Epoch 5/8
# 120/120 [==============================] - 13s 109ms/step - loss: 0.0055 - mean_absolute_error: 0.0055 - mean_squared_error: 7.2607e-05 - root_mean_squared_error: 0.0085 - coefficient_of_determination: 0.9979 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 6.2959e-05 - val_root_mean_squared_error: 0.0079 - val_coefficient_of_determination: 0.9067
# Epoch 6/8
# 120/120 [==============================] - 13s 109ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.2908e-05 - root_mean_squared_error: 0.0085 - coefficient_of_determination: 0.9979 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 6.1430e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9110
# Epoch 7/8
# 120/120 [==============================] - 14s 113ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.3339e-05 - root_mean_squared_error: 0.0086 - coefficient_of_determination: 0.9979 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 6.3865e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.9049
# Epoch 8/8
# 120/120 [==============================] - 14s 120ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.2918e-05 - root_mean_squared_error: 0.0085 - coefficient_of_determination: 0.9979 - val_loss: 0.0059 - val_mean_absolute_error: 0.0059 - val_mean_squared_error: 6.6275e-05 - val_root_mean_squared_error: 0.0081 - val_coefficient_of_determination: 0.9001

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 1/4 [======>.......................] - ETA: 1s
# 2022-08-17 15:59:57.654107: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 4/4 [==============================] - 1s 40ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted HSI Open Price ($)")
plt.plot(y_test, color='blue', label="Actual HSI Open Price ($)")
plt.title('HSI Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('HSI Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.0055641853250563145
# Mean Squared Error (MSE): 7.291787915164605e-05
# Root Mean Squared Error (RMSE): 0.008539197035133839
# Coefficient of Determination (R2): 0.9979217052459717

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.005932474508881569
# Validation Mean Squared Error (MSE): 6.627536640735343e-05
# Validation Root Mean Squared Error (RMSE): 0.008140968158841133
# Validation Coefficient of Determination (R2): 0.9001100659370422

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 119 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $54772.06214572443
# Balance Percentage Change: 5.477206214572443%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $97911.12813486453
# Balance Percentage Change: 9.791112813486452%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $162393.16361452523
# Balance Percentage Change: 16.23931636145252%
# ----------------------------------------------------------------
