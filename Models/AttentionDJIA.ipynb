# %% [markdown]
# # DJIA Price Prediction LSTM with an Attention Mechanism

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from attention import Attention
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/DJIA.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingData = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingData.shape[0]):
    X_train.append(trainingData[i-exposureSize:i])
    y_train.append(trainingData[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (4414, 365, 5)
# (4414,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(testInputsNormalised[i-exposureSize:i])
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (125, 365, 5)
# (125,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(Attention(units=16))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./AttentionDJIAModel.png', show_shapes=True)
# Out:
# 2022-08-17 15:39:24.221079: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 365, 50)           11200
#
#  attention (Attention)       (None, 16)                4100
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 15,317
# Trainable params: 15,317
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
historyOne = model.fit(X_train, y_train, epochs=16, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=12, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=8, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 2022-08-17 15:39:27.170994: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 138/138 [==============================] - ETA: 0s - loss: 0.0354 - mean_absolute_error: 0.0354 - mean_squared_error: 0.0072 - root_mean_squared_error: 0.0851 - coefficient_of_determination: 0.7982
# 2022-08-17 15:39:45.959949: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 138/138 [==============================] - 21s 135ms/step - loss: 0.0354 - mean_absolute_error: 0.0354 - mean_squared_error: 0.0072 - root_mean_squared_error: 0.0851 - coefficient_of_determination: 0.7982 - val_loss: 0.0428 - val_mean_absolute_error: 0.0428 - val_mean_squared_error: 0.0019 - val_root_mean_squared_error: 0.0440 - val_coefficient_of_determination: -5.0947
# Epoch 2/16
# 138/138 [==============================] - 14s 98ms/step - loss: 0.0098 - mean_absolute_error: 0.0098 - mean_squared_error: 1.8444e-04 - root_mean_squared_error: 0.0136 - coefficient_of_determination: 0.9961 - val_loss: 0.0112 - val_mean_absolute_error: 0.0112 - val_mean_squared_error: 1.8741e-04 - val_root_mean_squared_error: 0.0137 - val_coefficient_of_determination: 0.3720
# Epoch 3/16
# 138/138 [==============================] - 12s 85ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - mean_squared_error: 2.1096e-04 - root_mean_squared_error: 0.0145 - coefficient_of_determination: 0.9954 - val_loss: 0.0062 - val_mean_absolute_error: 0.0062 - val_mean_squared_error: 5.8828e-05 - val_root_mean_squared_error: 0.0077 - val_coefficient_of_determination: 0.8253
# Epoch 4/16
# 138/138 [==============================] - 12s 89ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 1.9291e-04 - root_mean_squared_error: 0.0139 - coefficient_of_determination: 0.9956 - val_loss: 0.0593 - val_mean_absolute_error: 0.0593 - val_mean_squared_error: 0.0036 - val_root_mean_squared_error: 0.0597 - val_coefficient_of_determination: -10.4472
# Epoch 5/16
# 138/138 [==============================] - 13s 93ms/step - loss: 0.0077 - mean_absolute_error: 0.0077 - mean_squared_error: 1.1539e-04 - root_mean_squared_error: 0.0107 - coefficient_of_determination: 0.9976 - val_loss: 0.0190 - val_mean_absolute_error: 0.0190 - val_mean_squared_error: 4.0464e-04 - val_root_mean_squared_error: 0.0201 - val_coefficient_of_determination: -0.2380
# Epoch 6/16
# 138/138 [==============================] - 13s 93ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - mean_squared_error: 9.0996e-05 - root_mean_squared_error: 0.0095 - coefficient_of_determination: 0.9980 - val_loss: 0.0101 - val_mean_absolute_error: 0.0101 - val_mean_squared_error: 1.3305e-04 - val_root_mean_squared_error: 0.0115 - val_coefficient_of_determination: 0.5999
# Epoch 7/16
# 138/138 [==============================] - 13s 95ms/step - loss: 0.0066 - mean_absolute_error: 0.0066 - mean_squared_error: 8.1483e-05 - root_mean_squared_error: 0.0090 - coefficient_of_determination: 0.9982 - val_loss: 0.0063 - val_mean_absolute_error: 0.0063 - val_mean_squared_error: 6.7018e-05 - val_root_mean_squared_error: 0.0082 - val_coefficient_of_determination: 0.8263
# Epoch 8/16
# 138/138 [==============================] - 15s 107ms/step - loss: 0.0050 - mean_absolute_error: 0.0050 - mean_squared_error: 4.6764e-05 - root_mean_squared_error: 0.0068 - coefficient_of_determination: 0.9991 - val_loss: 0.0097 - val_mean_absolute_error: 0.0097 - val_mean_squared_error: 1.2104e-04 - val_root_mean_squared_error: 0.0110 - val_coefficient_of_determination: 0.6104
# Epoch 9/16
# 138/138 [==============================] - 15s 108ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - mean_squared_error: 6.3026e-05 - root_mean_squared_error: 0.0079 - coefficient_of_determination: 0.9987 - val_loss: 0.0340 - val_mean_absolute_error: 0.0340 - val_mean_squared_error: 0.0012 - val_root_mean_squared_error: 0.0346 - val_coefficient_of_determination: -2.6779
# Epoch 10/16
# 138/138 [==============================] - 14s 103ms/step - loss: 0.0062 - mean_absolute_error: 0.0062 - mean_squared_error: 7.6940e-05 - root_mean_squared_error: 0.0088 - coefficient_of_determination: 0.9984 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 4.5041e-05 - val_root_mean_squared_error: 0.0067 - val_coefficient_of_determination: 0.8809
# Epoch 11/16
# 138/138 [==============================] - 15s 106ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - mean_squared_error: 1.0222e-04 - root_mean_squared_error: 0.0101 - coefficient_of_determination: 0.9978 - val_loss: 0.0053 - val_mean_absolute_error: 0.0053 - val_mean_squared_error: 4.6894e-05 - val_root_mean_squared_error: 0.0068 - val_coefficient_of_determination: 0.8932
# Epoch 12/16
# 138/138 [==============================] - 14s 101ms/step - loss: 0.0042 - mean_absolute_error: 0.0042 - mean_squared_error: 3.6838e-05 - root_mean_squared_error: 0.0061 - coefficient_of_determination: 0.9992 - val_loss: 0.0190 - val_mean_absolute_error: 0.0190 - val_mean_squared_error: 4.0852e-04 - val_root_mean_squared_error: 0.0202 - val_coefficient_of_determination: -0.3396
# Epoch 13/16
# 138/138 [==============================] - 14s 103ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 5.9641e-05 - root_mean_squared_error: 0.0077 - coefficient_of_determination: 0.9988 - val_loss: 0.0159 - val_mean_absolute_error: 0.0159 - val_mean_squared_error: 2.9200e-04 - val_root_mean_squared_error: 0.0171 - val_coefficient_of_determination: 0.0603
# Epoch 14/16
# 138/138 [==============================] - 14s 104ms/step - loss: 0.0060 - mean_absolute_error: 0.0060 - mean_squared_error: 6.9218e-05 - root_mean_squared_error: 0.0083 - coefficient_of_determination: 0.9985 - val_loss: 0.0238 - val_mean_absolute_error: 0.0238 - val_mean_squared_error: 6.1989e-04 - val_root_mean_squared_error: 0.0249 - val_coefficient_of_determination: -1.0416
# Epoch 15/16
# 138/138 [==============================] - 14s 100ms/step - loss: 0.0050 - mean_absolute_error: 0.0050 - mean_squared_error: 4.6237e-05 - root_mean_squared_error: 0.0068 - coefficient_of_determination: 0.9990 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 5.0556e-05 - val_root_mean_squared_error: 0.0071 - val_coefficient_of_determination: 0.8730
# Epoch 16/16
# 138/138 [==============================] - 14s 102ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - mean_squared_error: 2.9162e-05 - root_mean_squared_error: 0.0054 - coefficient_of_determination: 0.9994 - val_loss: 0.0267 - val_mean_absolute_error: 0.0267 - val_mean_squared_error: 7.4428e-04 - val_root_mean_squared_error: 0.0273 - val_coefficient_of_determination: -1.3251
# Epoch 1/12
# 138/138 [==============================] - 15s 110ms/step - loss: 0.0019 - mean_absolute_error: 0.0019 - mean_squared_error: 1.1174e-05 - root_mean_squared_error: 0.0033 - coefficient_of_determination: 0.9998 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054 - val_mean_squared_error: 4.1353e-05 - val_root_mean_squared_error: 0.0064 - val_coefficient_of_determination: 0.8896
# Epoch 2/12
# 138/138 [==============================] - 16s 113ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 4.7612e-06 - root_mean_squared_error: 0.0022 - coefficient_of_determination: 0.9999 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048 - val_mean_squared_error: 3.4706e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9134
# Epoch 3/12
# 138/138 [==============================] - 14s 103ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 4.4591e-06 - root_mean_squared_error: 0.0021 - coefficient_of_determination: 0.9999 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051 - val_mean_squared_error: 3.7041e-05 - val_root_mean_squared_error: 0.0061 - val_coefficient_of_determination: 0.9004
# Epoch 4/12
# 138/138 [==============================] - 15s 110ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 4.4258e-06 - root_mean_squared_error: 0.0021 - coefficient_of_determination: 0.9999 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046 - val_mean_squared_error: 3.2811e-05 - val_root_mean_squared_error: 0.0057 - val_coefficient_of_determination: 0.9161
# Epoch 5/12
# 138/138 [==============================] - 16s 115ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 4.5229e-06 - root_mean_squared_error: 0.0021 - coefficient_of_determination: 0.9999 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045 - val_mean_squared_error: 3.2579e-05 - val_root_mean_squared_error: 0.0057 - val_coefficient_of_determination: 0.9181
# Epoch 6/12
# 138/138 [==============================] - 16s 115ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 4.2575e-06 - root_mean_squared_error: 0.0021 - coefficient_of_determination: 0.9999 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049 - val_mean_squared_error: 3.5221e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9048
# Epoch 7/12
# 138/138 [==============================] - 16s 114ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 4.4734e-06 - root_mean_squared_error: 0.0021 - coefficient_of_determination: 0.9999 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045 - val_mean_squared_error: 3.0774e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9203
# Epoch 8/12
# 138/138 [==============================] - 16s 118ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 4.1640e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045 - val_mean_squared_error: 3.1057e-05 - val_root_mean_squared_error: 0.0056 - val_coefficient_of_determination: 0.9191
# Epoch 9/12
# 138/138 [==============================] - 16s 116ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 4.0015e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 3.0486e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9216
# Epoch 10/12
# 138/138 [==============================] - 17s 120ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 4.2401e-06 - root_mean_squared_error: 0.0021 - coefficient_of_determination: 0.9999 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049 - val_mean_squared_error: 3.4943e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9047
# Epoch 11/12
# 138/138 [==============================] - 17s 121ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.8866e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060 - val_mean_squared_error: 5.0128e-05 - val_root_mean_squared_error: 0.0071 - val_coefficient_of_determination: 0.8551
# Epoch 12/12
# 138/138 [==============================] - 17s 121ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.9153e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 4.4123e-05 - val_root_mean_squared_error: 0.0066 - val_coefficient_of_determination: 0.8759
# Epoch 1/8
# 138/138 [==============================] - 16s 119ms/step - loss: 9.4602e-04 - mean_absolute_error: 9.4602e-04 - mean_squared_error: 3.2305e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045 - val_mean_squared_error: 3.0593e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9194
# Epoch 2/8
# 138/138 [==============================] - 17s 126ms/step - loss: 9.2768e-04 - mean_absolute_error: 9.2768e-04 - mean_squared_error: 3.1847e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 2.9871e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9217
# Epoch 3/8
# 138/138 [==============================] - 17s 123ms/step - loss: 9.2651e-04 - mean_absolute_error: 9.2651e-04 - mean_squared_error: 3.2098e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 2.9009e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9242
# Epoch 4/8
# 138/138 [==============================] - 17s 121ms/step - loss: 9.2807e-04 - mean_absolute_error: 9.2807e-04 - mean_squared_error: 3.1773e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 2.8538e-05 - val_root_mean_squared_error: 0.0053 - val_coefficient_of_determination: 0.9257
# Epoch 5/8
# 138/138 [==============================] - 16s 118ms/step - loss: 9.3661e-04 - mean_absolute_error: 9.3661e-04 - mean_squared_error: 3.2687e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 2.9359e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9231
# Epoch 6/8
# 138/138 [==============================] - 18s 127ms/step - loss: 9.2662e-04 - mean_absolute_error: 9.2662e-04 - mean_squared_error: 3.1988e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 2.9300e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9232
# Epoch 7/8
# 138/138 [==============================] - 18s 127ms/step - loss: 9.1871e-04 - mean_absolute_error: 9.1871e-04 - mean_squared_error: 3.1337e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045 - val_mean_squared_error: 3.0068e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9207
# Epoch 8/8
# 138/138 [==============================] - 17s 121ms/step - loss: 9.2086e-04 - mean_absolute_error: 9.2086e-04 - mean_squared_error: 3.1806e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 2.9315e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9232

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 1/4 [======>.......................] - ETA: 1s
# 2022-08-17 15:48:37.521231: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 4/4 [==============================] - 1s 40ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted DJIA Open Price ($)")
plt.plot(y_test, color='blue', label="Actual DJIA Open Price ($)")
plt.title('DJIA Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('DJIA Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.0009208607953041792
# Mean Squared Error (MSE): 3.180563453497598e-06
# Root Mean Squared Error (RMSE): 0.0017834134632721543
# Coefficient of Determination (R2): 0.9999381899833679

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.004382949788123369
# Validation Mean Squared Error (MSE): 2.9315284336917102e-05
# Validation Root Mean Squared Error (RMSE): 0.005414359271526337
# Validation Coefficient of Determination (R2): 0.9231780767440796

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 125 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $49819.954550310504
# Balance Percentage Change: 4.981995455031051%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $162509.80005976406
# Balance Percentage Change: 16.250980005976405%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $251226.33725258848
# Balance Percentage Change: 25.122633725258847%
# ----------------------------------------------------------------
