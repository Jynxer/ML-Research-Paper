# %% [markdown]
# # S&P 500 Price Prediction Stacked LSTM with New Input using Wavelet Transforms and an Attention Mechanism

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from attention import Attention
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/S&P500.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingDataNormalised.shape[0]):
    X_train.append(np.concatenate([trainingDataNormalised[i-exposureSize:i], trainingData[i-exposureSize:i]], axis=1))
    y_train.append(trainingDataNormalised[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (4414, 365, 10)
# (4414,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)
testInputsTransformed = np.array(WaveletTransform(testInputsNormalised, 3))

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(np.concatenate([testInputsNormalised[i-exposureSize:i], testInputsTransformed[i-exposureSize:i]], axis=1))
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (125, 365, 10)
# (125,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res = K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return (1 - SS_res/(SS_tot + K.epsilon()))

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(50, return_sequences=True))
model.add(Attention(units=16))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./StackedSP500Model.png', show_shapes=True)
# Out:
# 2022-08-18 14:26:45.935379: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 365, 50)           12200
#
#  lstm_1 (LSTM)               (None, 365, 50)           20200
#
#  attention (Attention)       (None, 16)                4100
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 36,517
# Trainable params: 36,517
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
numEpochsOne = 16
numEpochsTwo = 12
numEpochsThree = 8

historyOne = model.fit(X_train, y_train, epochs=numEpochsOne, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=numEpochsTwo, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=numEpochsThree, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 2022-08-18 14:26:51.035985: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 138/138 [==============================] - ETA: 0s - loss: 0.0380 - mean_absolute_error: 0.0380 - mean_squared_error: 0.0073 - root_mean_squared_error: 0.0853 - coefficient_of_determination: 0.8429
# 2022-08-18 14:27:25.696148: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 138/138 [==============================] - 38s 242ms/step - loss: 0.0380 - mean_absolute_error: 0.0380 - mean_squared_error: 0.0073 - root_mean_squared_error: 0.0853 - coefficient_of_determination: 0.8429 - val_loss: 0.0356 - val_mean_absolute_error: 0.0356 - val_mean_squared_error: 0.0014 - val_root_mean_squared_error: 0.0376 - val_coefficient_of_determination: -3.2907
# Epoch 2/16
# 138/138 [==============================] - 28s 201ms/step - loss: 0.0168 - mean_absolute_error: 0.0168 - mean_squared_error: 5.5116e-04 - root_mean_squared_error: 0.0235 - coefficient_of_determination: 0.9897 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - val_mean_squared_error: 0.0029 - val_root_mean_squared_error: 0.0543 - val_coefficient_of_determination: -7.8051
# Epoch 3/16
# 138/138 [==============================] - 27s 196ms/step - loss: 0.0131 - mean_absolute_error: 0.0131 - mean_squared_error: 3.0994e-04 - root_mean_squared_error: 0.0176 - coefficient_of_determination: 0.9939 - val_loss: 0.0317 - val_mean_absolute_error: 0.0317 - val_mean_squared_error: 0.0011 - val_root_mean_squared_error: 0.0334 - val_coefficient_of_determination: -2.3835
# Epoch 4/16
# 138/138 [==============================] - 29s 212ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - mean_squared_error: 2.3837e-04 - root_mean_squared_error: 0.0154 - coefficient_of_determination: 0.9956 - val_loss: 0.0246 - val_mean_absolute_error: 0.0246 - val_mean_squared_error: 6.8087e-04 - val_root_mean_squared_error: 0.0261 - val_coefficient_of_determination: -0.9478
# Epoch 5/16
# 138/138 [==============================] - 30s 218ms/step - loss: 0.0135 - mean_absolute_error: 0.0135 - mean_squared_error: 3.6735e-04 - root_mean_squared_error: 0.0192 - coefficient_of_determination: 0.9931 - val_loss: 0.0072 - val_mean_absolute_error: 0.0072 - val_mean_squared_error: 8.6969e-05 - val_root_mean_squared_error: 0.0093 - val_coefficient_of_determination: 0.7846
# Epoch 6/16
# 138/138 [==============================] - 33s 237ms/step - loss: 0.0154 - mean_absolute_error: 0.0154 - mean_squared_error: 4.6603e-04 - root_mean_squared_error: 0.0216 - coefficient_of_determination: 0.9902 - val_loss: 0.0074 - val_mean_absolute_error: 0.0074 - val_mean_squared_error: 9.2298e-05 - val_root_mean_squared_error: 0.0096 - val_coefficient_of_determination: 0.7736
# Epoch 7/16
# 138/138 [==============================] - 29s 213ms/step - loss: 0.0082 - mean_absolute_error: 0.0082 - mean_squared_error: 1.2871e-04 - root_mean_squared_error: 0.0113 - coefficient_of_determination: 0.9975 - val_loss: 0.0310 - val_mean_absolute_error: 0.0310 - val_mean_squared_error: 0.0010 - val_root_mean_squared_error: 0.0320 - val_coefficient_of_determination: -1.9573
# Epoch 8/16
# 138/138 [==============================] - 32s 228ms/step - loss: 0.0069 - mean_absolute_error: 0.0069 - mean_squared_error: 8.6606e-05 - root_mean_squared_error: 0.0093 - coefficient_of_determination: 0.9984 - val_loss: 0.0075 - val_mean_absolute_error: 0.0075 - val_mean_squared_error: 9.7375e-05 - val_root_mean_squared_error: 0.0099 - val_coefficient_of_determination: 0.7565
# Epoch 9/16
# 138/138 [==============================] - 32s 229ms/step - loss: 0.0088 - mean_absolute_error: 0.0088 - mean_squared_error: 1.5752e-04 - root_mean_squared_error: 0.0126 - coefficient_of_determination: 0.9969 - val_loss: 0.0297 - val_mean_absolute_error: 0.0297 - val_mean_squared_error: 9.1755e-04 - val_root_mean_squared_error: 0.0303 - val_coefficient_of_determination: -1.8008
# Epoch 10/16
# 138/138 [==============================] - 34s 246ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - mean_squared_error: 1.1052e-04 - root_mean_squared_error: 0.0105 - coefficient_of_determination: 0.9979 - val_loss: 0.0228 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 5.8806e-04 - val_root_mean_squared_error: 0.0242 - val_coefficient_of_determination: -0.7362
# Epoch 11/16
# 138/138 [==============================] - 32s 232ms/step - loss: 0.0087 - mean_absolute_error: 0.0087 - mean_squared_error: 1.4761e-04 - root_mean_squared_error: 0.0121 - coefficient_of_determination: 0.9972 - val_loss: 0.0194 - val_mean_absolute_error: 0.0194 - val_mean_squared_error: 4.2421e-04 - val_root_mean_squared_error: 0.0206 - val_coefficient_of_determination: -0.1649
# Epoch 12/16
# 138/138 [==============================] - 31s 224ms/step - loss: 0.0061 - mean_absolute_error: 0.0061 - mean_squared_error: 7.1450e-05 - root_mean_squared_error: 0.0085 - coefficient_of_determination: 0.9986 - val_loss: 0.0264 - val_mean_absolute_error: 0.0264 - val_mean_squared_error: 7.6018e-04 - val_root_mean_squared_error: 0.0276 - val_coefficient_of_determination: -1.2696
# Epoch 13/16
# 138/138 [==============================] - 32s 234ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - mean_squared_error: 1.0203e-04 - root_mean_squared_error: 0.0101 - coefficient_of_determination: 0.9980 - val_loss: 0.0158 - val_mean_absolute_error: 0.0158 - val_mean_squared_error: 2.9828e-04 - val_root_mean_squared_error: 0.0173 - val_coefficient_of_determination: 0.1583
# Epoch 14/16
# 138/138 [==============================] - 34s 249ms/step - loss: 0.0064 - mean_absolute_error: 0.0064 - mean_squared_error: 8.7304e-05 - root_mean_squared_error: 0.0093 - coefficient_of_determination: 0.9983 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.8539e-05 - val_root_mean_squared_error: 0.0077 - val_coefficient_of_determination: 0.8563
# Epoch 15/16
# 138/138 [==============================] - 34s 245ms/step - loss: 0.0063 - mean_absolute_error: 0.0063 - mean_squared_error: 8.1522e-05 - root_mean_squared_error: 0.0090 - coefficient_of_determination: 0.9984 - val_loss: 0.0077 - val_mean_absolute_error: 0.0077 - val_mean_squared_error: 9.3223e-05 - val_root_mean_squared_error: 0.0097 - val_coefficient_of_determination: 0.7691
# Epoch 16/16
# 138/138 [==============================] - 36s 262ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - mean_squared_error: 1.1455e-04 - root_mean_squared_error: 0.0107 - coefficient_of_determination: 0.9977 - val_loss: 0.0070 - val_mean_absolute_error: 0.0070 - val_mean_squared_error: 8.2631e-05 - val_root_mean_squared_error: 0.0091 - val_coefficient_of_determination: 0.8243
# Epoch 1/12
# 138/138 [==============================] - 34s 243ms/step - loss: 0.0019 - mean_absolute_error: 0.0019 - mean_squared_error: 8.6090e-06 - root_mean_squared_error: 0.0029 - coefficient_of_determination: 0.9998 - val_loss: 0.0077 - val_mean_absolute_error: 0.0077 - val_mean_squared_error: 8.8823e-05 - val_root_mean_squared_error: 0.0094 - val_coefficient_of_determination: 0.7587
# Epoch 2/12
# 138/138 [==============================] - 31s 227ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - mean_squared_error: 5.9426e-06 - root_mean_squared_error: 0.0024 - coefficient_of_determination: 0.9999 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048 - val_mean_squared_error: 4.0243e-05 - val_root_mean_squared_error: 0.0063 - val_coefficient_of_determination: 0.9020
# Epoch 3/12
# 138/138 [==============================] - 34s 248ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - mean_squared_error: 5.8091e-06 - root_mean_squared_error: 0.0024 - coefficient_of_determination: 0.9999 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050 - val_mean_squared_error: 4.1445e-05 - val_root_mean_squared_error: 0.0064 - val_coefficient_of_determination: 0.8971
# Epoch 4/12
# 138/138 [==============================] - 36s 263ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - mean_squared_error: 5.4579e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 3.3531e-05 - val_root_mean_squared_error: 0.0058 - val_coefficient_of_determination: 0.9174
# Epoch 5/12
# 138/138 [==============================] - 36s 260ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - mean_squared_error: 5.3932e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 3.1386e-05 - val_root_mean_squared_error: 0.0056 - val_coefficient_of_determination: 0.9231
# Epoch 6/12
# 138/138 [==============================] - 36s 263ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - mean_squared_error: 5.1026e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045 - val_mean_squared_error: 3.4737e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9147
# Epoch 7/12
# 138/138 [==============================] - 35s 256ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - mean_squared_error: 5.4632e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0053 - val_mean_absolute_error: 0.0053 - val_mean_squared_error: 4.2970e-05 - val_root_mean_squared_error: 0.0066 - val_coefficient_of_determination: 0.8910
# Epoch 8/12
# 138/138 [==============================] - 37s 268ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - mean_squared_error: 4.7783e-06 - root_mean_squared_error: 0.0022 - coefficient_of_determination: 0.9999 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 3.2053e-05 - val_root_mean_squared_error: 0.0057 - val_coefficient_of_determination: 0.9220
# Epoch 9/12
# 138/138 [==============================] - 37s 270ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - mean_squared_error: 5.4506e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 4.4895e-05 - val_root_mean_squared_error: 0.0067 - val_coefficient_of_determination: 0.8855
# Epoch 10/12
# 138/138 [==============================] - 38s 276ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - mean_squared_error: 4.7831e-06 - root_mean_squared_error: 0.0022 - coefficient_of_determination: 0.9999 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054 - val_mean_squared_error: 4.2862e-05 - val_root_mean_squared_error: 0.0065 - val_coefficient_of_determination: 0.8924
# Epoch 11/12
# 138/138 [==============================] - 39s 285ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - mean_squared_error: 5.2150e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 2.9591e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9270
# Epoch 12/12
# 138/138 [==============================] - 38s 273ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - mean_squared_error: 4.7956e-06 - root_mean_squared_error: 0.0022 - coefficient_of_determination: 0.9999 - val_loss: 0.0070 - val_mean_absolute_error: 0.0070 - val_mean_squared_error: 6.6716e-05 - val_root_mean_squared_error: 0.0082 - val_coefficient_of_determination: 0.8222
# Epoch 1/8
# 138/138 [==============================] - 39s 285ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.5362e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046 - val_mean_squared_error: 3.4204e-05 - val_root_mean_squared_error: 0.0058 - val_coefficient_of_determination: 0.9156
# Epoch 2/8
# 138/138 [==============================] - 34s 246ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.4980e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046 - val_mean_squared_error: 3.4231e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9157
# Epoch 3/8
# 138/138 [==============================] - 37s 272ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.4247e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 2.9696e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9267
# Epoch 4/8
# 138/138 [==============================] - 40s 290ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.4800e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047 - val_mean_squared_error: 3.4901e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9141
# Epoch 5/8
# 138/138 [==============================] - 39s 282ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.4236e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 3.0192e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9259
# Epoch 6/8
# 138/138 [==============================] - 42s 302ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.3974e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050 - val_mean_squared_error: 3.8428e-05 - val_root_mean_squared_error: 0.0062 - val_coefficient_of_determination: 0.9046
# Epoch 7/8
# 138/138 [==============================] - 36s 260ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.4996e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049 - val_mean_squared_error: 3.6884e-05 - val_root_mean_squared_error: 0.0061 - val_coefficient_of_determination: 0.9091
# Epoch 8/8
# 138/138 [==============================] - 36s 261ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.4409e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 3.1785e-05 - val_root_mean_squared_error: 0.0056 - val_coefficient_of_determination: 0.9222

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 2022-08-18 14:47:35.646603: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 4/4 [==============================] - 1s 81ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]

# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
numTicks = 10
xTicks = []
tickDifference = dates.shape[0] // numTicks
for i in range(numTicks):
    xTicks.append(dates.iloc[i*tickDifference])
xTicks.append(dates.iloc[-1])

xTickLocations = np.arange(0, dates.shape[0], tickDifference)

plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted S&P 500 Open Price ($)")
plt.plot(y_test, color='blue', label="Actual S&P 500 Open Price ($)")
plt.title('S&P 500 Open Price Prediction')
plt.xticks(xTickLocations, xTicks)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('S&P 500 Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, numEpochsOne, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(numEpochsOne, numEpochsOne+numEpochsTwo, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(numEpochsOne+numEpochsTwo, numEpochsOne+numEpochsTwo+numEpochsThree, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, numEpochsOne+numEpochsTwo+numEpochsThree-1)
plt.xticks([2*i for i in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)], [(2*j)+1 for j in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, numEpochsOne, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(numEpochsOne, numEpochsOne+numEpochsTwo, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(numEpochsOne+numEpochsTwo, numEpochsOne+numEpochsTwo+numEpochsThree, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, numEpochsOne+numEpochsTwo+numEpochsThree-1)
plt.xticks([2*i for i in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)], [(2*j)+1 for j in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.0010343976318836212
# Mean Squared Error (MSE): 3.4409015370329143e-06
# Root Mean Squared Error (RMSE): 0.001854966743849218
# Coefficient of Determination (R2): 0.9999365210533142

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.004349391907453537
# Validation Mean Squared Error (MSE): 3.178525730618276e-05
# Validation Root Mean Squared Error (RMSE): 0.005637841764837503
# Validation Coefficient of Determination (R2): 0.9222304821014404

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 125 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $84933.85981104779
# Balance Percentage Change: 8.493385981104778%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $199619.67847085418
# Balance Percentage Change: 19.96196784708542%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $240336.69800868584
# Balance Percentage Change: 24.033669800868584%
# ----------------------------------------------------------------
