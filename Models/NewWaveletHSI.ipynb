# %% [markdown]
# # HSI Price Prediction LSTM with New Input using Wavelet Transforms

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from attention import Attention
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/HSI.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingDataNormalised.shape[0]):
    X_train.append(np.concatenate([trainingDataNormalised[i-exposureSize:i], trainingData[i-exposureSize:i]], axis=1))
    y_train.append(trainingDataNormalised[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (3820, 365, 10)
# (3820,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)
testInputsTransformed = np.array(WaveletTransform(testInputsNormalised, 3))

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(np.concatenate([testInputsNormalised[i-exposureSize:i], testInputsTransformed[i-exposureSize:i]], axis=1))
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (119, 365, 10)
# (119,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./StackedHSIModel.png', show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 50)                12200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 12,251
# Trainable params: 12,251
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
numEpochsOne = 16
numEpochsTwo = 12
numEpochsThree = 8

historyOne = model.fit(X_train, y_train, epochs=numEpochsOne, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=numEpochsTwo, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=numEpochsThree, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 120/120 [==============================] - 22s 169ms/step - loss: 0.0365 - mean_absolute_error: 0.0365 - mean_squared_error: 0.0086 - root_mean_squared_error: 0.0927 - coefficient_of_determination: 0.7479 - val_loss: 0.0155 - val_mean_absolute_error: 0.0155 - val_mean_squared_error: 3.3606e-04 - val_root_mean_squared_error: 0.0183 - val_coefficient_of_determination: 0.5459
# Epoch 2/16
# 120/120 [==============================] - 10s 87ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - mean_squared_error: 2.3475e-04 - root_mean_squared_error: 0.0153 - coefficient_of_determination: 0.9930 - val_loss: 0.0315 - val_mean_absolute_error: 0.0315 - val_mean_squared_error: 0.0011 - val_root_mean_squared_error: 0.0328 - val_coefficient_of_determination: -0.7385
# Epoch 3/16
# 120/120 [==============================] - 9s 77ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - mean_squared_error: 2.2971e-04 - root_mean_squared_error: 0.0152 - coefficient_of_determination: 0.9936 - val_loss: 0.0117 - val_mean_absolute_error: 0.0117 - val_mean_squared_error: 1.8679e-04 - val_root_mean_squared_error: 0.0137 - val_coefficient_of_determination: 0.6929
# Epoch 4/16
# 120/120 [==============================] - 9s 79ms/step - loss: 0.0083 - mean_absolute_error: 0.0083 - mean_squared_error: 1.2458e-04 - root_mean_squared_error: 0.0112 - coefficient_of_determination: 0.9964 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104 - val_mean_squared_error: 1.5438e-04 - val_root_mean_squared_error: 0.0124 - val_coefficient_of_determination: 0.7771
# Epoch 5/16
# 120/120 [==============================] - 9s 78ms/step - loss: 0.0088 - mean_absolute_error: 0.0088 - mean_squared_error: 1.3783e-04 - root_mean_squared_error: 0.0117 - coefficient_of_determination: 0.9961 - val_loss: 0.0210 - val_mean_absolute_error: 0.0210 - val_mean_squared_error: 5.0020e-04 - val_root_mean_squared_error: 0.0224 - val_coefficient_of_determination: 0.2707
# Epoch 6/16
# 120/120 [==============================] - 9s 78ms/step - loss: 0.0098 - mean_absolute_error: 0.0098 - mean_squared_error: 1.7301e-04 - root_mean_squared_error: 0.0132 - coefficient_of_determination: 0.9951 - val_loss: 0.0079 - val_mean_absolute_error: 0.0079 - val_mean_squared_error: 9.6100e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.8453
# Epoch 7/16
# 120/120 [==============================] - 9s 76ms/step - loss: 0.0086 - mean_absolute_error: 0.0086 - mean_squared_error: 1.3353e-04 - root_mean_squared_error: 0.0116 - coefficient_of_determination: 0.9962 - val_loss: 0.0061 - val_mean_absolute_error: 0.0061 - val_mean_squared_error: 6.1499e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9031
# Epoch 8/16
# 120/120 [==============================] - 9s 74ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - mean_squared_error: 1.8928e-04 - root_mean_squared_error: 0.0138 - coefficient_of_determination: 0.9948 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060 - val_mean_squared_error: 6.0902e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9014
# Epoch 9/16
# 120/120 [==============================] - 9s 77ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - mean_squared_error: 9.6123e-05 - root_mean_squared_error: 0.0098 - coefficient_of_determination: 0.9972 - val_loss: 0.0125 - val_mean_absolute_error: 0.0125 - val_mean_squared_error: 2.0222e-04 - val_root_mean_squared_error: 0.0142 - val_coefficient_of_determination: 0.6736
# Epoch 10/16
# 120/120 [==============================] - 9s 79ms/step - loss: 0.0084 - mean_absolute_error: 0.0084 - mean_squared_error: 1.3190e-04 - root_mean_squared_error: 0.0115 - coefficient_of_determination: 0.9962 - val_loss: 0.0084 - val_mean_absolute_error: 0.0084 - val_mean_squared_error: 1.0940e-04 - val_root_mean_squared_error: 0.0105 - val_coefficient_of_determination: 0.8257
# Epoch 11/16
# 120/120 [==============================] - 9s 77ms/step - loss: 0.0065 - mean_absolute_error: 0.0065 - mean_squared_error: 8.2294e-05 - root_mean_squared_error: 0.0091 - coefficient_of_determination: 0.9976 - val_loss: 0.0086 - val_mean_absolute_error: 0.0086 - val_mean_squared_error: 1.1163e-04 - val_root_mean_squared_error: 0.0106 - val_coefficient_of_determination: 0.8195
# Epoch 12/16
# 120/120 [==============================] - 9s 76ms/step - loss: 0.0067 - mean_absolute_error: 0.0067 - mean_squared_error: 8.5937e-05 - root_mean_squared_error: 0.0093 - coefficient_of_determination: 0.9976 - val_loss: 0.0083 - val_mean_absolute_error: 0.0083 - val_mean_squared_error: 1.0598e-04 - val_root_mean_squared_error: 0.0103 - val_coefficient_of_determination: 0.8281
# Epoch 13/16
# 120/120 [==============================] - 9s 76ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - mean_squared_error: 9.2495e-05 - root_mean_squared_error: 0.0096 - coefficient_of_determination: 0.9973 - val_loss: 0.0084 - val_mean_absolute_error: 0.0084 - val_mean_squared_error: 1.0556e-04 - val_root_mean_squared_error: 0.0103 - val_coefficient_of_determination: 0.8401
# Epoch 14/16
# 120/120 [==============================] - 9s 75ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - mean_squared_error: 9.2551e-05 - root_mean_squared_error: 0.0096 - coefficient_of_determination: 0.9974 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 5.5607e-05 - val_root_mean_squared_error: 0.0075 - val_coefficient_of_determination: 0.9140
# Epoch 15/16
# 120/120 [==============================] - 9s 74ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - mean_squared_error: 9.4149e-05 - root_mean_squared_error: 0.0097 - coefficient_of_determination: 0.9970 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.5914e-05 - val_root_mean_squared_error: 0.0075 - val_coefficient_of_determination: 0.9123
# Epoch 16/16
# 120/120 [==============================] - 10s 79ms/step - loss: 0.0077 - mean_absolute_error: 0.0077 - mean_squared_error: 1.0730e-04 - root_mean_squared_error: 0.0104 - coefficient_of_determination: 0.9970 - val_loss: 0.0076 - val_mean_absolute_error: 0.0076 - val_mean_squared_error: 9.2018e-05 - val_root_mean_squared_error: 0.0096 - val_coefficient_of_determination: 0.8627
# Epoch 1/12
# 120/120 [==============================] - 10s 81ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - mean_squared_error: 6.0649e-05 - root_mean_squared_error: 0.0078 - coefficient_of_determination: 0.9983 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.4194e-05 - val_root_mean_squared_error: 0.0074 - val_coefficient_of_determination: 0.9124
# Epoch 2/12
# 120/120 [==============================] - 9s 79ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - mean_squared_error: 6.0312e-05 - root_mean_squared_error: 0.0078 - coefficient_of_determination: 0.9983 - val_loss: 0.0065 - val_mean_absolute_error: 0.0065 - val_mean_squared_error: 6.8244e-05 - val_root_mean_squared_error: 0.0083 - val_coefficient_of_determination: 0.8880
# Epoch 3/12
# 120/120 [==============================] - 9s 78ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - mean_squared_error: 5.9817e-05 - root_mean_squared_error: 0.0077 - coefficient_of_determination: 0.9983 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 5.4553e-05 - val_root_mean_squared_error: 0.0074 - val_coefficient_of_determination: 0.9144
# Epoch 4/12
# 120/120 [==============================] - 9s 76ms/step - loss: 0.0050 - mean_absolute_error: 0.0050 - mean_squared_error: 5.7643e-05 - root_mean_squared_error: 0.0076 - coefficient_of_determination: 0.9984 - val_loss: 0.0065 - val_mean_absolute_error: 0.0065 - val_mean_squared_error: 7.1055e-05 - val_root_mean_squared_error: 0.0084 - val_coefficient_of_determination: 0.8934
# Epoch 5/12
# 120/120 [==============================] - 9s 77ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - mean_squared_error: 5.9620e-05 - root_mean_squared_error: 0.0077 - coefficient_of_determination: 0.9983 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060 - val_mean_squared_error: 6.0922e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9073
# Epoch 6/12
# 120/120 [==============================] - 10s 80ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - mean_squared_error: 6.0665e-05 - root_mean_squared_error: 0.0078 - coefficient_of_determination: 0.9983 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 5.4046e-05 - val_root_mean_squared_error: 0.0074 - val_coefficient_of_determination: 0.9139
# Epoch 7/12
# 120/120 [==============================] - 9s 79ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - mean_squared_error: 5.9110e-05 - root_mean_squared_error: 0.0077 - coefficient_of_determination: 0.9983 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.5818e-05 - val_root_mean_squared_error: 0.0075 - val_coefficient_of_determination: 0.9095
# Epoch 8/12
# 120/120 [==============================] - 9s 79ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - mean_squared_error: 6.0588e-05 - root_mean_squared_error: 0.0078 - coefficient_of_determination: 0.9983 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 5.7839e-05 - val_root_mean_squared_error: 0.0076 - val_coefficient_of_determination: 0.9111
# Epoch 9/12
# 120/120 [==============================] - 10s 80ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - mean_squared_error: 5.9050e-05 - root_mean_squared_error: 0.0077 - coefficient_of_determination: 0.9983 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 5.3387e-05 - val_root_mean_squared_error: 0.0073 - val_coefficient_of_determination: 0.9165
# Epoch 10/12
# 120/120 [==============================] - 9s 78ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - mean_squared_error: 5.8743e-05 - root_mean_squared_error: 0.0077 - coefficient_of_determination: 0.9984 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 5.2237e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.9170
# Epoch 11/12
# 120/120 [==============================] - 10s 80ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - mean_squared_error: 5.8011e-05 - root_mean_squared_error: 0.0076 - coefficient_of_determination: 0.9983 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 5.2333e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.9164
# Epoch 12/12
# 120/120 [==============================] - 10s 83ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - mean_squared_error: 5.8604e-05 - root_mean_squared_error: 0.0077 - coefficient_of_determination: 0.9983 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.5672e-05 - val_root_mean_squared_error: 0.0075 - val_coefficient_of_determination: 0.9102
# Epoch 1/8
# 120/120 [==============================] - 10s 81ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - mean_squared_error: 5.6183e-05 - root_mean_squared_error: 0.0075 - coefficient_of_determination: 0.9984 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 5.2238e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.9179
# Epoch 2/8
# 120/120 [==============================] - 9s 76ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - mean_squared_error: 5.5524e-05 - root_mean_squared_error: 0.0075 - coefficient_of_determination: 0.9984 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 5.2447e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.9160
# Epoch 3/8
# 120/120 [==============================] - 9s 77ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - mean_squared_error: 5.5481e-05 - root_mean_squared_error: 0.0074 - coefficient_of_determination: 0.9984 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 5.2463e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.9176
# Epoch 4/8
# 120/120 [==============================] - 9s 77ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - mean_squared_error: 5.5633e-05 - root_mean_squared_error: 0.0075 - coefficient_of_determination: 0.9984 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 5.3424e-05 - val_root_mean_squared_error: 0.0073 - val_coefficient_of_determination: 0.9165
# Epoch 5/8
# 120/120 [==============================] - 10s 83ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - mean_squared_error: 5.5494e-05 - root_mean_squared_error: 0.0074 - coefficient_of_determination: 0.9984 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 5.2056e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.9176
# Epoch 6/8
# 120/120 [==============================] - 10s 83ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - mean_squared_error: 5.5330e-05 - root_mean_squared_error: 0.0074 - coefficient_of_determination: 0.9984 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 5.2107e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.9177
# Epoch 7/8
# 120/120 [==============================] - 10s 83ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - mean_squared_error: 5.5345e-05 - root_mean_squared_error: 0.0074 - coefficient_of_determination: 0.9984 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 5.1905e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.9178
# Epoch 8/8
# 120/120 [==============================] - 10s 83ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - mean_squared_error: 5.5291e-05 - root_mean_squared_error: 0.0074 - coefficient_of_determination: 0.9984 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 5.1739e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.9171

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 22ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted HSI Open Price ($)")
plt.plot(y_test, color='blue', label="Actual HSI Open Price ($)")
plt.title('HSI Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('HSI Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, numEpochsOne, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(numEpochsOne, numEpochsOne+numEpochsTwo, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(numEpochsOne+numEpochsTwo, numEpochsOne+numEpochsTwo+numEpochsThree, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, numEpochsOne+numEpochsTwo+numEpochsThree-1)
plt.xticks([2*i for i in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)], [(2*j)+1 for j in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, numEpochsOne, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(numEpochsOne, numEpochsOne+numEpochsTwo, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(numEpochsOne+numEpochsTwo, numEpochsOne+numEpochsTwo+numEpochsThree, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, numEpochsOne+numEpochsTwo+numEpochsThree-1)
plt.xticks([2*i for i in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)], [(2*j)+1 for j in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.004919675178825855
# Mean Squared Error (MSE): 5.529087866307236e-05
# Root Mean Squared Error (RMSE): 0.007435783743858337
# Coefficient of Determination (R2): 0.9984017014503479

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.0054946281015872955
# Validation Mean Squared Error (MSE): 5.173932731850073e-05
# Validation Root Mean Squared Error (RMSE): 0.007193005643785
# Validation Coefficient of Determination (R2): 0.9171306490898132

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 119 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $79890.27614800958
# Balance Percentage Change: 7.989027614800957%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $97911.12813486453
# Balance Percentage Change: 9.791112813486452%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $243825.75574595341
# Balance Percentage Change: 24.382575574595343%
# ----------------------------------------------------------------
