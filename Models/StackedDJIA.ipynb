# %% [markdown]
# # DJIA Price Prediction Stacked LSTM with Wavelet Transforms and an Attention Mechanism

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from attention import Attention
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/DJIA.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingData.shape[0]):
    X_train.append(trainingData[i-exposureSize:i])
    y_train.append(trainingData[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (4415, 365, 5)
# (4415,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(testInputsNormalised[i-exposureSize:i])
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (125, 365, 5)
# (125,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(50, return_sequences=True))
model.add(Attention(units=16))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./StackedDJIAModel.png', show_shapes=True)
# Out:
# 2022-08-17 17:32:28.657325: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 365, 50)           11200
#
#  lstm_1 (LSTM)               (None, 365, 50)           20200
#
#  attention (Attention)       (None, 16)                4100
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 35,517
# Trainable params: 35,517
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
numEpochsOne = 16
numEpochsTwo = 12
numEpochsThree = 8

historyOne = model.fit(X_train, y_train, epochs=numEpochsOne, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=numEpochsTwo, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=numEpochsThree, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 2022-08-17 17:32:32.380715: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 138/138 [==============================] - ETA: 0s - loss: 0.0427 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0109 - root_mean_squared_error: 0.1044 - coefficient_of_determination: 0.7333
# 2022-08-17 17:32:56.621886: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 138/138 [==============================] - 27s 172ms/step - loss: 0.0427 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0109 - root_mean_squared_error: 0.1044 - coefficient_of_determination: 0.7333 - val_loss: 0.0833 - val_mean_absolute_error: 0.0833 - val_mean_squared_error: 0.0071 - val_root_mean_squared_error: 0.0844 - val_coefficient_of_determination: -22.3198
# Epoch 2/16
# 138/138 [==============================] - 24s 174ms/step - loss: 0.0173 - mean_absolute_error: 0.0173 - mean_squared_error: 6.6360e-04 - root_mean_squared_error: 0.0258 - coefficient_of_determination: 0.9857 - val_loss: 0.0830 - val_mean_absolute_error: 0.0830 - val_mean_squared_error: 0.0070 - val_root_mean_squared_error: 0.0839 - val_coefficient_of_determination: -22.4584
# Epoch 3/16
# 138/138 [==============================] - 25s 180ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - mean_squared_error: 2.7515e-04 - root_mean_squared_error: 0.0166 - coefficient_of_determination: 0.9943 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417 - val_mean_squared_error: 0.0018 - val_root_mean_squared_error: 0.0430 - val_coefficient_of_determination: -5.2037
# Epoch 4/16
# 138/138 [==============================] - 25s 181ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - mean_squared_error: 2.7055e-04 - root_mean_squared_error: 0.0164 - coefficient_of_determination: 0.9946 - val_loss: 0.0855 - val_mean_absolute_error: 0.0855 - val_mean_squared_error: 0.0074 - val_root_mean_squared_error: 0.0861 - val_coefficient_of_determination: -22.7359
# Epoch 5/16
# 138/138 [==============================] - 25s 182ms/step - loss: 0.0129 - mean_absolute_error: 0.0129 - mean_squared_error: 3.3233e-04 - root_mean_squared_error: 0.0182 - coefficient_of_determination: 0.9930 - val_loss: 0.0177 - val_mean_absolute_error: 0.0177 - val_mean_squared_error: 3.7898e-04 - val_root_mean_squared_error: 0.0195 - val_coefficient_of_determination: -0.2648
# Epoch 6/16
# 138/138 [==============================] - 27s 197ms/step - loss: 0.0092 - mean_absolute_error: 0.0092 - mean_squared_error: 1.9864e-04 - root_mean_squared_error: 0.0141 - coefficient_of_determination: 0.9956 - val_loss: 0.0065 - val_mean_absolute_error: 0.0065 - val_mean_squared_error: 6.9195e-05 - val_root_mean_squared_error: 0.0083 - val_coefficient_of_determination: 0.7893
# Epoch 7/16
# 138/138 [==============================] - 26s 188ms/step - loss: 0.0091 - mean_absolute_error: 0.0091 - mean_squared_error: 1.7949e-04 - root_mean_squared_error: 0.0134 - coefficient_of_determination: 0.9962 - val_loss: 0.0131 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 2.1479e-04 - val_root_mean_squared_error: 0.0147 - val_coefficient_of_determination: 0.3606
# Epoch 8/16
# 138/138 [==============================] - 26s 189ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - mean_squared_error: 1.2333e-04 - root_mean_squared_error: 0.0111 - coefficient_of_determination: 0.9974 - val_loss: 0.0090 - val_mean_absolute_error: 0.0090 - val_mean_squared_error: 1.1397e-04 - val_root_mean_squared_error: 0.0107 - val_coefficient_of_determination: 0.6525
# Epoch 9/16
# 138/138 [==============================] - 27s 194ms/step - loss: 0.0100 - mean_absolute_error: 0.0100 - mean_squared_error: 2.1872e-04 - root_mean_squared_error: 0.0148 - coefficient_of_determination: 0.9954 - val_loss: 0.0169 - val_mean_absolute_error: 0.0169 - val_mean_squared_error: 3.2197e-04 - val_root_mean_squared_error: 0.0179 - val_coefficient_of_determination: -0.0311
# Epoch 10/16
# 138/138 [==============================] - 27s 198ms/step - loss: 0.0069 - mean_absolute_error: 0.0069 - mean_squared_error: 1.0895e-04 - root_mean_squared_error: 0.0104 - coefficient_of_determination: 0.9977 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 5.0574e-05 - val_root_mean_squared_error: 0.0071 - val_coefficient_of_determination: 0.8544
# Epoch 11/16
# 138/138 [==============================] - 26s 190ms/step - loss: 0.0068 - mean_absolute_error: 0.0068 - mean_squared_error: 1.0014e-04 - root_mean_squared_error: 0.0100 - coefficient_of_determination: 0.9980 - val_loss: 0.0061 - val_mean_absolute_error: 0.0061 - val_mean_squared_error: 6.5409e-05 - val_root_mean_squared_error: 0.0081 - val_coefficient_of_determination: 0.8260
# Epoch 12/16
# 138/138 [==============================] - 27s 197ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - mean_squared_error: 1.2939e-04 - root_mean_squared_error: 0.0114 - coefficient_of_determination: 0.9971 - val_loss: 0.0293 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 8.9955e-04 - val_root_mean_squared_error: 0.0300 - val_coefficient_of_determination: -1.7373
# Epoch 13/16
# 138/138 [==============================] - 28s 202ms/step - loss: 0.0087 - mean_absolute_error: 0.0087 - mean_squared_error: 1.7428e-04 - root_mean_squared_error: 0.0132 - coefficient_of_determination: 0.9962 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054 - val_mean_squared_error: 4.6446e-05 - val_root_mean_squared_error: 0.0068 - val_coefficient_of_determination: 0.8744
# Epoch 14/16
# 138/138 [==============================] - 28s 204ms/step - loss: 0.0063 - mean_absolute_error: 0.0063 - mean_squared_error: 7.9762e-05 - root_mean_squared_error: 0.0089 - coefficient_of_determination: 0.9984 - val_loss: 0.0453 - val_mean_absolute_error: 0.0453 - val_mean_squared_error: 0.0021 - val_root_mean_squared_error: 0.0460 - val_coefficient_of_determination: -5.9484
# Epoch 15/16
# 138/138 [==============================] - 26s 189ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - mean_squared_error: 1.0809e-04 - root_mean_squared_error: 0.0104 - coefficient_of_determination: 0.9977 - val_loss: 0.0124 - val_mean_absolute_error: 0.0124 - val_mean_squared_error: 2.0650e-04 - val_root_mean_squared_error: 0.0144 - val_coefficient_of_determination: 0.3228
# Epoch 16/16
# 138/138 [==============================] - 28s 204ms/step - loss: 0.0068 - mean_absolute_error: 0.0068 - mean_squared_error: 9.8829e-05 - root_mean_squared_error: 0.0099 - coefficient_of_determination: 0.9979 - val_loss: 0.0119 - val_mean_absolute_error: 0.0119 - val_mean_squared_error: 1.9233e-04 - val_root_mean_squared_error: 0.0139 - val_coefficient_of_determination: 0.3714
# Epoch 1/12
# 138/138 [==============================] - 27s 198ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 4.2743e-06 - root_mean_squared_error: 0.0021 - coefficient_of_determination: 0.9999 - val_loss: 0.0070 - val_mean_absolute_error: 0.0070 - val_mean_squared_error: 8.1874e-05 - val_root_mean_squared_error: 0.0090 - val_coefficient_of_determination: 0.7542
# Epoch 2/12
# 138/138 [==============================] - 28s 207ms/step - loss: 9.2179e-04 - mean_absolute_error: 9.2179e-04 - mean_squared_error: 2.8438e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0071 - val_mean_absolute_error: 0.0071 - val_mean_squared_error: 8.4227e-05 - val_root_mean_squared_error: 0.0092 - val_coefficient_of_determination: 0.7485
# Epoch 3/12
# 138/138 [==============================] - 28s 202ms/step - loss: 9.3039e-04 - mean_absolute_error: 9.3039e-04 - mean_squared_error: 2.7495e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0075 - val_mean_absolute_error: 0.0075 - val_mean_squared_error: 9.0771e-05 - val_root_mean_squared_error: 0.0095 - val_coefficient_of_determination: 0.7299
# Epoch 4/12
# 138/138 [==============================] - 26s 191ms/step - loss: 8.7304e-04 - mean_absolute_error: 8.7304e-04 - mean_squared_error: 2.3319e-06 - root_mean_squared_error: 0.0015 - coefficient_of_determination: 1.0000 - val_loss: 0.0086 - val_mean_absolute_error: 0.0086 - val_mean_squared_error: 1.1101e-04 - val_root_mean_squared_error: 0.0105 - val_coefficient_of_determination: 0.6672
# Epoch 5/12
# 138/138 [==============================] - 28s 202ms/step - loss: 9.4800e-04 - mean_absolute_error: 9.4800e-04 - mean_squared_error: 2.8672e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0085 - val_mean_absolute_error: 0.0085 - val_mean_squared_error: 1.0958e-04 - val_root_mean_squared_error: 0.0105 - val_coefficient_of_determination: 0.6761
# Epoch 6/12
# 138/138 [==============================] - 29s 207ms/step - loss: 9.4684e-04 - mean_absolute_error: 9.4684e-04 - mean_squared_error: 2.6567e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 0.9999 - val_loss: 0.0074 - val_mean_absolute_error: 0.0074 - val_mean_squared_error: 8.9432e-05 - val_root_mean_squared_error: 0.0095 - val_coefficient_of_determination: 0.7379
# Epoch 7/12
# 138/138 [==============================] - 28s 206ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 2.8779e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0078 - val_mean_absolute_error: 0.0078 - val_mean_squared_error: 9.7254e-05 - val_root_mean_squared_error: 0.0099 - val_coefficient_of_determination: 0.7179
# Epoch 8/12
# 138/138 [==============================] - 28s 199ms/step - loss: 7.8302e-04 - mean_absolute_error: 7.8302e-04 - mean_squared_error: 2.0784e-06 - root_mean_squared_error: 0.0014 - coefficient_of_determination: 1.0000 - val_loss: 0.0079 - val_mean_absolute_error: 0.0079 - val_mean_squared_error: 9.8704e-05 - val_root_mean_squared_error: 0.0099 - val_coefficient_of_determination: 0.7164
# Epoch 9/12
# 138/138 [==============================] - 28s 202ms/step - loss: 9.2399e-04 - mean_absolute_error: 9.2399e-04 - mean_squared_error: 2.3750e-06 - root_mean_squared_error: 0.0015 - coefficient_of_determination: 1.0000 - val_loss: 0.0093 - val_mean_absolute_error: 0.0093 - val_mean_squared_error: 1.2740e-04 - val_root_mean_squared_error: 0.0113 - val_coefficient_of_determination: 0.6270
# Epoch 10/12
# 138/138 [==============================] - 28s 201ms/step - loss: 9.6435e-04 - mean_absolute_error: 9.6435e-04 - mean_squared_error: 2.5923e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 0.9999 - val_loss: 0.0077 - val_mean_absolute_error: 0.0077 - val_mean_squared_error: 9.6642e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.7265
# Epoch 11/12
# 138/138 [==============================] - 29s 208ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.2146e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0096 - val_mean_absolute_error: 0.0096 - val_mean_squared_error: 1.3695e-04 - val_root_mean_squared_error: 0.0117 - val_coefficient_of_determination: 0.6023
# Epoch 12/12
# 138/138 [==============================] - 29s 210ms/step - loss: 9.1690e-04 - mean_absolute_error: 9.1690e-04 - mean_squared_error: 2.2491e-06 - root_mean_squared_error: 0.0015 - coefficient_of_determination: 1.0000 - val_loss: 0.0091 - val_mean_absolute_error: 0.0091 - val_mean_squared_error: 1.2590e-04 - val_root_mean_squared_error: 0.0112 - val_coefficient_of_determination: 0.6387
# Epoch 1/8
# 138/138 [==============================] - 27s 196ms/step - loss: 6.8788e-04 - mean_absolute_error: 6.8788e-04 - mean_squared_error: 1.6813e-06 - root_mean_squared_error: 0.0013 - coefficient_of_determination: 1.0000 - val_loss: 0.0080 - val_mean_absolute_error: 0.0080 - val_mean_squared_error: 1.0325e-04 - val_root_mean_squared_error: 0.0102 - val_coefficient_of_determination: 0.7099
# Epoch 2/8
# 138/138 [==============================] - 28s 201ms/step - loss: 6.2111e-04 - mean_absolute_error: 6.2111e-04 - mean_squared_error: 1.4697e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0082 - val_mean_absolute_error: 0.0082 - val_mean_squared_error: 1.0606e-04 - val_root_mean_squared_error: 0.0103 - val_coefficient_of_determination: 0.7019
# Epoch 3/8
# 138/138 [==============================] - 28s 200ms/step - loss: 6.2399e-04 - mean_absolute_error: 6.2399e-04 - mean_squared_error: 1.4629e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0082 - val_mean_absolute_error: 0.0082 - val_mean_squared_error: 1.0603e-04 - val_root_mean_squared_error: 0.0103 - val_coefficient_of_determination: 0.7022
# Epoch 4/8
# 138/138 [==============================] - 28s 200ms/step - loss: 6.1939e-04 - mean_absolute_error: 6.1939e-04 - mean_squared_error: 1.4587e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0083 - val_mean_absolute_error: 0.0083 - val_mean_squared_error: 1.0763e-04 - val_root_mean_squared_error: 0.0104 - val_coefficient_of_determination: 0.6981
# Epoch 5/8
# 138/138 [==============================] - 29s 211ms/step - loss: 6.2260e-04 - mean_absolute_error: 6.2260e-04 - mean_squared_error: 1.4595e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0083 - val_mean_absolute_error: 0.0083 - val_mean_squared_error: 1.0820e-04 - val_root_mean_squared_error: 0.0104 - val_coefficient_of_determination: 0.6965
# Epoch 6/8
# 138/138 [==============================] - 28s 202ms/step - loss: 6.2357e-04 - mean_absolute_error: 6.2357e-04 - mean_squared_error: 1.4436e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0081 - val_mean_absolute_error: 0.0081 - val_mean_squared_error: 1.0414e-04 - val_root_mean_squared_error: 0.0102 - val_coefficient_of_determination: 0.7093
# Epoch 7/8
# 138/138 [==============================] - 27s 198ms/step - loss: 6.3440e-04 - mean_absolute_error: 6.3440e-04 - mean_squared_error: 1.4689e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0080 - val_mean_absolute_error: 0.0080 - val_mean_squared_error: 1.0310e-04 - val_root_mean_squared_error: 0.0102 - val_coefficient_of_determination: 0.7130
# Epoch 8/8
# 138/138 [==============================] - 30s 216ms/step - loss: 6.1889e-04 - mean_absolute_error: 6.1889e-04 - mean_squared_error: 1.4477e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0084 - val_mean_absolute_error: 0.0084 - val_mean_squared_error: 1.0923e-04 - val_root_mean_squared_error: 0.0105 - val_coefficient_of_determination: 0.6958

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 2022-08-17 17:48:53.872222: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 4/4 [==============================] - 1s 61ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted DJIA Open Price ($)")
plt.plot(y_test, color='blue', label="Actual DJIA Open Price ($)")
plt.title('DJIA Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('DJIA Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, numEpochsOne, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(numEpochsOne, numEpochsOne+numEpochsTwo, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(numEpochsOne+numEpochsTwo, numEpochsOne+numEpochsTwo+numEpochsThree, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, numEpochsOne+numEpochsTwo+numEpochsThree-1)
plt.xticks([2*i for i in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)], [(2*j)+1 for j in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, numEpochsOne, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(numEpochsOne, numEpochsOne+numEpochsTwo, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(numEpochsOne+numEpochsTwo, numEpochsOne+numEpochsTwo+numEpochsThree, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, numEpochsOne+numEpochsTwo+numEpochsThree-1)
plt.xticks([2*i for i in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)], [(2*j)+1 for j in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.0006188917905092239
# Mean Squared Error (MSE): 1.447709678359388e-06
# Root Mean Squared Error (RMSE): 0.0012032081140205264
# Coefficient of Determination (R2): 0.9999697208404541

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.00836174376308918
# Validation Mean Squared Error (MSE): 0.00010922942601609975
# Validation Root Mean Squared Error (RMSE): 0.01045128796249628
# Validation Coefficient of Determination (R2): 0.695755660533905

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 125 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $90519.93294729199
# Balance Percentage Change: 9.051993294729199%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $162509.80005976406
# Balance Percentage Change: 16.250980005976405%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $253189.24210693408
# Balance Percentage Change: 25.318924210693407%
# ----------------------------------------------------------------
