# %% [markdown]
# # S&P 500 Price Prediction LSTM with Wavelet Transforms

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/S&P500.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingData.shape[0]):
    X_train.append(trainingData[i-exposureSize:i])
    y_train.append(trainingData[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (4415, 365, 5)
# (4415,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(testInputsNormalised[i-exposureSize:i])
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (125, 365, 5)
# (125,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./WaveletSP500Model.png', show_shapes=True)
# Out:
# 2022-08-17 14:47:30.664058: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                11200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 11,251
# Trainable params: 11,251
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
historyOne = model.fit(X_train, y_train, epochs=16, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=12, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=8, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 138/138 [==============================] - 13s 82ms/step - loss: 0.0183 - mean_absolute_error: 0.0183 - mean_squared_error: 0.0031 - root_mean_squared_error: 0.0561 - coefficient_of_determination: 0.9398 - val_loss: 0.0118 - val_mean_absolute_error: 0.0118 - val_mean_squared_error: 2.0150e-04 - val_root_mean_squared_error: 0.0142 - val_coefficient_of_determination: 0.3897
# Epoch 2/16
# 138/138 [==============================] - 10s 75ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - mean_squared_error: 1.1742e-04 - root_mean_squared_error: 0.0108 - coefficient_of_determination: 0.9977 - val_loss: 0.0071 - val_mean_absolute_error: 0.0071 - val_mean_squared_error: 7.9266e-05 - val_root_mean_squared_error: 0.0089 - val_coefficient_of_determination: 0.7959
# Epoch 3/16
# 138/138 [==============================] - 10s 75ms/step - loss: 0.0084 - mean_absolute_error: 0.0084 - mean_squared_error: 1.3173e-04 - root_mean_squared_error: 0.0115 - coefficient_of_determination: 0.9974 - val_loss: 0.0064 - val_mean_absolute_error: 0.0064 - val_mean_squared_error: 6.3216e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.8348
# Epoch 4/16
# 138/138 [==============================] - 10s 74ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - mean_squared_error: 1.0518e-04 - root_mean_squared_error: 0.0103 - coefficient_of_determination: 0.9980 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054 - val_mean_squared_error: 4.7174e-05 - val_root_mean_squared_error: 0.0069 - val_coefficient_of_determination: 0.8811
# Epoch 5/16
# 138/138 [==============================] - 10s 75ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - mean_squared_error: 1.1914e-04 - root_mean_squared_error: 0.0109 - coefficient_of_determination: 0.9976 - val_loss: 0.0123 - val_mean_absolute_error: 0.0123 - val_mean_squared_error: 1.9121e-04 - val_root_mean_squared_error: 0.0138 - val_coefficient_of_determination: 0.4799
# Epoch 6/16
# 138/138 [==============================] - 10s 75ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - mean_squared_error: 1.3198e-04 - root_mean_squared_error: 0.0115 - coefficient_of_determination: 0.9974 - val_loss: 0.0280 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 8.2730e-04 - val_root_mean_squared_error: 0.0288 - val_coefficient_of_determination: -1.4671
# Epoch 7/16
# 138/138 [==============================] - 10s 75ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - mean_squared_error: 5.4923e-05 - root_mean_squared_error: 0.0074 - coefficient_of_determination: 0.9990 - val_loss: 0.0116 - val_mean_absolute_error: 0.0116 - val_mean_squared_error: 1.7002e-04 - val_root_mean_squared_error: 0.0130 - val_coefficient_of_determination: 0.5181
# Epoch 8/16
# 138/138 [==============================] - 20s 143ms/step - loss: 0.0057 - mean_absolute_error: 0.0057 - mean_squared_error: 5.7261e-05 - root_mean_squared_error: 0.0076 - coefficient_of_determination: 0.9989 - val_loss: 0.0149 - val_mean_absolute_error: 0.0149 - val_mean_squared_error: 2.5887e-04 - val_root_mean_squared_error: 0.0161 - val_coefficient_of_determination: 0.2616
# Epoch 9/16
# 138/138 [==============================] - 15s 112ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 6.1770e-05 - root_mean_squared_error: 0.0079 - coefficient_of_determination: 0.9987 - val_loss: 0.0111 - val_mean_absolute_error: 0.0111 - val_mean_squared_error: 1.5665e-04 - val_root_mean_squared_error: 0.0125 - val_coefficient_of_determination: 0.5597
# Epoch 10/16
# 138/138 [==============================] - 12s 91ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - mean_squared_error: 6.1117e-05 - root_mean_squared_error: 0.0078 - coefficient_of_determination: 0.9988 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060 - val_mean_squared_error: 5.1534e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.8687
# Epoch 11/16
# 138/138 [==============================] - 12s 86ms/step - loss: 0.0041 - mean_absolute_error: 0.0041 - mean_squared_error: 3.2637e-05 - root_mean_squared_error: 0.0057 - coefficient_of_determination: 0.9994 - val_loss: 0.0103 - val_mean_absolute_error: 0.0103 - val_mean_squared_error: 1.4231e-04 - val_root_mean_squared_error: 0.0119 - val_coefficient_of_determination: 0.6083
# Epoch 12/16
# 138/138 [==============================] - 15s 108ms/step - loss: 0.0060 - mean_absolute_error: 0.0060 - mean_squared_error: 7.8860e-05 - root_mean_squared_error: 0.0089 - coefficient_of_determination: 0.9985 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 4.8351e-05 - val_root_mean_squared_error: 0.0070 - val_coefficient_of_determination: 0.8714
# Epoch 13/16
# 138/138 [==============================] - 21s 155ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - mean_squared_error: 4.4962e-05 - root_mean_squared_error: 0.0067 - coefficient_of_determination: 0.9991 - val_loss: 0.0180 - val_mean_absolute_error: 0.0180 - val_mean_squared_error: 3.7611e-04 - val_root_mean_squared_error: 0.0194 - val_coefficient_of_determination: -0.0849
# Epoch 14/16
# 138/138 [==============================] - 14s 101ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 6.4985e-05 - root_mean_squared_error: 0.0081 - coefficient_of_determination: 0.9987 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104 - val_mean_squared_error: 1.5616e-04 - val_root_mean_squared_error: 0.0125 - val_coefficient_of_determination: 0.5291
# Epoch 15/16
# 138/138 [==============================] - 12s 87ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - mean_squared_error: 2.7228e-05 - root_mean_squared_error: 0.0052 - coefficient_of_determination: 0.9995 - val_loss: 0.0159 - val_mean_absolute_error: 0.0159 - val_mean_squared_error: 3.1508e-04 - val_root_mean_squared_error: 0.0178 - val_coefficient_of_determination: 0.0501
# Epoch 16/16
# 138/138 [==============================] - 12s 88ms/step - loss: 0.0047 - mean_absolute_error: 0.0047 - mean_squared_error: 4.8515e-05 - root_mean_squared_error: 0.0070 - coefficient_of_determination: 0.9990 - val_loss: 0.0219 - val_mean_absolute_error: 0.0219 - val_mean_squared_error: 5.4873e-04 - val_root_mean_squared_error: 0.0234 - val_coefficient_of_determination: -0.6720
# Epoch 1/12
# 138/138 [==============================] - 15s 111ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 5.6016e-06 - root_mean_squared_error: 0.0024 - coefficient_of_determination: 0.9999 - val_loss: 0.0070 - val_mean_absolute_error: 0.0070 - val_mean_squared_error: 7.2303e-05 - val_root_mean_squared_error: 0.0085 - val_coefficient_of_determination: 0.8160
# Epoch 2/12
# 138/138 [==============================] - 20s 143ms/step - loss: 6.3429e-04 - mean_absolute_error: 6.3429e-04 - mean_squared_error: 1.6201e-06 - root_mean_squared_error: 0.0013 - coefficient_of_determination: 1.0000 - val_loss: 0.0070 - val_mean_absolute_error: 0.0070 - val_mean_squared_error: 7.2465e-05 - val_root_mean_squared_error: 0.0085 - val_coefficient_of_determination: 0.8135
# Epoch 3/12
# 138/138 [==============================] - 13s 97ms/step - loss: 6.9722e-04 - mean_absolute_error: 6.9722e-04 - mean_squared_error: 1.6586e-06 - root_mean_squared_error: 0.0013 - coefficient_of_determination: 1.0000 - val_loss: 0.0071 - val_mean_absolute_error: 0.0071 - val_mean_squared_error: 7.6548e-05 - val_root_mean_squared_error: 0.0087 - val_coefficient_of_determination: 0.7997
# Epoch 4/12
# 138/138 [==============================] - 12s 89ms/step - loss: 6.2739e-04 - mean_absolute_error: 6.2739e-04 - mean_squared_error: 1.4953e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0072 - val_mean_absolute_error: 0.0072 - val_mean_squared_error: 7.7517e-05 - val_root_mean_squared_error: 0.0088 - val_coefficient_of_determination: 0.7999
# Epoch 5/12
# 138/138 [==============================] - 12s 88ms/step - loss: 6.8613e-04 - mean_absolute_error: 6.8613e-04 - mean_squared_error: 1.5748e-06 - root_mean_squared_error: 0.0013 - coefficient_of_determination: 1.0000 - val_loss: 0.0073 - val_mean_absolute_error: 0.0073 - val_mean_squared_error: 7.8452e-05 - val_root_mean_squared_error: 0.0089 - val_coefficient_of_determination: 0.7978
# Epoch 6/12
# 138/138 [==============================] - 12s 90ms/step - loss: 6.6918e-04 - mean_absolute_error: 6.6918e-04 - mean_squared_error: 1.5055e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0074 - val_mean_absolute_error: 0.0074 - val_mean_squared_error: 8.0667e-05 - val_root_mean_squared_error: 0.0090 - val_coefficient_of_determination: 0.7942
# Epoch 7/12
# 138/138 [==============================] - 13s 91ms/step - loss: 6.2738e-04 - mean_absolute_error: 6.2738e-04 - mean_squared_error: 1.4073e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0073 - val_mean_absolute_error: 0.0073 - val_mean_squared_error: 8.0271e-05 - val_root_mean_squared_error: 0.0090 - val_coefficient_of_determination: 0.7925
# Epoch 8/12
# 138/138 [==============================] - 21s 156ms/step - loss: 5.9185e-04 - mean_absolute_error: 5.9185e-04 - mean_squared_error: 1.3606e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0075 - val_mean_absolute_error: 0.0075 - val_mean_squared_error: 8.4438e-05 - val_root_mean_squared_error: 0.0092 - val_coefficient_of_determination: 0.7858
# Epoch 9/12
# 138/138 [==============================] - 14s 99ms/step - loss: 6.0407e-04 - mean_absolute_error: 6.0407e-04 - mean_squared_error: 1.3174e-06 - root_mean_squared_error: 0.0011 - coefficient_of_determination: 1.0000 - val_loss: 0.0073 - val_mean_absolute_error: 0.0073 - val_mean_squared_error: 8.0054e-05 - val_root_mean_squared_error: 0.0089 - val_coefficient_of_determination: 0.7959
# Epoch 10/12
# 138/138 [==============================] - 12s 89ms/step - loss: 6.0289e-04 - mean_absolute_error: 6.0289e-04 - mean_squared_error: 1.3200e-06 - root_mean_squared_error: 0.0011 - coefficient_of_determination: 1.0000 - val_loss: 0.0073 - val_mean_absolute_error: 0.0073 - val_mean_squared_error: 7.9470e-05 - val_root_mean_squared_error: 0.0089 - val_coefficient_of_determination: 0.7987
# Epoch 11/12
# 138/138 [==============================] - 21s 152ms/step - loss: 6.0718e-04 - mean_absolute_error: 6.0718e-04 - mean_squared_error: 1.3348e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0073 - val_mean_absolute_error: 0.0073 - val_mean_squared_error: 7.9001e-05 - val_root_mean_squared_error: 0.0089 - val_coefficient_of_determination: 0.7989
# Epoch 12/12
# 138/138 [==============================] - 14s 98ms/step - loss: 6.3304e-04 - mean_absolute_error: 6.3304e-04 - mean_squared_error: 1.3782e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0073 - val_mean_absolute_error: 0.0073 - val_mean_squared_error: 7.9383e-05 - val_root_mean_squared_error: 0.0089 - val_coefficient_of_determination: 0.7993
# Epoch 1/8
# 138/138 [==============================] - 12s 87ms/step - loss: 5.2599e-04 - mean_absolute_error: 5.2599e-04 - mean_squared_error: 1.1499e-06 - root_mean_squared_error: 0.0011 - coefficient_of_determination: 1.0000 - val_loss: 0.0072 - val_mean_absolute_error: 0.0072 - val_mean_squared_error: 7.7811e-05 - val_root_mean_squared_error: 0.0088 - val_coefficient_of_determination: 0.8014
# Epoch 2/8
# 138/138 [==============================] - 12s 86ms/step - loss: 5.1553e-04 - mean_absolute_error: 5.1553e-04 - mean_squared_error: 1.1304e-06 - root_mean_squared_error: 0.0011 - coefficient_of_determination: 1.0000 - val_loss: 0.0072 - val_mean_absolute_error: 0.0072 - val_mean_squared_error: 7.8511e-05 - val_root_mean_squared_error: 0.0089 - val_coefficient_of_determination: 0.8013
# Epoch 3/8
# 138/138 [==============================] - 12s 88ms/step - loss: 5.1601e-04 - mean_absolute_error: 5.1601e-04 - mean_squared_error: 1.1336e-06 - root_mean_squared_error: 0.0011 - coefficient_of_determination: 1.0000 - val_loss: 0.0072 - val_mean_absolute_error: 0.0072 - val_mean_squared_error: 7.7723e-05 - val_root_mean_squared_error: 0.0088 - val_coefficient_of_determination: 0.8023
# Epoch 4/8
# 138/138 [==============================] - 13s 91ms/step - loss: 5.0979e-04 - mean_absolute_error: 5.0979e-04 - mean_squared_error: 1.1243e-06 - root_mean_squared_error: 0.0011 - coefficient_of_determination: 1.0000 - val_loss: 0.0072 - val_mean_absolute_error: 0.0072 - val_mean_squared_error: 7.7615e-05 - val_root_mean_squared_error: 0.0088 - val_coefficient_of_determination: 0.8025
# Epoch 5/8
# 138/138 [==============================] - 13s 96ms/step - loss: 5.0564e-04 - mean_absolute_error: 5.0564e-04 - mean_squared_error: 1.1191e-06 - root_mean_squared_error: 0.0011 - coefficient_of_determination: 1.0000 - val_loss: 0.0072 - val_mean_absolute_error: 0.0072 - val_mean_squared_error: 7.7709e-05 - val_root_mean_squared_error: 0.0088 - val_coefficient_of_determination: 0.8019
# Epoch 6/8
# 138/138 [==============================] - 13s 94ms/step - loss: 5.1126e-04 - mean_absolute_error: 5.1126e-04 - mean_squared_error: 1.1144e-06 - root_mean_squared_error: 0.0011 - coefficient_of_determination: 1.0000 - val_loss: 0.0072 - val_mean_absolute_error: 0.0072 - val_mean_squared_error: 7.7653e-05 - val_root_mean_squared_error: 0.0088 - val_coefficient_of_determination: 0.8023
# Epoch 7/8
# 138/138 [==============================] - 13s 92ms/step - loss: 5.1702e-04 - mean_absolute_error: 5.1702e-04 - mean_squared_error: 1.1084e-06 - root_mean_squared_error: 0.0011 - coefficient_of_determination: 1.0000 - val_loss: 0.0072 - val_mean_absolute_error: 0.0072 - val_mean_squared_error: 7.7796e-05 - val_root_mean_squared_error: 0.0088 - val_coefficient_of_determination: 0.8014
# Epoch 8/8
# 138/138 [==============================] - 13s 92ms/step - loss: 5.1823e-04 - mean_absolute_error: 5.1823e-04 - mean_squared_error: 1.1221e-06 - root_mean_squared_error: 0.0011 - coefficient_of_determination: 1.0000 - val_loss: 0.0072 - val_mean_absolute_error: 0.0072 - val_mean_squared_error: 7.7657e-05 - val_root_mean_squared_error: 0.0088 - val_coefficient_of_determination: 0.8035

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 4/4 [==============================] - 1s 21ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted S&P 500 Open Price ($)")
plt.plot(y_test, color='blue', label="Actual S&P 500 Open Price ($)")
plt.title('S&P 500 Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('S&P 500 Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.0005182289169169962
# Mean Squared Error (MSE): 1.1221278555240133e-06
# Root Mean Squared Error (RMSE): 0.0010593053884804249
# Coefficient of Determination (R2): 0.9999767541885376

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.007189846597611904
# Validation Mean Squared Error (MSE): 7.76573724579066e-05
# Validation Root Mean Squared Error (RMSE): 0.008812341839075089
# Validation Coefficient of Determination (R2): 0.8035218119621277

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 125 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $110632.80760443909
# Balance Percentage Change: 11.06328076044391%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $19961967.84708542
# Balance Percentage Change: 19.96196784708542%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $263864.81729653967
# Balance Percentage Change: 26.386481729653966%
# ----------------------------------------------------------------
