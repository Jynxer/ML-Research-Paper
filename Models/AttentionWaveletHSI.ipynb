# %% [markdown]
# # HSI Price Prediction LSTM with Wavelet Transforms and an Attention Mechanism

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from attention import Attention
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/HSI.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingData.shape[0]):
    X_train.append(trainingData[i-exposureSize:i])
    y_train.append(trainingData[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (3821, 365, 5)
# (3821,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(testInputsNormalised[i-exposureSize:i])
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (119, 365, 5)
# (119,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(Attention(units=16))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./AttentionWaveletHSIModel.png', show_shapes=True)
# Out:
# 2022-08-17 16:50:03.518005: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 365, 50)           11200
#
#  attention (Attention)       (None, 16)                4100
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 15,317
# Trainable params: 15,317
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
historyOne = model.fit(X_train, y_train, epochs=16, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=12, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=8, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 2022-08-17 16:50:06.108982: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 120/120 [==============================] - ETA: 0s - loss: 0.0545 - mean_absolute_error: 0.0545 - mean_squared_error: 0.0244 - root_mean_squared_error: 0.1562 - coefficient_of_determination: 0.3823
# 2022-08-17 16:50:18.657646: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 120/120 [==============================] - 14s 101ms/step - loss: 0.0545 - mean_absolute_error: 0.0545 - mean_squared_error: 0.0244 - root_mean_squared_error: 0.1562 - coefficient_of_determination: 0.3823 - val_loss: 0.0244 - val_mean_absolute_error: 0.0244 - val_mean_squared_error: 7.6347e-04 - val_root_mean_squared_error: 0.0276 - val_coefficient_of_determination: -0.2321
# Epoch 2/16
# 120/120 [==============================] - 11s 92ms/step - loss: 0.0143 - mean_absolute_error: 0.0143 - mean_squared_error: 3.6004e-04 - root_mean_squared_error: 0.0190 - coefficient_of_determination: 0.9897 - val_loss: 0.0128 - val_mean_absolute_error: 0.0128 - val_mean_squared_error: 2.4258e-04 - val_root_mean_squared_error: 0.0156 - val_coefficient_of_determination: 0.5794
# Epoch 3/16
# 120/120 [==============================] - 11s 94ms/step - loss: 0.0184 - mean_absolute_error: 0.0184 - mean_squared_error: 6.0533e-04 - root_mean_squared_error: 0.0246 - coefficient_of_determination: 0.9829 - val_loss: 0.0096 - val_mean_absolute_error: 0.0096 - val_mean_squared_error: 1.4804e-04 - val_root_mean_squared_error: 0.0122 - val_coefficient_of_determination: 0.7879
# Epoch 4/16
# 120/120 [==============================] - 11s 95ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - mean_squared_error: 1.9729e-04 - root_mean_squared_error: 0.0140 - coefficient_of_determination: 0.9937 - val_loss: 0.0390 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0016 - val_root_mean_squared_error: 0.0406 - val_coefficient_of_determination: -1.4278
# Epoch 5/16
# 120/120 [==============================] - 11s 93ms/step - loss: 0.0152 - mean_absolute_error: 0.0152 - mean_squared_error: 3.9596e-04 - root_mean_squared_error: 0.0199 - coefficient_of_determination: 0.9889 - val_loss: 0.0074 - val_mean_absolute_error: 0.0074 - val_mean_squared_error: 9.7591e-05 - val_root_mean_squared_error: 0.0099 - val_coefficient_of_determination: 0.8488
# Epoch 6/16
# 120/120 [==============================] - 11s 94ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - mean_squared_error: 2.0627e-04 - root_mean_squared_error: 0.0144 - coefficient_of_determination: 0.9940 - val_loss: 0.0133 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 2.4139e-04 - val_root_mean_squared_error: 0.0155 - val_coefficient_of_determination: 0.6094
# Epoch 7/16
# 120/120 [==============================] - 11s 96ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - mean_squared_error: 1.8199e-04 - root_mean_squared_error: 0.0135 - coefficient_of_determination: 0.9945 - val_loss: 0.0252 - val_mean_absolute_error: 0.0252 - val_mean_squared_error: 7.2081e-04 - val_root_mean_squared_error: 0.0268 - val_coefficient_of_determination: -0.1473
# Epoch 8/16
# 120/120 [==============================] - 11s 94ms/step - loss: 0.0084 - mean_absolute_error: 0.0084 - mean_squared_error: 1.3181e-04 - root_mean_squared_error: 0.0115 - coefficient_of_determination: 0.9964 - val_loss: 0.0094 - val_mean_absolute_error: 0.0094 - val_mean_squared_error: 1.3779e-04 - val_root_mean_squared_error: 0.0117 - val_coefficient_of_determination: 0.7990
# Epoch 9/16
# 120/120 [==============================] - 11s 95ms/step - loss: 0.0104 - mean_absolute_error: 0.0104 - mean_squared_error: 1.8108e-04 - root_mean_squared_error: 0.0135 - coefficient_of_determination: 0.9949 - val_loss: 0.0147 - val_mean_absolute_error: 0.0147 - val_mean_squared_error: 2.8559e-04 - val_root_mean_squared_error: 0.0169 - val_coefficient_of_determination: 0.5763
# Epoch 10/16
# 120/120 [==============================] - 12s 97ms/step - loss: 0.0112 - mean_absolute_error: 0.0112 - mean_squared_error: 2.0667e-04 - root_mean_squared_error: 0.0144 - coefficient_of_determination: 0.9941 - val_loss: 0.0165 - val_mean_absolute_error: 0.0165 - val_mean_squared_error: 3.4081e-04 - val_root_mean_squared_error: 0.0185 - val_coefficient_of_determination: 0.4937
# Epoch 11/16
# 120/120 [==============================] - 11s 95ms/step - loss: 0.0092 - mean_absolute_error: 0.0092 - mean_squared_error: 1.5232e-04 - root_mean_squared_error: 0.0123 - coefficient_of_determination: 0.9956 - val_loss: 0.0075 - val_mean_absolute_error: 0.0075 - val_mean_squared_error: 9.6325e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.8574
# Epoch 12/16
# 120/120 [==============================] - 12s 101ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - mean_squared_error: 1.4028e-04 - root_mean_squared_error: 0.0118 - coefficient_of_determination: 0.9961 - val_loss: 0.0083 - val_mean_absolute_error: 0.0083 - val_mean_squared_error: 1.1646e-04 - val_root_mean_squared_error: 0.0108 - val_coefficient_of_determination: 0.8250
# Epoch 13/16
# 120/120 [==============================] - 12s 100ms/step - loss: 0.0112 - mean_absolute_error: 0.0112 - mean_squared_error: 2.1708e-04 - root_mean_squared_error: 0.0147 - coefficient_of_determination: 0.9940 - val_loss: 0.0122 - val_mean_absolute_error: 0.0122 - val_mean_squared_error: 2.0807e-04 - val_root_mean_squared_error: 0.0144 - val_coefficient_of_determination: 0.7003
# Epoch 14/16
# 120/120 [==============================] - 12s 100ms/step - loss: 0.0099 - mean_absolute_error: 0.0099 - mean_squared_error: 1.4659e-04 - root_mean_squared_error: 0.0121 - coefficient_of_determination: 0.9959 - val_loss: 0.0075 - val_mean_absolute_error: 0.0075 - val_mean_squared_error: 9.4041e-05 - val_root_mean_squared_error: 0.0097 - val_coefficient_of_determination: 0.8637
# Epoch 15/16
# 120/120 [==============================] - 12s 98ms/step - loss: 0.0067 - mean_absolute_error: 0.0067 - mean_squared_error: 8.1318e-05 - root_mean_squared_error: 0.0090 - coefficient_of_determination: 0.9977 - val_loss: 0.0078 - val_mean_absolute_error: 0.0078 - val_mean_squared_error: 1.0010e-04 - val_root_mean_squared_error: 0.0100 - val_coefficient_of_determination: 0.8521
# Epoch 16/16
# 120/120 [==============================] - 11s 94ms/step - loss: 0.0078 - mean_absolute_error: 0.0078 - mean_squared_error: 1.2137e-04 - root_mean_squared_error: 0.0110 - coefficient_of_determination: 0.9965 - val_loss: 0.0295 - val_mean_absolute_error: 0.0295 - val_mean_squared_error: 9.7287e-04 - val_root_mean_squared_error: 0.0312 - val_coefficient_of_determination: -0.5070
# Epoch 1/12
# 120/120 [==============================] - 12s 96ms/step - loss: 0.0026 - mean_absolute_error: 0.0026 - mean_squared_error: 2.8516e-05 - root_mean_squared_error: 0.0053 - coefficient_of_determination: 0.9992 - val_loss: 0.0082 - val_mean_absolute_error: 0.0082 - val_mean_squared_error: 1.1312e-04 - val_root_mean_squared_error: 0.0106 - val_coefficient_of_determination: 0.8360
# Epoch 2/12
# 120/120 [==============================] - 12s 99ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - mean_squared_error: 1.0622e-05 - root_mean_squared_error: 0.0033 - coefficient_of_determination: 0.9996 - val_loss: 0.0084 - val_mean_absolute_error: 0.0084 - val_mean_squared_error: 1.1418e-04 - val_root_mean_squared_error: 0.0107 - val_coefficient_of_determination: 0.8347
# Epoch 3/12
# 120/120 [==============================] - 12s 99ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 1.0812e-05 - root_mean_squared_error: 0.0033 - coefficient_of_determination: 0.9997 - val_loss: 0.0086 - val_mean_absolute_error: 0.0086 - val_mean_squared_error: 1.1795e-04 - val_root_mean_squared_error: 0.0109 - val_coefficient_of_determination: 0.8294
# Epoch 4/12
# 120/120 [==============================] - 12s 102ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 1.0800e-05 - root_mean_squared_error: 0.0033 - coefficient_of_determination: 0.9997 - val_loss: 0.0088 - val_mean_absolute_error: 0.0088 - val_mean_squared_error: 1.2624e-04 - val_root_mean_squared_error: 0.0112 - val_coefficient_of_determination: 0.8171
# Epoch 5/12
# 120/120 [==============================] - 12s 102ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - mean_squared_error: 1.1491e-05 - root_mean_squared_error: 0.0034 - coefficient_of_determination: 0.9997 - val_loss: 0.0088 - val_mean_absolute_error: 0.0088 - val_mean_squared_error: 1.2266e-04 - val_root_mean_squared_error: 0.0111 - val_coefficient_of_determination: 0.8230
# Epoch 6/12
# 120/120 [==============================] - 12s 104ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 1.0707e-05 - root_mean_squared_error: 0.0033 - coefficient_of_determination: 0.9997 - val_loss: 0.0089 - val_mean_absolute_error: 0.0089 - val_mean_squared_error: 1.2521e-04 - val_root_mean_squared_error: 0.0112 - val_coefficient_of_determination: 0.8195
# Epoch 7/12
# 120/120 [==============================] - 13s 105ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 1.1159e-05 - root_mean_squared_error: 0.0033 - coefficient_of_determination: 0.9996 - val_loss: 0.0090 - val_mean_absolute_error: 0.0090 - val_mean_squared_error: 1.2694e-04 - val_root_mean_squared_error: 0.0113 - val_coefficient_of_determination: 0.8170
# Epoch 8/12
# 120/120 [==============================] - 13s 108ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 1.0693e-05 - root_mean_squared_error: 0.0033 - coefficient_of_determination: 0.9997 - val_loss: 0.0091 - val_mean_absolute_error: 0.0091 - val_mean_squared_error: 1.3293e-04 - val_root_mean_squared_error: 0.0115 - val_coefficient_of_determination: 0.8083
# Epoch 9/12
# 120/120 [==============================] - 13s 105ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 1.0504e-05 - root_mean_squared_error: 0.0032 - coefficient_of_determination: 0.9997 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092 - val_mean_squared_error: 1.3240e-04 - val_root_mean_squared_error: 0.0115 - val_coefficient_of_determination: 0.8093
# Epoch 10/12
# 120/120 [==============================] - 13s 109ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 1.0671e-05 - root_mean_squared_error: 0.0033 - coefficient_of_determination: 0.9997 - val_loss: 0.0091 - val_mean_absolute_error: 0.0091 - val_mean_squared_error: 1.3125e-04 - val_root_mean_squared_error: 0.0115 - val_coefficient_of_determination: 0.8116
# Epoch 11/12
# 120/120 [==============================] - 13s 107ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 1.0441e-05 - root_mean_squared_error: 0.0032 - coefficient_of_determination: 0.9995 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092 - val_mean_squared_error: 1.3444e-04 - val_root_mean_squared_error: 0.0116 - val_coefficient_of_determination: 0.8065
# Epoch 12/12
# 120/120 [==============================] - 12s 103ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 1.0508e-05 - root_mean_squared_error: 0.0032 - coefficient_of_determination: 0.9997 - val_loss: 0.0093 - val_mean_absolute_error: 0.0093 - val_mean_squared_error: 1.3563e-04 - val_root_mean_squared_error: 0.0116 - val_coefficient_of_determination: 0.8051
# Epoch 1/8
# 120/120 [==============================] - 12s 103ms/step - loss: 9.7870e-04 - mean_absolute_error: 9.7870e-04 - mean_squared_error: 9.7990e-06 - root_mean_squared_error: 0.0031 - coefficient_of_determination: 0.9997 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092 - val_mean_squared_error: 1.3432e-04 - val_root_mean_squared_error: 0.0116 - val_coefficient_of_determination: 0.8071
# Epoch 2/8
# 120/120 [==============================] - 12s 103ms/step - loss: 9.8900e-04 - mean_absolute_error: 9.8900e-04 - mean_squared_error: 9.8702e-06 - root_mean_squared_error: 0.0031 - coefficient_of_determination: 0.9997 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092 - val_mean_squared_error: 1.3466e-04 - val_root_mean_squared_error: 0.0116 - val_coefficient_of_determination: 0.8067
# Epoch 3/8
# 120/120 [==============================] - 13s 105ms/step - loss: 9.6453e-04 - mean_absolute_error: 9.6453e-04 - mean_squared_error: 9.7616e-06 - root_mean_squared_error: 0.0031 - coefficient_of_determination: 0.9997 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092 - val_mean_squared_error: 1.3491e-04 - val_root_mean_squared_error: 0.0116 - val_coefficient_of_determination: 0.8063
# Epoch 4/8
# 120/120 [==============================] - 13s 105ms/step - loss: 9.5984e-04 - mean_absolute_error: 9.5984e-04 - mean_squared_error: 9.7719e-06 - root_mean_squared_error: 0.0031 - coefficient_of_determination: 0.9997 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092 - val_mean_squared_error: 1.3542e-04 - val_root_mean_squared_error: 0.0116 - val_coefficient_of_determination: 0.8056
# Epoch 5/8
# 120/120 [==============================] - 13s 109ms/step - loss: 9.6011e-04 - mean_absolute_error: 9.6011e-04 - mean_squared_error: 9.8009e-06 - root_mean_squared_error: 0.0031 - coefficient_of_determination: 0.9998 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092 - val_mean_squared_error: 1.3615e-04 - val_root_mean_squared_error: 0.0117 - val_coefficient_of_determination: 0.8046
# Epoch 6/8
# 120/120 [==============================] - 13s 109ms/step - loss: 9.7300e-04 - mean_absolute_error: 9.7300e-04 - mean_squared_error: 9.7451e-06 - root_mean_squared_error: 0.0031 - coefficient_of_determination: 0.9998 - val_loss: 0.0093 - val_mean_absolute_error: 0.0093 - val_mean_squared_error: 1.3630e-04 - val_root_mean_squared_error: 0.0117 - val_coefficient_of_determination: 0.8043
# Epoch 7/8
# 120/120 [==============================] - 13s 107ms/step - loss: 9.5659e-04 - mean_absolute_error: 9.5659e-04 - mean_squared_error: 9.7802e-06 - root_mean_squared_error: 0.0031 - coefficient_of_determination: 0.9997 - val_loss: 0.0093 - val_mean_absolute_error: 0.0093 - val_mean_squared_error: 1.3645e-04 - val_root_mean_squared_error: 0.0117 - val_coefficient_of_determination: 0.8041
# Epoch 8/8
# 120/120 [==============================] - 13s 110ms/step - loss: 9.5533e-04 - mean_absolute_error: 9.5533e-04 - mean_squared_error: 9.7703e-06 - root_mean_squared_error: 0.0031 - coefficient_of_determination: 0.9997 - val_loss: 0.0093 - val_mean_absolute_error: 0.0093 - val_mean_squared_error: 1.3665e-04 - val_root_mean_squared_error: 0.0117 - val_coefficient_of_determination: 0.8039

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 3/4 [=====================>........] - ETA: 0s
# 2022-08-17 16:57:22.836851: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 4/4 [==============================] - 1s 34ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted HSI Open Price ($)")
plt.plot(y_test, color='blue', label="Actual HSI Open Price ($)")
plt.title('HSI Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('HSI Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.000955333816818893
# Mean Squared Error (MSE): 9.770341421244666e-06
# Root Mean Squared Error (RMSE): 0.003125754650682211
# Coefficient of Determination (R2): 0.999732255935669

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.009282761253416538
# Validation Mean Squared Error (MSE): 0.00013664766447618604
# Validation Root Mean Squared Error (RMSE): 0.011689639650285244
# Validation Coefficient of Determination (R2): 0.8039310574531555

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 119 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $66553.05056241248
# Balance Percentage Change: 6.655305056241248%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $97911.12813486453
# Balance Percentage Change: 9.791112813486452%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $147523.03252308
# Balance Percentage Change: 14.752303252308%
# ----------------------------------------------------------------
