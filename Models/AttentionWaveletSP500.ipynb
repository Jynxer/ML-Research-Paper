# %% [markdown]
# # S&P 500 Price Prediction LSTM with Wavelet Transforms and an Attention Mechanism

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from attention import Attention
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/S&P500.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingData.shape[0]):
    X_train.append(trainingData[i-exposureSize:i])
    y_train.append(trainingData[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (4415, 365, 5)
# (4415,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)

X_test = []
y_test = []

for i in range(exposureSize, testInputsNormalised.shape[0]):
    X_test.append(testInputsNormalised[i-exposureSize:i])
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (125, 365, 5)
# (125,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(Attention(units=16))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./AttentionWaveletSP500Model.png', show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 365, 50)           11200
#
#  attention_1 (Attention)     (None, 16)                4100
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 15,317
# Trainable params: 15,317
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
historyOne = model.fit(X_train, y_train, epochs=16, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=12, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=8, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 2022-08-17 16:19:49.031655: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 138/138 [==============================] - ETA: 0s - loss: 0.0274 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0046 - root_mean_squared_error: 0.0678 - coefficient_of_determination: 0.9267
# 2022-08-17 16:20:15.395070: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 138/138 [==============================] - 28s 192ms/step - loss: 0.0274 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0046 - root_mean_squared_error: 0.0678 - coefficient_of_determination: 0.9267 - val_loss: 0.0248 - val_mean_absolute_error: 0.0248 - val_mean_squared_error: 7.0884e-04 - val_root_mean_squared_error: 0.0266 - val_coefficient_of_determination: -1.0032
# Epoch 2/16
# 138/138 [==============================] - 20s 141ms/step - loss: 0.0166 - mean_absolute_error: 0.0166 - mean_squared_error: 5.2529e-04 - root_mean_squared_error: 0.0229 - coefficient_of_determination: 0.9902 - val_loss: 0.0078 - val_mean_absolute_error: 0.0078 - val_mean_squared_error: 1.0006e-04 - val_root_mean_squared_error: 0.0100 - val_coefficient_of_determination: 0.7900
# Epoch 3/16
# 138/138 [==============================] - 16s 116ms/step - loss: 0.0089 - mean_absolute_error: 0.0089 - mean_squared_error: 1.6962e-04 - root_mean_squared_error: 0.0130 - coefficient_of_determination: 0.9967 - val_loss: 0.0127 - val_mean_absolute_error: 0.0127 - val_mean_squared_error: 2.1052e-04 - val_root_mean_squared_error: 0.0145 - val_coefficient_of_determination: 0.4138
# Epoch 4/16
# 138/138 [==============================] - 15s 112ms/step - loss: 0.0092 - mean_absolute_error: 0.0092 - mean_squared_error: 1.7327e-04 - root_mean_squared_error: 0.0132 - coefficient_of_determination: 0.9967 - val_loss: 0.0398 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0016 - val_root_mean_squared_error: 0.0404 - val_coefficient_of_determination: -3.7693
# Epoch 5/16
# 138/138 [==============================] - 14s 104ms/step - loss: 0.0083 - mean_absolute_error: 0.0083 - mean_squared_error: 1.4923e-04 - root_mean_squared_error: 0.0122 - coefficient_of_determination: 0.9972 - val_loss: 0.0182 - val_mean_absolute_error: 0.0182 - val_mean_squared_error: 3.7870e-04 - val_root_mean_squared_error: 0.0195 - val_coefficient_of_determination: -0.1201
# Epoch 6/16
# 138/138 [==============================] - 15s 108ms/step - loss: 0.0092 - mean_absolute_error: 0.0092 - mean_squared_error: 1.8565e-04 - root_mean_squared_error: 0.0136 - coefficient_of_determination: 0.9964 - val_loss: 0.0275 - val_mean_absolute_error: 0.0275 - val_mean_squared_error: 8.0154e-04 - val_root_mean_squared_error: 0.0283 - val_coefficient_of_determination: -1.3801
# Epoch 7/16
# 138/138 [==============================] - 15s 108ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - mean_squared_error: 5.9863e-05 - root_mean_squared_error: 0.0077 - coefficient_of_determination: 0.9988 - val_loss: 0.0093 - val_mean_absolute_error: 0.0093 - val_mean_squared_error: 1.1680e-04 - val_root_mean_squared_error: 0.0108 - val_coefficient_of_determination: 0.6671
# Epoch 8/16
# 138/138 [==============================] - 15s 111ms/step - loss: 0.0047 - mean_absolute_error: 0.0047 - mean_squared_error: 4.6123e-05 - root_mean_squared_error: 0.0068 - coefficient_of_determination: 0.9991 - val_loss: 0.0335 - val_mean_absolute_error: 0.0335 - val_mean_squared_error: 0.0012 - val_root_mean_squared_error: 0.0342 - val_coefficient_of_determination: -2.5560
# Epoch 9/16
# 138/138 [==============================] - 15s 107ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - mean_squared_error: 9.8730e-05 - root_mean_squared_error: 0.0099 - coefficient_of_determination: 0.9981 - val_loss: 0.0359 - val_mean_absolute_error: 0.0359 - val_mean_squared_error: 0.0013 - val_root_mean_squared_error: 0.0366 - val_coefficient_of_determination: -3.0642
# Epoch 10/16
# 138/138 [==============================] - 15s 106ms/step - loss: 0.0063 - mean_absolute_error: 0.0063 - mean_squared_error: 8.3892e-05 - root_mean_squared_error: 0.0092 - coefficient_of_determination: 0.9984 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 4.5348e-05 - val_root_mean_squared_error: 0.0067 - val_coefficient_of_determination: 0.8828
# Epoch 11/16
# 138/138 [==============================] - 14s 99ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - mean_squared_error: 6.0992e-05 - root_mean_squared_error: 0.0078 - coefficient_of_determination: 0.9988 - val_loss: 0.0068 - val_mean_absolute_error: 0.0068 - val_mean_squared_error: 6.4038e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.8219
# Epoch 12/16
# 138/138 [==============================] - 14s 98ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - mean_squared_error: 5.9981e-05 - root_mean_squared_error: 0.0077 - coefficient_of_determination: 0.9988 - val_loss: 0.0102 - val_mean_absolute_error: 0.0102 - val_mean_squared_error: 1.3539e-04 - val_root_mean_squared_error: 0.0116 - val_coefficient_of_determination: 0.6208
# Epoch 13/16
# 138/138 [==============================] - 14s 103ms/step - loss: 0.0063 - mean_absolute_error: 0.0063 - mean_squared_error: 7.4594e-05 - root_mean_squared_error: 0.0086 - coefficient_of_determination: 0.9986 - val_loss: 0.0268 - val_mean_absolute_error: 0.0268 - val_mean_squared_error: 7.5445e-04 - val_root_mean_squared_error: 0.0275 - val_coefficient_of_determination: -1.1765
# Epoch 14/16
# 138/138 [==============================] - 15s 107ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - mean_squared_error: 4.9632e-05 - root_mean_squared_error: 0.0070 - coefficient_of_determination: 0.9990 - val_loss: 0.0169 - val_mean_absolute_error: 0.0169 - val_mean_squared_error: 3.2252e-04 - val_root_mean_squared_error: 0.0180 - val_coefficient_of_determination: 0.0392
# Epoch 15/16
# 138/138 [==============================] - 15s 107ms/step - loss: 0.0042 - mean_absolute_error: 0.0042 - mean_squared_error: 3.1441e-05 - root_mean_squared_error: 0.0056 - coefficient_of_determination: 0.9994 - val_loss: 0.0124 - val_mean_absolute_error: 0.0124 - val_mean_squared_error: 1.8806e-04 - val_root_mean_squared_error: 0.0137 - val_coefficient_of_determination: 0.4823
# Epoch 16/16
# 138/138 [==============================] - 14s 100ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - mean_squared_error: 5.0971e-05 - root_mean_squared_error: 0.0071 - coefficient_of_determination: 0.9990 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054 - val_mean_squared_error: 4.4251e-05 - val_root_mean_squared_error: 0.0067 - val_coefficient_of_determination: 0.8857
# Epoch 1/12
# 138/138 [==============================] - 15s 110ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.7744e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060 - val_mean_squared_error: 5.1859e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.8622
# Epoch 2/12
# 138/138 [==============================] - 15s 108ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.3390e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048 - val_mean_squared_error: 3.8146e-05 - val_root_mean_squared_error: 0.0062 - val_coefficient_of_determination: 0.9009
# Epoch 3/12
# 138/138 [==============================] - 15s 111ms/step - loss: 9.1489e-04 - mean_absolute_error: 9.1489e-04 - mean_squared_error: 2.8794e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048 - val_mean_squared_error: 3.9124e-05 - val_root_mean_squared_error: 0.0063 - val_coefficient_of_determination: 0.8979
# Epoch 4/12
# 138/138 [==============================] - 15s 109ms/step - loss: 9.9441e-04 - mean_absolute_error: 9.9441e-04 - mean_squared_error: 3.1739e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050 - val_mean_squared_error: 3.9927e-05 - val_root_mean_squared_error: 0.0063 - val_coefficient_of_determination: 0.8968
# Epoch 5/12
# 138/138 [==============================] - 15s 105ms/step - loss: 8.4964e-04 - mean_absolute_error: 8.4964e-04 - mean_squared_error: 2.6007e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 1.0000 - val_loss: 0.0052 - val_mean_absolute_error: 0.0052 - val_mean_squared_error: 4.2306e-05 - val_root_mean_squared_error: 0.0065 - val_coefficient_of_determination: 0.8907
# Epoch 6/12
# 138/138 [==============================] - 15s 106ms/step - loss: 8.1458e-04 - mean_absolute_error: 8.1458e-04 - mean_squared_error: 2.4204e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 1.0000 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051 - val_mean_squared_error: 4.2541e-05 - val_root_mean_squared_error: 0.0065 - val_coefficient_of_determination: 0.8902
# Epoch 7/12
# 138/138 [==============================] - 15s 106ms/step - loss: 8.7561e-04 - mean_absolute_error: 8.7561e-04 - mean_squared_error: 2.4759e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 1.0000 - val_loss: 0.0052 - val_mean_absolute_error: 0.0052 - val_mean_squared_error: 4.3648e-05 - val_root_mean_squared_error: 0.0066 - val_coefficient_of_determination: 0.8867
# Epoch 8/12
# 138/138 [==============================] - 15s 105ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.0352e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0053 - val_mean_absolute_error: 0.0053 - val_mean_squared_error: 4.4654e-05 - val_root_mean_squared_error: 0.0067 - val_coefficient_of_determination: 0.8848
# Epoch 9/12
# 138/138 [==============================] - 15s 107ms/step - loss: 9.1381e-04 - mean_absolute_error: 9.1381e-04 - mean_squared_error: 2.5629e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 1.0000 - val_loss: 0.0053 - val_mean_absolute_error: 0.0053 - val_mean_squared_error: 4.5413e-05 - val_root_mean_squared_error: 0.0067 - val_coefficient_of_determination: 0.8827
# Epoch 10/12
# 138/138 [==============================] - 15s 111ms/step - loss: 8.0498e-04 - mean_absolute_error: 8.0498e-04 - mean_squared_error: 2.2342e-06 - root_mean_squared_error: 0.0015 - coefficient_of_determination: 1.0000 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 5.3378e-05 - val_root_mean_squared_error: 0.0073 - val_coefficient_of_determination: 0.8563
# Epoch 11/12
# 138/138 [==============================] - 16s 113ms/step - loss: 9.7198e-04 - mean_absolute_error: 9.7198e-04 - mean_squared_error: 2.6514e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 0.9999 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 4.8274e-05 - val_root_mean_squared_error: 0.0069 - val_coefficient_of_determination: 0.8756
# Epoch 12/12
# 138/138 [==============================] - 17s 121ms/step - loss: 7.7815e-04 - mean_absolute_error: 7.7815e-04 - mean_squared_error: 2.0228e-06 - root_mean_squared_error: 0.0014 - coefficient_of_determination: 1.0000 - val_loss: 0.0059 - val_mean_absolute_error: 0.0059 - val_mean_squared_error: 5.3769e-05 - val_root_mean_squared_error: 0.0073 - val_coefficient_of_determination: 0.8615
# Epoch 1/8
# 138/138 [==============================] - 17s 120ms/step - loss: 6.2040e-04 - mean_absolute_error: 6.2040e-04 - mean_squared_error: 1.6011e-06 - root_mean_squared_error: 0.0013 - coefficient_of_determination: 1.0000 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 5.0190e-05 - val_root_mean_squared_error: 0.0071 - val_coefficient_of_determination: 0.8709
# Epoch 2/8
# 138/138 [==============================] - 16s 115ms/step - loss: 5.9950e-04 - mean_absolute_error: 5.9950e-04 - mean_squared_error: 1.5628e-06 - root_mean_squared_error: 0.0013 - coefficient_of_determination: 1.0000 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.1290e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.8682
# Epoch 3/8
# 138/138 [==============================] - 16s 113ms/step - loss: 5.9642e-04 - mean_absolute_error: 5.9642e-04 - mean_squared_error: 1.5882e-06 - root_mean_squared_error: 0.0013 - coefficient_of_determination: 1.0000 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.0910e-05 - val_root_mean_squared_error: 0.0071 - val_coefficient_of_determination: 0.8692
# Epoch 4/8
# 138/138 [==============================] - 16s 117ms/step - loss: 6.0412e-04 - mean_absolute_error: 6.0412e-04 - mean_squared_error: 1.5701e-06 - root_mean_squared_error: 0.0013 - coefficient_of_determination: 1.0000 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 5.2604e-05 - val_root_mean_squared_error: 0.0073 - val_coefficient_of_determination: 0.8648
# Epoch 5/8
# 138/138 [==============================] - 16s 113ms/step - loss: 6.2650e-04 - mean_absolute_error: 6.2650e-04 - mean_squared_error: 1.6066e-06 - root_mean_squared_error: 0.0013 - coefficient_of_determination: 1.0000 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.1570e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.8675
# Epoch 6/8
# 138/138 [==============================] - 15s 112ms/step - loss: 5.9723e-04 - mean_absolute_error: 5.9723e-04 - mean_squared_error: 1.5427e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 5.1444e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.8677
# Epoch 7/8
# 138/138 [==============================] - 15s 112ms/step - loss: 5.9449e-04 - mean_absolute_error: 5.9449e-04 - mean_squared_error: 1.5346e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 5.2691e-05 - val_root_mean_squared_error: 0.0073 - val_coefficient_of_determination: 0.8647
# Epoch 8/8
# 138/138 [==============================] - 16s 117ms/step - loss: 6.0418e-04 - mean_absolute_error: 6.0418e-04 - mean_squared_error: 1.5187e-06 - root_mean_squared_error: 0.0012 - coefficient_of_determination: 1.0000 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 5.2360e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.8656

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 1/4 [======>.......................] - ETA: 1s
# 2022-08-17 16:29:09.322007: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 4/4 [==============================] - 1s 35ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted S&P 500 Open Price ($)")
plt.plot(y_test, color='blue', label="Actual S&P 500 Open Price ($)")
plt.title('S&P 500 Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('S&P 500 Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.0006041753804311156
# Mean Squared Error (MSE): 1.5187154076556908e-06
# Root Mean Squared Error (RMSE): 0.001232361770235002
# Coefficient of Determination (R2): 0.9999690651893616

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.005774879362434149
# Validation Mean Squared Error (MSE): 5.235988646745682e-05
# Validation Root Mean Squared Error (RMSE): 0.007236013188958168
# Validation Coefficient of Determination (R2): 0.8655984997749329

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 125 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $44660.85393751087
# Balance Percentage Change: 4.4660853937510865%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $199619.67847085418
# Balance Percentage Change: 19.96196784708542%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $253221.02324538818
# Balance Percentage Change: 25.322102324538818%
# ----------------------------------------------------------------
