# %% [markdown]
# # Initial HSI Price Prediction LSTM

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/HSI.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingData = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingData.shape[0]):
    X_train.append(trainingData[i-exposureSize:i])
    y_train.append(trainingData[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (3820, 365, 5)
# (3820,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(testInputsNormalised[i-exposureSize:i])
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (119, 365, 5)
# (119,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./InitialHSIModel.png', show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 50)                11200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 11,251
# Trainable params: 11,251
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
historyOne = model.fit(X_train, y_train, epochs=16, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=12, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=8, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 120/120 [==============================] - 17s 122ms/step - loss: 0.0396 - mean_absolute_error: 0.0396 - mean_squared_error: 0.0133 - root_mean_squared_error: 0.1154 - coefficient_of_determination: 0.5831 - val_loss: 0.0130 - val_mean_absolute_error: 0.0130 - val_mean_squared_error: 2.4944e-04 - val_root_mean_squared_error: 0.0158 - val_coefficient_of_determination: 0.5678
# Epoch 2/16
# 120/120 [==============================] - 10s 83ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - mean_squared_error: 2.0432e-04 - root_mean_squared_error: 0.0143 - coefficient_of_determination: 0.9942 - val_loss: 0.0193 - val_mean_absolute_error: 0.0193 - val_mean_squared_error: 4.5560e-04 - val_root_mean_squared_error: 0.0213 - val_coefficient_of_determination: 0.2490
# Epoch 3/16
# 120/120 [==============================] - 11s 91ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - mean_squared_error: 2.2224e-04 - root_mean_squared_error: 0.0149 - coefficient_of_determination: 0.9939 - val_loss: 0.0096 - val_mean_absolute_error: 0.0096 - val_mean_squared_error: 1.4505e-04 - val_root_mean_squared_error: 0.0120 - val_coefficient_of_determination: 0.7947
# Epoch 4/16
# 120/120 [==============================] - 12s 100ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - mean_squared_error: 2.2913e-04 - root_mean_squared_error: 0.0151 - coefficient_of_determination: 0.9933 - val_loss: 0.0280 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 8.5637e-04 - val_root_mean_squared_error: 0.0293 - val_coefficient_of_determination: -0.3642
# Epoch 5/16
# 120/120 [==============================] - 12s 98ms/step - loss: 0.0093 - mean_absolute_error: 0.0093 - mean_squared_error: 1.6301e-04 - root_mean_squared_error: 0.0128 - coefficient_of_determination: 0.9953 - val_loss: 0.0228 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 5.9210e-04 - val_root_mean_squared_error: 0.0243 - val_coefficient_of_determination: 0.0581
# Epoch 6/16
# 120/120 [==============================] - 11s 89ms/step - loss: 0.0087 - mean_absolute_error: 0.0087 - mean_squared_error: 1.4874e-04 - root_mean_squared_error: 0.0122 - coefficient_of_determination: 0.9958 - val_loss: 0.0111 - val_mean_absolute_error: 0.0111 - val_mean_squared_error: 1.6999e-04 - val_root_mean_squared_error: 0.0130 - val_coefficient_of_determination: 0.7315
# Epoch 7/16
# 120/120 [==============================] - 10s 86ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - mean_squared_error: 1.2098e-04 - root_mean_squared_error: 0.0110 - coefficient_of_determination: 0.9965 - val_loss: 0.0110 - val_mean_absolute_error: 0.0110 - val_mean_squared_error: 1.7437e-04 - val_root_mean_squared_error: 0.0132 - val_coefficient_of_determination: 0.7618
# Epoch 8/16
# 120/120 [==============================] - 10s 86ms/step - loss: 0.0091 - mean_absolute_error: 0.0091 - mean_squared_error: 1.5154e-04 - root_mean_squared_error: 0.0123 - coefficient_of_determination: 0.9957 - val_loss: 0.0131 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 2.1871e-04 - val_root_mean_squared_error: 0.0148 - val_coefficient_of_determination: 0.6497
# Epoch 9/16
# 120/120 [==============================] - 10s 86ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - mean_squared_error: 1.0696e-04 - root_mean_squared_error: 0.0103 - coefficient_of_determination: 0.9970 - val_loss: 0.0086 - val_mean_absolute_error: 0.0086 - val_mean_squared_error: 1.1494e-04 - val_root_mean_squared_error: 0.0107 - val_coefficient_of_determination: 0.8392
# Epoch 10/16
# 120/120 [==============================] - 10s 86ms/step - loss: 0.0090 - mean_absolute_error: 0.0090 - mean_squared_error: 1.4935e-04 - root_mean_squared_error: 0.0122 - coefficient_of_determination: 0.9958 - val_loss: 0.0139 - val_mean_absolute_error: 0.0139 - val_mean_squared_error: 2.3992e-04 - val_root_mean_squared_error: 0.0155 - val_coefficient_of_determination: 0.6192
# Epoch 11/16
# 120/120 [==============================] - 11s 90ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - mean_squared_error: 1.1021e-04 - root_mean_squared_error: 0.0105 - coefficient_of_determination: 0.9968 - val_loss: 0.0061 - val_mean_absolute_error: 0.0061 - val_mean_squared_error: 7.0062e-05 - val_root_mean_squared_error: 0.0084 - val_coefficient_of_determination: 0.8955
# Epoch 12/16
# 120/120 [==============================] - 12s 97ms/step - loss: 0.0089 - mean_absolute_error: 0.0089 - mean_squared_error: 1.4850e-04 - root_mean_squared_error: 0.0122 - coefficient_of_determination: 0.9957 - val_loss: 0.0157 - val_mean_absolute_error: 0.0157 - val_mean_squared_error: 2.9745e-04 - val_root_mean_squared_error: 0.0172 - val_coefficient_of_determination: 0.5270
# Epoch 13/16
# 120/120 [==============================] - 11s 95ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - mean_squared_error: 1.2075e-04 - root_mean_squared_error: 0.0110 - coefficient_of_determination: 0.9966 - val_loss: 0.0135 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 2.3752e-04 - val_root_mean_squared_error: 0.0154 - val_coefficient_of_determination: 0.6701
# Epoch 14/16
# 120/120 [==============================] - 12s 98ms/step - loss: 0.0079 - mean_absolute_error: 0.0079 - mean_squared_error: 1.1707e-04 - root_mean_squared_error: 0.0108 - coefficient_of_determination: 0.9968 - val_loss: 0.0063 - val_mean_absolute_error: 0.0063 - val_mean_squared_error: 7.3712e-05 - val_root_mean_squared_error: 0.0086 - val_coefficient_of_determination: 0.8929
# Epoch 15/16
# 120/120 [==============================] - 20s 167ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - mean_squared_error: 1.0387e-04 - root_mean_squared_error: 0.0102 - coefficient_of_determination: 0.9971 - val_loss: 0.0080 - val_mean_absolute_error: 0.0080 - val_mean_squared_error: 1.0286e-04 - val_root_mean_squared_error: 0.0101 - val_coefficient_of_determination: 0.8362
# Epoch 16/16
# 120/120 [==============================] - 15s 121ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - mean_squared_error: 1.1236e-04 - root_mean_squared_error: 0.0106 - coefficient_of_determination: 0.9968 - val_loss: 0.0085 - val_mean_absolute_error: 0.0085 - val_mean_squared_error: 1.1223e-04 - val_root_mean_squared_error: 0.0106 - val_coefficient_of_determination: 0.8433
# Epoch 1/12
# 120/120 [==============================] - 20s 163ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 7.7132e-05 - root_mean_squared_error: 0.0088 - coefficient_of_determination: 0.9978 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060 - val_mean_squared_error: 6.7883e-05 - val_root_mean_squared_error: 0.0082 - val_coefficient_of_determination: 0.9050
# Epoch 2/12
# 120/120 [==============================] - 14s 113ms/step - loss: 0.0057 - mean_absolute_error: 0.0057 - mean_squared_error: 7.6243e-05 - root_mean_squared_error: 0.0087 - coefficient_of_determination: 0.9979 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 6.4573e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.9044
# Epoch 3/12
# 120/120 [==============================] - 11s 93ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 7.7026e-05 - root_mean_squared_error: 0.0088 - coefficient_of_determination: 0.9978 - val_loss: 0.0061 - val_mean_absolute_error: 0.0061 - val_mean_squared_error: 6.8938e-05 - val_root_mean_squared_error: 0.0083 - val_coefficient_of_determination: 0.8946
# Epoch 4/12
# 120/120 [==============================] - 11s 91ms/step - loss: 0.0057 - mean_absolute_error: 0.0057 - mean_squared_error: 7.5377e-05 - root_mean_squared_error: 0.0087 - coefficient_of_determination: 0.9978 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 6.1790e-05 - val_root_mean_squared_error: 0.0079 - val_coefficient_of_determination: 0.9095
# Epoch 5/12
# 120/120 [==============================] - 16s 130ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 7.6458e-05 - root_mean_squared_error: 0.0087 - coefficient_of_determination: 0.9978 - val_loss: 0.0061 - val_mean_absolute_error: 0.0061 - val_mean_squared_error: 6.8768e-05 - val_root_mean_squared_error: 0.0083 - val_coefficient_of_determination: 0.8962
# Epoch 6/12
# 120/120 [==============================] - 19s 162ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 7.6491e-05 - root_mean_squared_error: 0.0087 - coefficient_of_determination: 0.9979 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 6.1499e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9102
# Epoch 7/12
# 120/120 [==============================] - 14s 113ms/step - loss: 0.0057 - mean_absolute_error: 0.0057 - mean_squared_error: 7.4831e-05 - root_mean_squared_error: 0.0087 - coefficient_of_determination: 0.9978 - val_loss: 0.0059 - val_mean_absolute_error: 0.0059 - val_mean_squared_error: 6.5308e-05 - val_root_mean_squared_error: 0.0081 - val_coefficient_of_determination: 0.9003
# Epoch 8/12
# 120/120 [==============================] - 11s 95ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 7.5851e-05 - root_mean_squared_error: 0.0087 - coefficient_of_determination: 0.9978 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 6.1151e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9112
# Epoch 9/12
# 120/120 [==============================] - 11s 95ms/step - loss: 0.0057 - mean_absolute_error: 0.0057 - mean_squared_error: 7.5386e-05 - root_mean_squared_error: 0.0087 - coefficient_of_determination: 0.9978 - val_loss: 0.0059 - val_mean_absolute_error: 0.0059 - val_mean_squared_error: 6.6359e-05 - val_root_mean_squared_error: 0.0081 - val_coefficient_of_determination: 0.9062
# Epoch 10/12
# 120/120 [==============================] - 12s 96ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 7.6131e-05 - root_mean_squared_error: 0.0087 - coefficient_of_determination: 0.9979 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 6.1496e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9118
# Epoch 11/12
# 120/120 [==============================] - 11s 95ms/step - loss: 0.0057 - mean_absolute_error: 0.0057 - mean_squared_error: 7.4449e-05 - root_mean_squared_error: 0.0086 - coefficient_of_determination: 0.9978 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 6.0379e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9109
# Epoch 12/12
# 120/120 [==============================] - 11s 96ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 7.6398e-05 - root_mean_squared_error: 0.0087 - coefficient_of_determination: 0.9978 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 6.0153e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9118
# Epoch 1/8
# 120/120 [==============================] - 17s 144ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.3124e-05 - root_mean_squared_error: 0.0086 - coefficient_of_determination: 0.9980 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 6.0301e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9120
# Epoch 2/8
# 120/120 [==============================] - 17s 140ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.2862e-05 - root_mean_squared_error: 0.0085 - coefficient_of_determination: 0.9979 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 6.0509e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9121
# Epoch 3/8
# 120/120 [==============================] - 11s 95ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.3105e-05 - root_mean_squared_error: 0.0086 - coefficient_of_determination: 0.9979 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 6.4007e-05 - val_root_mean_squared_error: 0.0080 - val_coefficient_of_determination: 0.9031
# Epoch 4/8
# 120/120 [==============================] - 11s 94ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.3143e-05 - root_mean_squared_error: 0.0086 - coefficient_of_determination: 0.9979 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 6.1238e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9117
# Epoch 5/8
# 120/120 [==============================] - 11s 93ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.3147e-05 - root_mean_squared_error: 0.0086 - coefficient_of_determination: 0.9979 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 6.1231e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9117
# Epoch 6/8
# 120/120 [==============================] - 11s 94ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.3161e-05 - root_mean_squared_error: 0.0086 - coefficient_of_determination: 0.9979 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 6.1048e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9117
# Epoch 7/8
# 120/120 [==============================] - 11s 92ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.3075e-05 - root_mean_squared_error: 0.0085 - coefficient_of_determination: 0.9979 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 6.1466e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9114
# Epoch 8/8
# 120/120 [==============================] - 11s 91ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 7.2835e-05 - root_mean_squared_error: 0.0085 - coefficient_of_determination: 0.9979 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 6.0154e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.9118

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 23ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted HSI Open Price ($)")
plt.plot(y_test, color='blue', label="Actual HSI Open Price ($)")
plt.title('HSI Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('HSI Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.005560692865401506
# Mean Squared Error (MSE): 7.283464219653979e-05
# Root Mean Squared Error (RMSE): 0.008534321561455727
# Coefficient of Determination (R2): 0.9979116320610046

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.005583152174949646
# Validation Mean Squared Error (MSE): 6.015449616825208e-05
# Validation Root Mean Squared Error (RMSE): 0.007755932863801718
# Validation Coefficient of Determination (R2): 0.9117775559425354

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 119 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $123697.15564370784
# Balance Percentage Change: 12.369715564370784%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $9791112.813486451
# Balance Percentage Change: 9.791112813486452%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $183326.31706372183
# Balance Percentage Change: 18.332631706372183%
# ----------------------------------------------------------------
