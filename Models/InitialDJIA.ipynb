# %% [markdown]
# # Initial DJIA Price Prediction LSTM

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/DJIA.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingData = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingData.shape[0]):
    X_train.append(trainingData[i-exposureSize:i])
    y_train.append(trainingData[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (4414, 365, 5)
# (4414,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(testInputsNormalised[i-exposureSize:i])
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (125, 365, 5)
# (125,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./InitialDJIAModel.png', show_shapes=True)
# Out:
# 2022-08-17 14:25:49.128485: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                11200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 11,251
# Trainable params: 11,251
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
historyOne = model.fit(X_train, y_train, epochs=16, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=12, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=8, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 138/138 [==============================] - 13s 78ms/step - loss: 0.0181 - mean_absolute_error: 0.0181 - mean_squared_error: 0.0019 - root_mean_squared_error: 0.0438 - coefficient_of_determination: 0.9570 - val_loss: 0.0306 - val_mean_absolute_error: 0.0306 - val_mean_squared_error: 0.0010 - val_root_mean_squared_error: 0.0320 - val_coefficient_of_determination: -2.2382
# Epoch 2/16
# 138/138 [==============================] - 10s 73ms/step - loss: 0.0083 - mean_absolute_error: 0.0083 - mean_squared_error: 1.2635e-04 - root_mean_squared_error: 0.0112 - coefficient_of_determination: 0.9973 - val_loss: 0.0065 - val_mean_absolute_error: 0.0065 - val_mean_squared_error: 6.2249e-05 - val_root_mean_squared_error: 0.0079 - val_coefficient_of_determination: 0.8194
# Epoch 3/16
# 138/138 [==============================] - 11s 79ms/step - loss: 0.0062 - mean_absolute_error: 0.0062 - mean_squared_error: 7.1851e-05 - root_mean_squared_error: 0.0085 - coefficient_of_determination: 0.9985 - val_loss: 0.0135 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 2.2052e-04 - val_root_mean_squared_error: 0.0149 - val_coefficient_of_determination: 0.2747
# Epoch 4/16
# 138/138 [==============================] - 24s 174ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - mean_squared_error: 4.5424e-05 - root_mean_squared_error: 0.0067 - coefficient_of_determination: 0.9991 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 3.0456e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9146
# Epoch 5/16
# 138/138 [==============================] - 23s 163ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - mean_squared_error: 6.2635e-05 - root_mean_squared_error: 0.0079 - coefficient_of_determination: 0.9987 - val_loss: 0.0070 - val_mean_absolute_error: 0.0070 - val_mean_squared_error: 6.5160e-05 - val_root_mean_squared_error: 0.0081 - val_coefficient_of_determination: 0.8105
# Epoch 6/16
# 138/138 [==============================] - 19s 141ms/step - loss: 0.0050 - mean_absolute_error: 0.0050 - mean_squared_error: 4.8491e-05 - root_mean_squared_error: 0.0070 - coefficient_of_determination: 0.9990 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 4.7482e-05 - val_root_mean_squared_error: 0.0069 - val_coefficient_of_determination: 0.8770
# Epoch 7/16
# 138/138 [==============================] - 16s 115ms/step - loss: 0.0057 - mean_absolute_error: 0.0057 - mean_squared_error: 6.3866e-05 - root_mean_squared_error: 0.0080 - coefficient_of_determination: 0.9986 - val_loss: 0.0303 - val_mean_absolute_error: 0.0303 - val_mean_squared_error: 9.5919e-04 - val_root_mean_squared_error: 0.0310 - val_coefficient_of_determination: -2.1289
# Epoch 8/16
# 138/138 [==============================] - 13s 97ms/step - loss: 0.0064 - mean_absolute_error: 0.0064 - mean_squared_error: 7.9446e-05 - root_mean_squared_error: 0.0089 - coefficient_of_determination: 0.9984 - val_loss: 0.0076 - val_mean_absolute_error: 0.0076 - val_mean_squared_error: 9.0906e-05 - val_root_mean_squared_error: 0.0095 - val_coefficient_of_determination: 0.7126
# Epoch 9/16
# 138/138 [==============================] - 12s 87ms/step - loss: 0.0044 - mean_absolute_error: 0.0044 - mean_squared_error: 3.5545e-05 - root_mean_squared_error: 0.0060 - coefficient_of_determination: 0.9992 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054 - val_mean_squared_error: 4.6632e-05 - val_root_mean_squared_error: 0.0068 - val_coefficient_of_determination: 0.8804
# Epoch 10/16
# 138/138 [==============================] - 12s 84ms/step - loss: 0.0042 - mean_absolute_error: 0.0042 - mean_squared_error: 3.3494e-05 - root_mean_squared_error: 0.0058 - coefficient_of_determination: 0.9993 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049 - val_mean_squared_error: 4.0577e-05 - val_root_mean_squared_error: 0.0064 - val_coefficient_of_determination: 0.8918
# Epoch 11/16
# 138/138 [==============================] - 11s 82ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - mean_squared_error: 2.5654e-05 - root_mean_squared_error: 0.0051 - coefficient_of_determination: 0.9995 - val_loss: 0.0102 - val_mean_absolute_error: 0.0102 - val_mean_squared_error: 1.3582e-04 - val_root_mean_squared_error: 0.0117 - val_coefficient_of_determination: 0.5671
# Epoch 12/16
# 138/138 [==============================] - 11s 82ms/step - loss: 0.0043 - mean_absolute_error: 0.0043 - mean_squared_error: 3.2532e-05 - root_mean_squared_error: 0.0057 - coefficient_of_determination: 0.9993 - val_loss: 0.0116 - val_mean_absolute_error: 0.0116 - val_mean_squared_error: 1.6153e-04 - val_root_mean_squared_error: 0.0127 - val_coefficient_of_determination: 0.4991
# Epoch 13/16
# 138/138 [==============================] - 11s 81ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - mean_squared_error: 2.8629e-05 - root_mean_squared_error: 0.0054 - coefficient_of_determination: 0.9994 - val_loss: 0.0153 - val_mean_absolute_error: 0.0153 - val_mean_squared_error: 2.6416e-04 - val_root_mean_squared_error: 0.0163 - val_coefficient_of_determination: 0.1480
# Epoch 14/16
# 138/138 [==============================] - 12s 84ms/step - loss: 0.0066 - mean_absolute_error: 0.0066 - mean_squared_error: 7.5366e-05 - root_mean_squared_error: 0.0087 - coefficient_of_determination: 0.9984 - val_loss: 0.0137 - val_mean_absolute_error: 0.0137 - val_mean_squared_error: 2.1679e-04 - val_root_mean_squared_error: 0.0147 - val_coefficient_of_determination: 0.3203
# Epoch 15/16
# 138/138 [==============================] - 12s 84ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - mean_squared_error: 2.9154e-05 - root_mean_squared_error: 0.0054 - coefficient_of_determination: 0.9994 - val_loss: 0.0070 - val_mean_absolute_error: 0.0070 - val_mean_squared_error: 6.6454e-05 - val_root_mean_squared_error: 0.0082 - val_coefficient_of_determination: 0.8112
# Epoch 16/16
# 138/138 [==============================] - 12s 85ms/step - loss: 0.0048 - mean_absolute_error: 0.0048 - mean_squared_error: 4.1859e-05 - root_mean_squared_error: 0.0065 - coefficient_of_determination: 0.9991 - val_loss: 0.0145 - val_mean_absolute_error: 0.0145 - val_mean_squared_error: 2.3982e-04 - val_root_mean_squared_error: 0.0155 - val_coefficient_of_determination: 0.2435
# Epoch 1/12
# 138/138 [==============================] - 12s 84ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 4.7680e-06 - root_mean_squared_error: 0.0022 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 3.0769e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9219
# Epoch 2/12
# 138/138 [==============================] - 11s 82ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.7428e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 4.9426e-05 - val_root_mean_squared_error: 0.0070 - val_coefficient_of_determination: 0.8644
# Epoch 3/12
# 138/138 [==============================] - 11s 82ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.7134e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 2.9754e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9234
# Epoch 4/12
# 138/138 [==============================] - 12s 84ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.6440e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 2.9744e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9235
# Epoch 5/12
# 138/138 [==============================] - 12s 84ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.3789e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 2.8946e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9264
# Epoch 6/12
# 138/138 [==============================] - 12s 84ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.3983e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046 - val_mean_squared_error: 3.3225e-05 - val_root_mean_squared_error: 0.0058 - val_coefficient_of_determination: 0.9137
# Epoch 7/12
# 138/138 [==============================] - 12s 84ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.3912e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 2.9024e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9268
# Epoch 8/12
# 138/138 [==============================] - 12s 84ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.3534e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 2.9987e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9230
# Epoch 9/12
# 138/138 [==============================] - 12s 84ms/step - loss: 9.6908e-04 - mean_absolute_error: 9.6908e-04 - mean_squared_error: 3.1433e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 2.9715e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9244
# Epoch 10/12
# 138/138 [==============================] - 12s 84ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.2064e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 3.0428e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9216
# Epoch 11/12
# 138/138 [==============================] - 12s 84ms/step - loss: 9.9086e-04 - mean_absolute_error: 9.9086e-04 - mean_squared_error: 3.0990e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 2.8404e-05 - val_root_mean_squared_error: 0.0053 - val_coefficient_of_determination: 0.9255
# Epoch 12/12
# 138/138 [==============================] - 12s 84ms/step - loss: 9.6529e-04 - mean_absolute_error: 9.6529e-04 - mean_squared_error: 3.0491e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 2.8853e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9248
# Epoch 1/8
# 138/138 [==============================] - 12s 86ms/step - loss: 8.3120e-04 - mean_absolute_error: 8.3120e-04 - mean_squared_error: 2.7116e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 0.9999 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 2.7805e-05 - val_root_mean_squared_error: 0.0053 - val_coefficient_of_determination: 0.9290
# Epoch 2/8
# 138/138 [==============================] - 12s 87ms/step - loss: 8.2194e-04 - mean_absolute_error: 8.2194e-04 - mean_squared_error: 2.6835e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 0.9999 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 2.7862e-05 - val_root_mean_squared_error: 0.0053 - val_coefficient_of_determination: 0.9293
# Epoch 3/8
# 138/138 [==============================] - 12s 84ms/step - loss: 8.2344e-04 - mean_absolute_error: 8.2344e-04 - mean_squared_error: 2.6696e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 0.9999 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 2.7783e-05 - val_root_mean_squared_error: 0.0053 - val_coefficient_of_determination: 0.9293
# Epoch 4/8
# 138/138 [==============================] - 12s 84ms/step - loss: 8.2716e-04 - mean_absolute_error: 8.2716e-04 - mean_squared_error: 2.6929e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 2.7842e-05 - val_root_mean_squared_error: 0.0053 - val_coefficient_of_determination: 0.9287
# Epoch 5/8
# 138/138 [==============================] - 12s 84ms/step - loss: 8.1880e-04 - mean_absolute_error: 8.1880e-04 - mean_squared_error: 2.6686e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 2.7791e-05 - val_root_mean_squared_error: 0.0053 - val_coefficient_of_determination: 0.9289
# Epoch 6/8
# 138/138 [==============================] - 12s 84ms/step - loss: 8.1857e-04 - mean_absolute_error: 8.1857e-04 - mean_squared_error: 2.6622e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 0.9999 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 2.7720e-05 - val_root_mean_squared_error: 0.0053 - val_coefficient_of_determination: 0.9295
# Epoch 7/8
# 138/138 [==============================] - 12s 84ms/step - loss: 8.2374e-04 - mean_absolute_error: 8.2374e-04 - mean_squared_error: 2.6718e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 0.9999 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 2.8256e-05 - val_root_mean_squared_error: 0.0053 - val_coefficient_of_determination: 0.9282
# Epoch 8/8
# 138/138 [==============================] - 12s 86ms/step - loss: 8.2517e-04 - mean_absolute_error: 8.2517e-04 - mean_squared_error: 2.6382e-06 - root_mean_squared_error: 0.0016 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 2.7663e-05 - val_root_mean_squared_error: 0.0053 - val_coefficient_of_determination: 0.9296

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 4/4 [==============================] - 1s 23ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted DJIA Open Price ($)")
plt.plot(y_test, color='blue', label="Actual DJIA Open Price ($)")
plt.title('DJIA Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('DJIA Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.0008251706603914499
# Mean Squared Error (MSE): 2.6382408577774186e-06
# Root Mean Squared Error (RMSE): 0.0016242662677541375
# Coefficient of Determination (R2): 0.9999468326568604

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.0041320910677313805
# Validation Mean Squared Error (MSE): 2.7662765205604956e-05
# Validation Root Mean Squared Error (RMSE): 0.005259540397673845
# Validation Coefficient of Determination (R2): 0.929560661315918

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 125 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $87848.10904842569
# Balance Percentage Change: 8.784810904842569%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $16250980.005976405
# Balance Percentage Change: 16.250980005976405%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $251226.33725258848
# Balance Percentage Change: 25.122633725258847%
# ----------------------------------------------------------------
