# %% [markdown]
# # Initial S&P 500 Price Prediction LSTM

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/S&P500.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingData = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingData.shape[0]):
    X_train.append(trainingData[i-exposureSize:i])
    y_train.append(trainingData[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (4414, 365, 5)
# (4414,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(testInputsNormalised[i-exposureSize:i])
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (125, 365, 5)
# (125,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./InitialSP500Model.png', show_shapes=True)
# Out:
# 2022-08-17 14:15:28.966897: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                11200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 11,251
# Trainable params: 11,251
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
historyOne = model.fit(X_train, y_train, epochs=16, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=12, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=8, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 138/138 [==============================] - 13s 80ms/step - loss: 0.0183 - mean_absolute_error: 0.0183 - mean_squared_error: 0.0051 - root_mean_squared_error: 0.0713 - coefficient_of_determination: 0.9127 - val_loss: 0.0100 - val_mean_absolute_error: 0.0100 - val_mean_squared_error: 1.4817e-04 - val_root_mean_squared_error: 0.0122 - val_coefficient_of_determination: 0.6232
# Epoch 2/16
# 138/138 [==============================] - 11s 78ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - mean_squared_error: 1.8815e-04 - root_mean_squared_error: 0.0137 - coefficient_of_determination: 0.9964 - val_loss: 0.0366 - val_mean_absolute_error: 0.0366 - val_mean_squared_error: 0.0014 - val_root_mean_squared_error: 0.0374 - val_coefficient_of_determination: -3.0600
# Epoch 3/16
# 138/138 [==============================] - 11s 79ms/step - loss: 0.0092 - mean_absolute_error: 0.0092 - mean_squared_error: 1.5655e-04 - root_mean_squared_error: 0.0125 - coefficient_of_determination: 0.9969 - val_loss: 0.0240 - val_mean_absolute_error: 0.0240 - val_mean_squared_error: 6.2025e-04 - val_root_mean_squared_error: 0.0249 - val_coefficient_of_determination: -0.7996
# Epoch 4/16
# 138/138 [==============================] - 11s 78ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - mean_squared_error: 1.0571e-04 - root_mean_squared_error: 0.0103 - coefficient_of_determination: 0.9980 - val_loss: 0.0308 - val_mean_absolute_error: 0.0308 - val_mean_squared_error: 9.8343e-04 - val_root_mean_squared_error: 0.0314 - val_coefficient_of_determination: -2.0350
# Epoch 5/16
# 138/138 [==============================] - 11s 79ms/step - loss: 0.0083 - mean_absolute_error: 0.0083 - mean_squared_error: 1.3503e-04 - root_mean_squared_error: 0.0116 - coefficient_of_determination: 0.9973 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 2.9470e-05 - val_root_mean_squared_error: 0.0054 - val_coefficient_of_determination: 0.9220
# Epoch 6/16
# 138/138 [==============================] - 11s 79ms/step - loss: 0.0047 - mean_absolute_error: 0.0047 - mean_squared_error: 4.2237e-05 - root_mean_squared_error: 0.0065 - coefficient_of_determination: 0.9992 - val_loss: 0.0197 - val_mean_absolute_error: 0.0197 - val_mean_squared_error: 4.1888e-04 - val_root_mean_squared_error: 0.0205 - val_coefficient_of_determination: -0.2179
# Epoch 7/16
# 138/138 [==============================] - 11s 79ms/step - loss: 0.0050 - mean_absolute_error: 0.0050 - mean_squared_error: 4.7290e-05 - root_mean_squared_error: 0.0069 - coefficient_of_determination: 0.9991 - val_loss: 0.0097 - val_mean_absolute_error: 0.0097 - val_mean_squared_error: 1.2499e-04 - val_root_mean_squared_error: 0.0112 - val_coefficient_of_determination: 0.6149
# Epoch 8/16
# 138/138 [==============================] - 11s 83ms/step - loss: 0.0050 - mean_absolute_error: 0.0050 - mean_squared_error: 5.0525e-05 - root_mean_squared_error: 0.0071 - coefficient_of_determination: 0.9990 - val_loss: 0.0217 - val_mean_absolute_error: 0.0217 - val_mean_squared_error: 5.1216e-04 - val_root_mean_squared_error: 0.0226 - val_coefficient_of_determination: -0.4823
# Epoch 9/16
# 138/138 [==============================] - 11s 82ms/step - loss: 0.0064 - mean_absolute_error: 0.0064 - mean_squared_error: 7.5589e-05 - root_mean_squared_error: 0.0087 - coefficient_of_determination: 0.9985 - val_loss: 0.0083 - val_mean_absolute_error: 0.0083 - val_mean_squared_error: 9.2382e-05 - val_root_mean_squared_error: 0.0096 - val_coefficient_of_determination: 0.7468
# Epoch 10/16
# 138/138 [==============================] - 11s 82ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - mean_squared_error: 4.8645e-05 - root_mean_squared_error: 0.0070 - coefficient_of_determination: 0.9990 - val_loss: 0.0124 - val_mean_absolute_error: 0.0124 - val_mean_squared_error: 1.8915e-04 - val_root_mean_squared_error: 0.0138 - val_coefficient_of_determination: 0.4340
# Epoch 11/16
# 138/138 [==============================] - 11s 83ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - mean_squared_error: 2.9220e-05 - root_mean_squared_error: 0.0054 - coefficient_of_determination: 0.9994 - val_loss: 0.0323 - val_mean_absolute_error: 0.0323 - val_mean_squared_error: 0.0011 - val_root_mean_squared_error: 0.0329 - val_coefficient_of_determination: -2.2144
# Epoch 12/16
# 138/138 [==============================] - 12s 88ms/step - loss: 0.0065 - mean_absolute_error: 0.0065 - mean_squared_error: 8.6183e-05 - root_mean_squared_error: 0.0093 - coefficient_of_determination: 0.9984 - val_loss: 0.0188 - val_mean_absolute_error: 0.0188 - val_mean_squared_error: 3.9171e-04 - val_root_mean_squared_error: 0.0198 - val_coefficient_of_determination: -0.1428
# Epoch 13/16
# 138/138 [==============================] - 12s 88ms/step - loss: 0.0041 - mean_absolute_error: 0.0041 - mean_squared_error: 3.3764e-05 - root_mean_squared_error: 0.0058 - coefficient_of_determination: 0.9993 - val_loss: 0.0175 - val_mean_absolute_error: 0.0175 - val_mean_squared_error: 3.3755e-04 - val_root_mean_squared_error: 0.0184 - val_coefficient_of_determination: 0.0206
# Epoch 14/16
# 138/138 [==============================] - 12s 90ms/step - loss: 0.0048 - mean_absolute_error: 0.0048 - mean_squared_error: 3.9651e-05 - root_mean_squared_error: 0.0063 - coefficient_of_determination: 0.9993 - val_loss: 0.0226 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 5.4624e-04 - val_root_mean_squared_error: 0.0234 - val_coefficient_of_determination: -0.6715
# Epoch 15/16
# 138/138 [==============================] - 12s 89ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - mean_squared_error: 2.7762e-05 - root_mean_squared_error: 0.0053 - coefficient_of_determination: 0.9995 - val_loss: 0.0099 - val_mean_absolute_error: 0.0099 - val_mean_squared_error: 1.2718e-04 - val_root_mean_squared_error: 0.0113 - val_coefficient_of_determination: 0.6137
# Epoch 16/16
# 138/138 [==============================] - 12s 83ms/step - loss: 0.0043 - mean_absolute_error: 0.0043 - mean_squared_error: 3.5671e-05 - root_mean_squared_error: 0.0060 - coefficient_of_determination: 0.9993 - val_loss: 0.0109 - val_mean_absolute_error: 0.0109 - val_mean_squared_error: 1.4386e-04 - val_root_mean_squared_error: 0.0120 - val_coefficient_of_determination: 0.5852
# Epoch 1/12
# 138/138 [==============================] - 12s 89ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 4.7815e-06 - root_mean_squared_error: 0.0022 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 3.1940e-05 - val_root_mean_squared_error: 0.0057 - val_coefficient_of_determination: 0.9194
# Epoch 2/12
# 138/138 [==============================] - 12s 84ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 3.8174e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047 - val_mean_squared_error: 3.4771e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9120
# Epoch 3/12
# 138/138 [==============================] - 14s 98ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 3.9366e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 2.9927e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9245
# Epoch 4/12
# 138/138 [==============================] - 14s 103ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.7551e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 3.0300e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9200
# Epoch 5/12
# 138/138 [==============================] - 12s 87ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.7493e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 3.0881e-05 - val_root_mean_squared_error: 0.0056 - val_coefficient_of_determination: 0.9225
# Epoch 6/12
# 138/138 [==============================] - 11s 78ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 4.0714e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045 - val_mean_squared_error: 3.5352e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9021
# Epoch 7/12
# 138/138 [==============================] - 10s 72ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 3.9422e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 2.8055e-05 - val_root_mean_squared_error: 0.0053 - val_coefficient_of_determination: 0.9293
# Epoch 8/12
# 138/138 [==============================] - 13s 91ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 3.8245e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 2.9996e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9252
# Epoch 9/12
# 138/138 [==============================] - 13s 91ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 3.7366e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 2.8587e-05 - val_root_mean_squared_error: 0.0053 - val_coefficient_of_determination: 0.9288
# Epoch 10/12
# 138/138 [==============================] - 13s 92ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 3.8809e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 2.9812e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9209
# Epoch 11/12
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.5973e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 4.7005e-05 - val_root_mean_squared_error: 0.0069 - val_coefficient_of_determination: 0.8785
# Epoch 12/12
# 138/138 [==============================] - 12s 90ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 3.6642e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 3.3932e-05 - val_root_mean_squared_error: 0.0058 - val_coefficient_of_determination: 0.9061
# Epoch 1/8
# 138/138 [==============================] - 12s 90ms/step - loss: 0.0010 - mean_absolute_error: 0.0010 - mean_squared_error: 3.2568e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 2.7493e-05 - val_root_mean_squared_error: 0.0052 - val_coefficient_of_determination: 0.9314
# Epoch 2/8
# 138/138 [==============================] - 14s 99ms/step - loss: 9.7868e-04 - mean_absolute_error: 9.7868e-04 - mean_squared_error: 3.1437e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 2.7086e-05 - val_root_mean_squared_error: 0.0052 - val_coefficient_of_determination: 0.9308
# Epoch 3/8
# 138/138 [==============================] - 22s 157ms/step - loss: 9.7514e-04 - mean_absolute_error: 9.7514e-04 - mean_squared_error: 3.1501e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 2.7289e-05 - val_root_mean_squared_error: 0.0052 - val_coefficient_of_determination: 0.9318
# Epoch 4/8
# 138/138 [==============================] - 14s 100ms/step - loss: 9.6893e-04 - mean_absolute_error: 9.6893e-04 - mean_squared_error: 3.1180e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 2.7807e-05 - val_root_mean_squared_error: 0.0053 - val_coefficient_of_determination: 0.9308
# Epoch 5/8
# 138/138 [==============================] - 12s 89ms/step - loss: 9.6632e-04 - mean_absolute_error: 9.6632e-04 - mean_squared_error: 3.1004e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 2.7507e-05 - val_root_mean_squared_error: 0.0052 - val_coefficient_of_determination: 0.9314
# Epoch 6/8
# 138/138 [==============================] - 12s 88ms/step - loss: 9.7072e-04 - mean_absolute_error: 9.7072e-04 - mean_squared_error: 3.1108e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 2.6921e-05 - val_root_mean_squared_error: 0.0052 - val_coefficient_of_determination: 0.9320
# Epoch 7/8
# 138/138 [==============================] - 13s 96ms/step - loss: 9.6366e-04 - mean_absolute_error: 9.6366e-04 - mean_squared_error: 3.1250e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 2.6930e-05 - val_root_mean_squared_error: 0.0052 - val_coefficient_of_determination: 0.9322
# Epoch 8/8
# 138/138 [==============================] - 22s 158ms/step - loss: 9.5966e-04 - mean_absolute_error: 9.5966e-04 - mean_squared_error: 3.0888e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 2.6884e-05 - val_root_mean_squared_error: 0.0052 - val_coefficient_of_determination: 0.9319

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 4/4 [==============================] - 1s 32ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]

# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted S&P 500 Open Price ($)")
plt.plot(y_test, color='blue', label="Actual S&P 500 Open Price ($)")
plt.title('S&P 500 Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('S&P 500 Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.0009596552117727697
# Mean Squared Error (MSE): 3.088816129093175e-06
# Root Mean Squared Error (RMSE): 0.0017575027886778116
# Coefficient of Determination (R2): 0.9999432563781738

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.003954475745558739
# Validation Mean Squared Error (MSE): 2.6884292310569435e-05
# Validation Root Mean Squared Error (RMSE): 0.0051850066520273685
# Validation Coefficient of Determination (R2): 0.9318821430206299

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 125 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $84268.42136022006
# Balance Percentage Change: 8.426842136022007%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $19961967.84708542
# Balance Percentage Change: 19.96196784708542%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $247775.01394355623
# Balance Percentage Change: 24.77750139435562%
# ----------------------------------------------------------------
