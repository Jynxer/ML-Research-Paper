# %% [markdown]
# # HSI Price Prediction LSTM with Wavelet Transforms

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/HSI.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingData.shape[0]):
    X_train.append(trainingData[i-exposureSize:i])
    y_train.append(trainingData[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (3821, 365, 5)
# (3821,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(testInputsNormalised[i-exposureSize:i])
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (119, 365, 5)
# (119,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./WaveletHSIModel.png', show_shapes=True)
# Out:
# 2022-08-17 15:08:26.838749: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                11200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 11,251
# Trainable params: 11,251
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
historyOne = model.fit(X_train, y_train, epochs=16, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=12, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=8, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 120/120 [==============================] - 23s 177ms/step - loss: 0.0201 - mean_absolute_error: 0.0201 - mean_squared_error: 0.0020 - root_mean_squared_error: 0.0445 - coefficient_of_determination: 0.9467 - val_loss: 0.0175 - val_mean_absolute_error: 0.0175 - val_mean_squared_error: 4.2543e-04 - val_root_mean_squared_error: 0.0206 - val_coefficient_of_determination: 0.4299
# Epoch 2/16
# 120/120 [==============================] - 14s 118ms/step - loss: 0.0095 - mean_absolute_error: 0.0095 - mean_squared_error: 1.7869e-04 - root_mean_squared_error: 0.0134 - coefficient_of_determination: 0.9949 - val_loss: 0.0306 - val_mean_absolute_error: 0.0306 - val_mean_squared_error: 0.0010 - val_root_mean_squared_error: 0.0322 - val_coefficient_of_determination: -0.6830
# Epoch 3/16
# 120/120 [==============================] - 13s 111ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - mean_squared_error: 3.2052e-04 - root_mean_squared_error: 0.0179 - coefficient_of_determination: 0.9906 - val_loss: 0.0116 - val_mean_absolute_error: 0.0116 - val_mean_squared_error: 1.9643e-04 - val_root_mean_squared_error: 0.0140 - val_coefficient_of_determination: 0.7209
# Epoch 4/16
# 120/120 [==============================] - 11s 94ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - mean_squared_error: 1.0824e-04 - root_mean_squared_error: 0.0104 - coefficient_of_determination: 0.9968 - val_loss: 0.0151 - val_mean_absolute_error: 0.0151 - val_mean_squared_error: 2.9133e-04 - val_root_mean_squared_error: 0.0171 - val_coefficient_of_determination: 0.5733
# Epoch 5/16
# 120/120 [==============================] - 11s 88ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - mean_squared_error: 1.0118e-04 - root_mean_squared_error: 0.0101 - coefficient_of_determination: 0.9971 - val_loss: 0.0365 - val_mean_absolute_error: 0.0365 - val_mean_squared_error: 0.0014 - val_root_mean_squared_error: 0.0379 - val_coefficient_of_determination: -1.1714
# Epoch 6/16
# 120/120 [==============================] - 10s 85ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - mean_squared_error: 1.2049e-04 - root_mean_squared_error: 0.0110 - coefficient_of_determination: 0.9965 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092 - val_mean_squared_error: 1.3919e-04 - val_root_mean_squared_error: 0.0118 - val_coefficient_of_determination: 0.7782
# Epoch 7/16
# 120/120 [==============================] - 11s 88ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - mean_squared_error: 1.1052e-04 - root_mean_squared_error: 0.0105 - coefficient_of_determination: 0.9968 - val_loss: 0.0112 - val_mean_absolute_error: 0.0112 - val_mean_squared_error: 1.8070e-04 - val_root_mean_squared_error: 0.0134 - val_coefficient_of_determination: 0.7239
# Epoch 8/16
# 120/120 [==============================] - 10s 87ms/step - loss: 0.0089 - mean_absolute_error: 0.0089 - mean_squared_error: 1.4485e-04 - root_mean_squared_error: 0.0120 - coefficient_of_determination: 0.9959 - val_loss: 0.0076 - val_mean_absolute_error: 0.0076 - val_mean_squared_error: 9.6685e-05 - val_root_mean_squared_error: 0.0098 - val_coefficient_of_determination: 0.8521
# Epoch 9/16
# 120/120 [==============================] - 11s 89ms/step - loss: 0.0064 - mean_absolute_error: 0.0064 - mean_squared_error: 8.2660e-05 - root_mean_squared_error: 0.0091 - coefficient_of_determination: 0.9976 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104 - val_mean_squared_error: 1.6927e-04 - val_root_mean_squared_error: 0.0130 - val_coefficient_of_determination: 0.7389
# Epoch 10/16
# 120/120 [==============================] - 11s 88ms/step - loss: 0.0050 - mean_absolute_error: 0.0050 - mean_squared_error: 5.4981e-05 - root_mean_squared_error: 0.0074 - coefficient_of_determination: 0.9983 - val_loss: 0.0109 - val_mean_absolute_error: 0.0109 - val_mean_squared_error: 1.8619e-04 - val_root_mean_squared_error: 0.0136 - val_coefficient_of_determination: 0.7143
# Epoch 11/16
# 120/120 [==============================] - 11s 92ms/step - loss: 0.0061 - mean_absolute_error: 0.0061 - mean_squared_error: 6.6833e-05 - root_mean_squared_error: 0.0082 - coefficient_of_determination: 0.9981 - val_loss: 0.0136 - val_mean_absolute_error: 0.0136 - val_mean_squared_error: 2.5591e-04 - val_root_mean_squared_error: 0.0160 - val_coefficient_of_determination: 0.6064
# Epoch 12/16
# 120/120 [==============================] - 11s 93ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 6.0620e-05 - root_mean_squared_error: 0.0078 - coefficient_of_determination: 0.9982 - val_loss: 0.0079 - val_mean_absolute_error: 0.0079 - val_mean_squared_error: 9.9656e-05 - val_root_mean_squared_error: 0.0100 - val_coefficient_of_determination: 0.8476
# Epoch 13/16
# 120/120 [==============================] - 12s 99ms/step - loss: 0.0046 - mean_absolute_error: 0.0046 - mean_squared_error: 4.4923e-05 - root_mean_squared_error: 0.0067 - coefficient_of_determination: 0.9987 - val_loss: 0.0082 - val_mean_absolute_error: 0.0082 - val_mean_squared_error: 1.1021e-04 - val_root_mean_squared_error: 0.0105 - val_coefficient_of_determination: 0.8338
# Epoch 14/16
# 120/120 [==============================] - 12s 97ms/step - loss: 0.0078 - mean_absolute_error: 0.0078 - mean_squared_error: 1.0173e-04 - root_mean_squared_error: 0.0101 - coefficient_of_determination: 0.9971 - val_loss: 0.0113 - val_mean_absolute_error: 0.0113 - val_mean_squared_error: 1.9262e-04 - val_root_mean_squared_error: 0.0139 - val_coefficient_of_determination: 0.7077
# Epoch 15/16
# 120/120 [==============================] - 11s 91ms/step - loss: 0.0059 - mean_absolute_error: 0.0059 - mean_squared_error: 6.5719e-05 - root_mean_squared_error: 0.0081 - coefficient_of_determination: 0.9981 - val_loss: 0.0114 - val_mean_absolute_error: 0.0114 - val_mean_squared_error: 1.9665e-04 - val_root_mean_squared_error: 0.0140 - val_coefficient_of_determination: 0.7016
# Epoch 16/16
# 120/120 [==============================] - 11s 89ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - mean_squared_error: 3.3526e-05 - root_mean_squared_error: 0.0058 - coefficient_of_determination: 0.9991 - val_loss: 0.0107 - val_mean_absolute_error: 0.0107 - val_mean_squared_error: 1.7912e-04 - val_root_mean_squared_error: 0.0134 - val_coefficient_of_determination: 0.7305
# Epoch 1/12
# 120/120 [==============================] - 11s 89ms/step - loss: 0.0019 - mean_absolute_error: 0.0019 - mean_squared_error: 1.4168e-05 - root_mean_squared_error: 0.0038 - coefficient_of_determination: 0.9996 - val_loss: 0.0090 - val_mean_absolute_error: 0.0090 - val_mean_squared_error: 1.2463e-04 - val_root_mean_squared_error: 0.0112 - val_coefficient_of_determination: 0.8124
# Epoch 2/12
# 120/120 [==============================] - 11s 89ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 8.8192e-06 - root_mean_squared_error: 0.0030 - coefficient_of_determination: 0.9997 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092 - val_mean_squared_error: 1.2932e-04 - val_root_mean_squared_error: 0.0114 - val_coefficient_of_determination: 0.8048
# Epoch 3/12
# 120/120 [==============================] - 11s 89ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 8.5792e-06 - root_mean_squared_error: 0.0029 - coefficient_of_determination: 0.9998 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092 - val_mean_squared_error: 1.2932e-04 - val_root_mean_squared_error: 0.0114 - val_coefficient_of_determination: 0.8057
# Epoch 4/12
# 120/120 [==============================] - 11s 90ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 8.4621e-06 - root_mean_squared_error: 0.0029 - coefficient_of_determination: 0.9998 - val_loss: 0.0093 - val_mean_absolute_error: 0.0093 - val_mean_squared_error: 1.3280e-04 - val_root_mean_squared_error: 0.0115 - val_coefficient_of_determination: 0.8008
# Epoch 5/12
# 120/120 [==============================] - 11s 90ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 8.4687e-06 - root_mean_squared_error: 0.0029 - coefficient_of_determination: 0.9997 - val_loss: 0.0094 - val_mean_absolute_error: 0.0094 - val_mean_squared_error: 1.3554e-04 - val_root_mean_squared_error: 0.0116 - val_coefficient_of_determination: 0.7972
# Epoch 6/12
# 120/120 [==============================] - 11s 91ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 8.2890e-06 - root_mean_squared_error: 0.0029 - coefficient_of_determination: 0.9998 - val_loss: 0.0095 - val_mean_absolute_error: 0.0095 - val_mean_squared_error: 1.3805e-04 - val_root_mean_squared_error: 0.0117 - val_coefficient_of_determination: 0.7938
# Epoch 7/12
# 120/120 [==============================] - 11s 93ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 8.3811e-06 - root_mean_squared_error: 0.0029 - coefficient_of_determination: 0.9998 - val_loss: 0.0097 - val_mean_absolute_error: 0.0097 - val_mean_squared_error: 1.4237e-04 - val_root_mean_squared_error: 0.0119 - val_coefficient_of_determination: 0.7871
# Epoch 8/12
# 120/120 [==============================] - 11s 93ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 8.2170e-06 - root_mean_squared_error: 0.0029 - coefficient_of_determination: 0.9998 - val_loss: 0.0096 - val_mean_absolute_error: 0.0096 - val_mean_squared_error: 1.4343e-04 - val_root_mean_squared_error: 0.0120 - val_coefficient_of_determination: 0.7862
# Epoch 9/12
# 120/120 [==============================] - 11s 94ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 8.2565e-06 - root_mean_squared_error: 0.0029 - coefficient_of_determination: 0.9998 - val_loss: 0.0098 - val_mean_absolute_error: 0.0098 - val_mean_squared_error: 1.4657e-04 - val_root_mean_squared_error: 0.0121 - val_coefficient_of_determination: 0.7816
# Epoch 10/12
# 120/120 [==============================] - 11s 92ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 8.0860e-06 - root_mean_squared_error: 0.0028 - coefficient_of_determination: 0.9998 - val_loss: 0.0100 - val_mean_absolute_error: 0.0100 - val_mean_squared_error: 1.5065e-04 - val_root_mean_squared_error: 0.0123 - val_coefficient_of_determination: 0.7770
# Epoch 11/12
# 120/120 [==============================] - 11s 88ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 8.1537e-06 - root_mean_squared_error: 0.0029 - coefficient_of_determination: 0.9998 - val_loss: 0.0099 - val_mean_absolute_error: 0.0099 - val_mean_squared_error: 1.5270e-04 - val_root_mean_squared_error: 0.0124 - val_coefficient_of_determination: 0.7746
# Epoch 12/12
# 120/120 [==============================] - 13s 108ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 7.8373e-06 - root_mean_squared_error: 0.0028 - coefficient_of_determination: 0.9997 - val_loss: 0.0099 - val_mean_absolute_error: 0.0099 - val_mean_squared_error: 1.5500e-04 - val_root_mean_squared_error: 0.0125 - val_coefficient_of_determination: 0.7718
# Epoch 1/8
# 120/120 [==============================] - 23s 190ms/step - loss: 9.4932e-04 - mean_absolute_error: 9.4932e-04 - mean_squared_error: 7.4473e-06 - root_mean_squared_error: 0.0027 - coefficient_of_determination: 0.9998 - val_loss: 0.0101 - val_mean_absolute_error: 0.0101 - val_mean_squared_error: 1.5522e-04 - val_root_mean_squared_error: 0.0125 - val_coefficient_of_determination: 0.7716
# Epoch 2/8
# 120/120 [==============================] - 17s 144ms/step - loss: 9.3735e-04 - mean_absolute_error: 9.3735e-04 - mean_squared_error: 7.4415e-06 - root_mean_squared_error: 0.0027 - coefficient_of_determination: 0.9998 - val_loss: 0.0101 - val_mean_absolute_error: 0.0101 - val_mean_squared_error: 1.5609e-04 - val_root_mean_squared_error: 0.0125 - val_coefficient_of_determination: 0.7704
# Epoch 3/8
# 120/120 [==============================] - 11s 88ms/step - loss: 9.4993e-04 - mean_absolute_error: 9.4993e-04 - mean_squared_error: 7.5224e-06 - root_mean_squared_error: 0.0027 - coefficient_of_determination: 0.9998 - val_loss: 0.0101 - val_mean_absolute_error: 0.0101 - val_mean_squared_error: 1.5625e-04 - val_root_mean_squared_error: 0.0125 - val_coefficient_of_determination: 0.7701
# Epoch 4/8
# 120/120 [==============================] - 10s 82ms/step - loss: 9.4711e-04 - mean_absolute_error: 9.4711e-04 - mean_squared_error: 7.4746e-06 - root_mean_squared_error: 0.0027 - coefficient_of_determination: 0.9998 - val_loss: 0.0101 - val_mean_absolute_error: 0.0101 - val_mean_squared_error: 1.5613e-04 - val_root_mean_squared_error: 0.0125 - val_coefficient_of_determination: 0.7705
# Epoch 5/8
# 120/120 [==============================] - 10s 80ms/step - loss: 9.3758e-04 - mean_absolute_error: 9.3758e-04 - mean_squared_error: 7.4546e-06 - root_mean_squared_error: 0.0027 - coefficient_of_determination: 0.9998 - val_loss: 0.0101 - val_mean_absolute_error: 0.0101 - val_mean_squared_error: 1.5634e-04 - val_root_mean_squared_error: 0.0125 - val_coefficient_of_determination: 0.7703
# Epoch 6/8
# 120/120 [==============================] - 10s 80ms/step - loss: 9.5604e-04 - mean_absolute_error: 9.5604e-04 - mean_squared_error: 7.4386e-06 - root_mean_squared_error: 0.0027 - coefficient_of_determination: 0.9998 - val_loss: 0.0101 - val_mean_absolute_error: 0.0101 - val_mean_squared_error: 1.5675e-04 - val_root_mean_squared_error: 0.0125 - val_coefficient_of_determination: 0.7700
# Epoch 7/8
# 120/120 [==============================] - 10s 80ms/step - loss: 9.3037e-04 - mean_absolute_error: 9.3037e-04 - mean_squared_error: 7.4170e-06 - root_mean_squared_error: 0.0027 - coefficient_of_determination: 0.9996 - val_loss: 0.0101 - val_mean_absolute_error: 0.0101 - val_mean_squared_error: 1.5751e-04 - val_root_mean_squared_error: 0.0126 - val_coefficient_of_determination: 0.7689
# Epoch 8/8
# 120/120 [==============================] - 10s 80ms/step - loss: 9.2511e-04 - mean_absolute_error: 9.2511e-04 - mean_squared_error: 7.3744e-06 - root_mean_squared_error: 0.0027 - coefficient_of_determination: 0.9998 - val_loss: 0.0101 - val_mean_absolute_error: 0.0101 - val_mean_squared_error: 1.5785e-04 - val_root_mean_squared_error: 0.0126 - val_coefficient_of_determination: 0.7684

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 4/4 [==============================] - 1s 22ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted HSI Open Price ($)")
plt.plot(y_test, color='blue', label="Actual HSI Open Price ($)")
plt.title('HSI Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('HSI Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.0009251128067262471
# Mean Squared Error (MSE): 7.374360393441748e-06
# Root Mean Squared Error (RMSE): 0.002715577371418476
# Coefficient of Determination (R2): 0.9998140931129456

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.010133990086615086
# Validation Mean Squared Error (MSE): 0.00015784965944476426
# Validation Root Mean Squared Error (RMSE): 0.012563823722302914
# Validation Coefficient of Determination (R2): 0.7684305906295776

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 119 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $11470.399483500281
# Balance Percentage Change: 1.147039948350028%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $97911.12813486453
# Balance Percentage Change: 9.791112813486452%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $273397.0664445455
# Balance Percentage Change: 27.33970664445455%
# ----------------------------------------------------------------
