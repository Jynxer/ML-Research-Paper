# %% [markdown]
# # S&P 500 Price Prediction LSTM with New Input using Wavelet Transforms

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/S&P500.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingDataNormalised.shape[0]):
    X_train.append(np.concatenate([trainingDataNormalised[i-exposureSize:i], trainingData[i-exposureSize:i]], axis=1))
    y_train.append(trainingDataNormalised[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (4414, 365, 10)
# (4414,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)
testInputsTransformed = np.array(WaveletTransform(testInputsNormalised, 3))

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(np.concatenate([testInputsNormalised[i-exposureSize:i], testInputsTransformed[i-exposureSize:i]], axis=1))
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (125, 365, 10)
# (125,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./WaveletSP500Model.png', show_shapes=True)
# Out:
# 2022-08-18 13:00:51.156911: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                12200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 12,251
# Trainable params: 12,251
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
historyOne = model.fit(X_train, y_train, epochs=16, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=12, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=8, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 138/138 [==============================] - 23s 156ms/step - loss: 0.0269 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0049 - root_mean_squared_error: 0.0699 - coefficient_of_determination: 0.9205 - val_loss: 0.0267 - val_mean_absolute_error: 0.0267 - val_mean_squared_error: 8.1135e-04 - val_root_mean_squared_error: 0.0285 - val_coefficient_of_determination: -1.3099
# Epoch 2/16
# 138/138 [==============================] - 24s 172ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - mean_squared_error: 2.1246e-04 - root_mean_squared_error: 0.0146 - coefficient_of_determination: 0.9959 - val_loss: 0.0647 - val_mean_absolute_error: 0.0647 - val_mean_squared_error: 0.0043 - val_root_mean_squared_error: 0.0654 - val_coefficient_of_determination: -11.6306
# Epoch 3/16
# 138/138 [==============================] - 16s 116ms/step - loss: 0.0089 - mean_absolute_error: 0.0089 - mean_squared_error: 1.5945e-04 - root_mean_squared_error: 0.0126 - coefficient_of_determination: 0.9968 - val_loss: 0.0156 - val_mean_absolute_error: 0.0156 - val_mean_squared_error: 3.1212e-04 - val_root_mean_squared_error: 0.0177 - val_coefficient_of_determination: 0.1514
# Epoch 4/16
# 138/138 [==============================] - 11s 82ms/step - loss: 0.0065 - mean_absolute_error: 0.0065 - mean_squared_error: 7.8411e-05 - root_mean_squared_error: 0.0089 - coefficient_of_determination: 0.9985 - val_loss: 0.0145 - val_mean_absolute_error: 0.0145 - val_mean_squared_error: 2.6751e-04 - val_root_mean_squared_error: 0.0164 - val_coefficient_of_determination: 0.2970
# Epoch 5/16
# 138/138 [==============================] - 11s 76ms/step - loss: 0.0065 - mean_absolute_error: 0.0065 - mean_squared_error: 7.4601e-05 - root_mean_squared_error: 0.0086 - coefficient_of_determination: 0.9986 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051 - val_mean_squared_error: 5.0969e-05 - val_root_mean_squared_error: 0.0071 - val_coefficient_of_determination: 0.8757
# Epoch 6/16
# 138/138 [==============================] - 10s 75ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - mean_squared_error: 9.7674e-05 - root_mean_squared_error: 0.0099 - coefficient_of_determination: 0.9982 - val_loss: 0.0189 - val_mean_absolute_error: 0.0189 - val_mean_squared_error: 4.0590e-04 - val_root_mean_squared_error: 0.0201 - val_coefficient_of_determination: -0.1513
# Epoch 7/16
# 138/138 [==============================] - 11s 76ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - mean_squared_error: 9.6586e-05 - root_mean_squared_error: 0.0098 - coefficient_of_determination: 0.9981 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050 - val_mean_squared_error: 5.2024e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.8815
# Epoch 8/16
# 138/138 [==============================] - 11s 78ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - mean_squared_error: 6.0720e-05 - root_mean_squared_error: 0.0078 - coefficient_of_determination: 0.9988 - val_loss: 0.0080 - val_mean_absolute_error: 0.0080 - val_mean_squared_error: 9.1817e-05 - val_root_mean_squared_error: 0.0096 - val_coefficient_of_determination: 0.7254
# Epoch 9/16
# 138/138 [==============================] - 11s 78ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - mean_squared_error: 2.9943e-05 - root_mean_squared_error: 0.0055 - coefficient_of_determination: 0.9994 - val_loss: 0.0357 - val_mean_absolute_error: 0.0357 - val_mean_squared_error: 0.0013 - val_root_mean_squared_error: 0.0362 - val_coefficient_of_determination: -3.0387
# Epoch 10/16
# 138/138 [==============================] - 11s 78ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - mean_squared_error: 4.9907e-05 - root_mean_squared_error: 0.0071 - coefficient_of_determination: 0.9990 - val_loss: 0.0196 - val_mean_absolute_error: 0.0196 - val_mean_squared_error: 4.1802e-04 - val_root_mean_squared_error: 0.0204 - val_coefficient_of_determination: -0.2866
# Epoch 11/16
# 138/138 [==============================] - 11s 78ms/step - loss: 0.0086 - mean_absolute_error: 0.0086 - mean_squared_error: 1.4647e-04 - root_mean_squared_error: 0.0121 - coefficient_of_determination: 0.9972 - val_loss: 0.0115 - val_mean_absolute_error: 0.0115 - val_mean_squared_error: 1.6872e-04 - val_root_mean_squared_error: 0.0130 - val_coefficient_of_determination: 0.5433
# Epoch 12/16
# 138/138 [==============================] - 11s 78ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - mean_squared_error: 2.8874e-05 - root_mean_squared_error: 0.0054 - coefficient_of_determination: 0.9994 - val_loss: 0.0070 - val_mean_absolute_error: 0.0070 - val_mean_squared_error: 7.3313e-05 - val_root_mean_squared_error: 0.0086 - val_coefficient_of_determination: 0.8112
# Epoch 13/16
# 138/138 [==============================] - 11s 79ms/step - loss: 0.0042 - mean_absolute_error: 0.0042 - mean_squared_error: 3.4801e-05 - root_mean_squared_error: 0.0059 - coefficient_of_determination: 0.9993 - val_loss: 0.0163 - val_mean_absolute_error: 0.0163 - val_mean_squared_error: 3.0286e-04 - val_root_mean_squared_error: 0.0174 - val_coefficient_of_determination: 0.1351
# Epoch 14/16
# 138/138 [==============================] - 11s 78ms/step - loss: 0.0055 - mean_absolute_error: 0.0055 - mean_squared_error: 5.2268e-05 - root_mean_squared_error: 0.0072 - coefficient_of_determination: 0.9990 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 6.0557e-05 - val_root_mean_squared_error: 0.0078 - val_coefficient_of_determination: 0.8516
# Epoch 15/16
# 138/138 [==============================] - 11s 79ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - mean_squared_error: 2.9148e-05 - root_mean_squared_error: 0.0054 - coefficient_of_determination: 0.9994 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 5.5926e-05 - val_root_mean_squared_error: 0.0075 - val_coefficient_of_determination: 0.8658
# Epoch 16/16
# 138/138 [==============================] - 11s 79ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - mean_squared_error: 3.0225e-05 - root_mean_squared_error: 0.0055 - coefficient_of_determination: 0.9994 - val_loss: 0.0099 - val_mean_absolute_error: 0.0099 - val_mean_squared_error: 1.2488e-04 - val_root_mean_squared_error: 0.0112 - val_coefficient_of_determination: 0.6214
# Epoch 1/12
# 138/138 [==============================] - 11s 80ms/step - loss: 0.0016 - mean_absolute_error: 0.0016 - mean_squared_error: 6.2057e-06 - root_mean_squared_error: 0.0025 - coefficient_of_determination: 0.9999 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 3.7661e-05 - val_root_mean_squared_error: 0.0061 - val_coefficient_of_determination: 0.9114
# Epoch 2/12
# 138/138 [==============================] - 11s 81ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 4.4639e-06 - root_mean_squared_error: 0.0021 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 3.8284e-05 - val_root_mean_squared_error: 0.0062 - val_coefficient_of_determination: 0.9109
# Epoch 3/12
# 138/138 [==============================] - 11s 80ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 3.9337e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 3.7544e-05 - val_root_mean_squared_error: 0.0061 - val_coefficient_of_determination: 0.9125
# Epoch 4/12
# 138/138 [==============================] - 11s 81ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 3.9360e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 3.4800e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9134
# Epoch 5/12
# 138/138 [==============================] - 11s 82ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 3.9896e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 3.6975e-05 - val_root_mean_squared_error: 0.0061 - val_coefficient_of_determination: 0.9136
# Epoch 6/12
# 138/138 [==============================] - 11s 82ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 3.7761e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 3.2982e-05 - val_root_mean_squared_error: 0.0057 - val_coefficient_of_determination: 0.9200
# Epoch 7/12
# 138/138 [==============================] - 11s 82ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.6354e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045 - val_mean_squared_error: 3.8394e-05 - val_root_mean_squared_error: 0.0062 - val_coefficient_of_determination: 0.8987
# Epoch 8/12
# 138/138 [==============================] - 11s 83ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 4.0773e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 3.1826e-05 - val_root_mean_squared_error: 0.0056 - val_coefficient_of_determination: 0.9238
# Epoch 9/12
# 138/138 [==============================] - 11s 82ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 3.6602e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 3.4056e-05 - val_root_mean_squared_error: 0.0058 - val_coefficient_of_determination: 0.9209
# Epoch 10/12
# 138/138 [==============================] - 11s 82ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 4.0647e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042 - val_mean_squared_error: 3.4324e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9112
# Epoch 11/12
# 138/138 [==============================] - 11s 82ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.5984e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 3.1856e-05 - val_root_mean_squared_error: 0.0056 - val_coefficient_of_determination: 0.9264
# Epoch 12/12
# 138/138 [==============================] - 12s 83ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.5263e-06 - root_mean_squared_error: 0.0019 - coefficient_of_determination: 0.9999 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 3.0812e-05 - val_root_mean_squared_error: 0.0056 - val_coefficient_of_determination: 0.9257
# Epoch 1/8
# 138/138 [==============================] - 12s 83ms/step - loss: 9.7244e-04 - mean_absolute_error: 9.7244e-04 - mean_squared_error: 3.0778e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 3.0518e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9278
# Epoch 2/8
# 138/138 [==============================] - 11s 82ms/step - loss: 9.6129e-04 - mean_absolute_error: 9.6129e-04 - mean_squared_error: 3.0257e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 3.0681e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9263
# Epoch 3/8
# 138/138 [==============================] - 12s 84ms/step - loss: 9.5959e-04 - mean_absolute_error: 9.5959e-04 - mean_squared_error: 3.0336e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 3.1056e-05 - val_root_mean_squared_error: 0.0056 - val_coefficient_of_determination: 0.9280
# Epoch 4/8
# 138/138 [==============================] - 11s 83ms/step - loss: 9.6292e-04 - mean_absolute_error: 9.6292e-04 - mean_squared_error: 3.0588e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 3.0392e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9283
# Epoch 5/8
# 138/138 [==============================] - 12s 86ms/step - loss: 9.6245e-04 - mean_absolute_error: 9.6245e-04 - mean_squared_error: 3.0593e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 3.0675e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9285
# Epoch 6/8
# 138/138 [==============================] - 12s 86ms/step - loss: 9.5710e-04 - mean_absolute_error: 9.5710e-04 - mean_squared_error: 3.0159e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 3.0465e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9286
# Epoch 7/8
# 138/138 [==============================] - 12s 85ms/step - loss: 9.5732e-04 - mean_absolute_error: 9.5732e-04 - mean_squared_error: 3.0641e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 3.0297e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9285
# Epoch 8/8
# 138/138 [==============================] - 12s 84ms/step - loss: 9.5548e-04 - mean_absolute_error: 9.5548e-04 - mean_squared_error: 2.9912e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0039 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 3.0350e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9288

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 4/4 [==============================] - 1s 24ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted S&P 500 Open Price ($)")
plt.plot(y_test, color='blue', label="Actual S&P 500 Open Price ($)")
plt.title('S&P 500 Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('S&P 500 Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, 16, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(16, 16+12, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(16+12, 16+12+8, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, 16+12+8)
plt.xticks([2*i for i in range(int((16+12+8)/2))], [(2*j)+1 for j in range(int((16+12+8)/2))])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.0009554775315336883
# Mean Squared Error (MSE): 2.9912478112237295e-06
# Root Mean Squared Error (RMSE): 0.0017295223660767078
# Coefficient of Determination (R2): 0.9999428391456604

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.003873360576108098
# Validation Mean Squared Error (MSE): 3.035030749742873e-05
# Validation Root Mean Squared Error (RMSE): 0.005509111098945141
# Validation Coefficient of Determination (R2): 0.9288012981414795

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 125 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $76532.09378356556
# Balance Percentage Change: 7.653209378356557%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $199619.67847085418
# Balance Percentage Change: 19.96196784708542%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $240336.69800868584
# Balance Percentage Change: 24.033669800868584%
# ----------------------------------------------------------------
