# %% [markdown]
# # DJIA Price Prediction Stacked LSTM with Wavelet Transforms and an Attention Mechanism

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pywt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from attention import Attention
from keras.optimizers import Adam
from keras import metrics
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)
from keras.utils.vis_utils import plot_model
from keras import backend as K
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("./Datasets/DJIA.csv")

# %% [markdown]
# ### Check Dataset is Clean

# %%
nulls = df.isnull().sum().sum() + df.isna().sum().sum()
boolSeries = df.duplicated().to_numpy()
if ((boolSeries.sum() == 0) and (nulls == 0)):
    print('Dataset is clean!')
else:
    print('Dataset is unclean!')
# Out:
# Dataset is clean!

# %% [markdown]
# ### Split Dataset

# %%
splitDate = '2019-05-16'
trainingDataUnscaled = df[df['Date'] <= splitDate].copy()
trainingDataUnscaled.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %% [markdown]
# ### Data Scaling

# %%
scaler = StandardScaler()
anotherScaler = MinMaxScaler()
trainingDataStandardised = scaler.fit_transform(trainingDataUnscaled)
trainingDataNormalised = anotherScaler.fit_transform(trainingDataStandardised)

# %% [markdown]
# ### Wavelet Transform

# %%
# Three decomposition layers of Coiflet 3 wavelet transform
def WaveletTransform(data, levels, threshold=0.63, wavelet='coif3'):
    reconstructedData = pd.DataFrame()
    for i in range(data.shape[1]):
        threshold = threshold * np.nanmax(data[:,i])
        coefficients = pywt.wavedec(data[:,i], wavelet, mode='per', level=levels)
        coefficients[1:] = (pywt.threshold(i, value=threshold, mode='soft') for i in coefficients[1:])
        reconstructedColumn = pywt.waverec(coefficients, wavelet, mode='per')
        reconstructedData = pd.concat([reconstructedData, pd.DataFrame(reconstructedColumn)], axis=1)
    return reconstructedData

trainingData = np.array(WaveletTransform(trainingDataNormalised, 3))

# %% [markdown]
# ### Build Training Input and Output Series

# %%
exposureSize = 365

X_train = []
y_train = []

for i in range(exposureSize, trainingDataNormalised.shape[0]):
    X_train.append(np.concatenate([trainingDataNormalised[i-exposureSize:i], trainingData[i-exposureSize:i]], axis=1))
    y_train.append(trainingDataNormalised[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (4414, 365, 10)
# (4414,)

# %% [markdown]
# ### Build Test Input and Output Series

# %%
testData = df[df['Date'] > splitDate].copy()
previousDays = trainingDataUnscaled.tail(exposureSize)
testInputs = pd.concat([previousDays, testData], ignore_index=True)
dates = testData['Date'].copy()
testInputs.drop(['Date', 'Adj Close'], axis=1, inplace=True)

testInputsStandardised = scaler.transform(testInputs)
testInputsNormalised = anotherScaler.transform(testInputsStandardised)
testInputsTransformed = np.array(WaveletTransform(testInputsNormalised, 3))

X_test = []
y_test = []

for i in range(exposureSize, testInputs.shape[0]):
    X_test.append(np.concatenate([testInputsNormalised[i-exposureSize:i], testInputsTransformed[i-exposureSize:i]], axis=1))
    y_test.append(testInputsNormalised[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (125, 365, 10)
# (125,)

# %% [markdown]
# ### Coefficient of Determination Function

# %%
# REF: https://jmlb.github.io/ml/2017/03/20/CoeffDetermination_CustomMetric4Keras/
def coefficient_of_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Define Model

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(50, return_sequences=True))
model.add(Attention(units=16))
model.add(Dense(1))
optimiser = Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=optimiser, metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError(), metrics.RootMeanSquaredError(), coefficient_of_determination])
print(model.summary())
plot_model(model, to_file='./StackedDJIAModel.png', show_shapes=True)
# Out:
# 2022-08-18 14:52:43.791089: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 365, 50)           12200
#
#  lstm_1 (LSTM)               (None, 365, 50)           20200
#
#  attention (Attention)       (None, 16)                4100
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 36,517
# Trainable params: 36,517
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train Model

# %%
numEpochsOne = 16
numEpochsTwo = 12
numEpochsThree = 8

historyOne = model.fit(X_train, y_train, epochs=numEpochsOne, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.001)
historyTwo = model.fit(X_train, y_train, epochs=numEpochsTwo, batch_size=32, validation_data=(X_test, y_test), verbose=1)
K.set_value(model.optimizer.learning_rate, 0.0001)
historyThree = model.fit(X_train, y_train, epochs=numEpochsThree, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/16
# 2022-08-18 14:53:08.279222: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 138/138 [==============================] - ETA: 0s - loss: 0.0490 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0119 - root_mean_squared_error: 0.1089 - coefficient_of_determination: 0.7384
# 2022-08-18 14:54:12.809922: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 138/138 [==============================] - 77s 456ms/step - loss: 0.0490 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0119 - root_mean_squared_error: 0.1089 - coefficient_of_determination: 0.7384 - val_loss: 0.0502 - val_mean_absolute_error: 0.0502 - val_mean_squared_error: 0.0027 - val_root_mean_squared_error: 0.0519 - val_coefficient_of_determination: -7.7087
# Epoch 2/16
# 138/138 [==============================] - 53s 386ms/step - loss: 0.0141 - mean_absolute_error: 0.0141 - mean_squared_error: 3.6656e-04 - root_mean_squared_error: 0.0191 - coefficient_of_determination: 0.9920 - val_loss: 0.1208 - val_mean_absolute_error: 0.1208 - val_mean_squared_error: 0.0147 - val_root_mean_squared_error: 0.1213 - val_coefficient_of_determination: -46.1968
# Epoch 3/16
# 138/138 [==============================] - 44s 316ms/step - loss: 0.0147 - mean_absolute_error: 0.0147 - mean_squared_error: 4.6526e-04 - root_mean_squared_error: 0.0216 - coefficient_of_determination: 0.9900 - val_loss: 0.0732 - val_mean_absolute_error: 0.0732 - val_mean_squared_error: 0.0055 - val_root_mean_squared_error: 0.0738 - val_coefficient_of_determination: -16.9977
# Epoch 4/16
# 138/138 [==============================] - 48s 346ms/step - loss: 0.0146 - mean_absolute_error: 0.0146 - mean_squared_error: 4.3936e-04 - root_mean_squared_error: 0.0210 - coefficient_of_determination: 0.9906 - val_loss: 0.0206 - val_mean_absolute_error: 0.0206 - val_mean_squared_error: 4.9065e-04 - val_root_mean_squared_error: 0.0222 - val_coefficient_of_determination: -0.5680
# Epoch 5/16
# 138/138 [==============================] - 34s 242ms/step - loss: 0.0089 - mean_absolute_error: 0.0089 - mean_squared_error: 1.7646e-04 - root_mean_squared_error: 0.0133 - coefficient_of_determination: 0.9964 - val_loss: 0.0103 - val_mean_absolute_error: 0.0103 - val_mean_squared_error: 1.5190e-04 - val_root_mean_squared_error: 0.0123 - val_coefficient_of_determination: 0.5185
# Epoch 6/16
# 138/138 [==============================] - 30s 218ms/step - loss: 0.0099 - mean_absolute_error: 0.0099 - mean_squared_error: 1.9739e-04 - root_mean_squared_error: 0.0140 - coefficient_of_determination: 0.9959 - val_loss: 0.0137 - val_mean_absolute_error: 0.0137 - val_mean_squared_error: 2.4109e-04 - val_root_mean_squared_error: 0.0155 - val_coefficient_of_determination: 0.3193
# Epoch 7/16
# 138/138 [==============================] - 31s 226ms/step - loss: 0.0094 - mean_absolute_error: 0.0094 - mean_squared_error: 1.6588e-04 - root_mean_squared_error: 0.0129 - coefficient_of_determination: 0.9965 - val_loss: 0.0241 - val_mean_absolute_error: 0.0241 - val_mean_squared_error: 6.6090e-04 - val_root_mean_squared_error: 0.0257 - val_coefficient_of_determination: -1.0737
# Epoch 8/16
# 138/138 [==============================] - 34s 244ms/step - loss: 0.0100 - mean_absolute_error: 0.0100 - mean_squared_error: 1.9397e-04 - root_mean_squared_error: 0.0139 - coefficient_of_determination: 0.9959 - val_loss: 0.0072 - val_mean_absolute_error: 0.0072 - val_mean_squared_error: 1.0033e-04 - val_root_mean_squared_error: 0.0100 - val_coefficient_of_determination: 0.7847
# Epoch 9/16
# 138/138 [==============================] - 36s 263ms/step - loss: 0.0096 - mean_absolute_error: 0.0096 - mean_squared_error: 1.9167e-04 - root_mean_squared_error: 0.0138 - coefficient_of_determination: 0.9959 - val_loss: 0.0310 - val_mean_absolute_error: 0.0310 - val_mean_squared_error: 0.0010 - val_root_mean_squared_error: 0.0322 - val_coefficient_of_determination: -2.2666
# Epoch 10/16
# 138/138 [==============================] - 36s 260ms/step - loss: 0.0077 - mean_absolute_error: 0.0077 - mean_squared_error: 1.3120e-04 - root_mean_squared_error: 0.0115 - coefficient_of_determination: 0.9972 - val_loss: 0.0111 - val_mean_absolute_error: 0.0111 - val_mean_squared_error: 1.8659e-04 - val_root_mean_squared_error: 0.0137 - val_coefficient_of_determination: 0.4831
# Epoch 11/16
# 138/138 [==============================] - 36s 257ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - mean_squared_error: 9.9785e-05 - root_mean_squared_error: 0.0100 - coefficient_of_determination: 0.9979 - val_loss: 0.0519 - val_mean_absolute_error: 0.0519 - val_mean_squared_error: 0.0028 - val_root_mean_squared_error: 0.0528 - val_coefficient_of_determination: -8.1350
# Epoch 12/16
# 138/138 [==============================] - 36s 258ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - mean_squared_error: 1.1688e-04 - root_mean_squared_error: 0.0108 - coefficient_of_determination: 0.9976 - val_loss: 0.0170 - val_mean_absolute_error: 0.0170 - val_mean_squared_error: 3.5366e-04 - val_root_mean_squared_error: 0.0188 - val_coefficient_of_determination: -0.0951
# Epoch 13/16
# 138/138 [==============================] - 36s 261ms/step - loss: 0.0068 - mean_absolute_error: 0.0068 - mean_squared_error: 1.0052e-04 - root_mean_squared_error: 0.0100 - coefficient_of_determination: 0.9979 - val_loss: 0.0188 - val_mean_absolute_error: 0.0188 - val_mean_squared_error: 3.9225e-04 - val_root_mean_squared_error: 0.0198 - val_coefficient_of_determination: -0.2022
# Epoch 14/16
# 138/138 [==============================] - 36s 259ms/step - loss: 0.0062 - mean_absolute_error: 0.0062 - mean_squared_error: 8.3655e-05 - root_mean_squared_error: 0.0091 - coefficient_of_determination: 0.9982 - val_loss: 0.0052 - val_mean_absolute_error: 0.0052 - val_mean_squared_error: 5.1575e-05 - val_root_mean_squared_error: 0.0072 - val_coefficient_of_determination: 0.8823
# Epoch 15/16
# 138/138 [==============================] - 36s 262ms/step - loss: 0.0060 - mean_absolute_error: 0.0060 - mean_squared_error: 8.4573e-05 - root_mean_squared_error: 0.0092 - coefficient_of_determination: 0.9982 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 6.3133e-05 - val_root_mean_squared_error: 0.0079 - val_coefficient_of_determination: 0.8704
# Epoch 16/16
# 138/138 [==============================] - 36s 261ms/step - loss: 0.0055 - mean_absolute_error: 0.0055 - mean_squared_error: 6.5675e-05 - root_mean_squared_error: 0.0081 - coefficient_of_determination: 0.9987 - val_loss: 0.0149 - val_mean_absolute_error: 0.0149 - val_mean_squared_error: 2.7565e-04 - val_root_mean_squared_error: 0.0166 - val_coefficient_of_determination: 0.1096
# Epoch 1/12
# 138/138 [==============================] - 35s 254ms/step - loss: 0.0015 - mean_absolute_error: 0.0015 - mean_squared_error: 6.4994e-06 - root_mean_squared_error: 0.0025 - coefficient_of_determination: 0.9999 - val_loss: 0.0059 - val_mean_absolute_error: 0.0059 - val_mean_squared_error: 5.7660e-05 - val_root_mean_squared_error: 0.0076 - val_coefficient_of_determination: 0.8557
# Epoch 2/12
# 138/138 [==============================] - 33s 242ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - mean_squared_error: 5.8183e-06 - root_mean_squared_error: 0.0024 - coefficient_of_determination: 0.9999 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045 - val_mean_squared_error: 3.9418e-05 - val_root_mean_squared_error: 0.0063 - val_coefficient_of_determination: 0.9117
# Epoch 3/12
# 138/138 [==============================] - 36s 259ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 5.1395e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0078 - val_mean_absolute_error: 0.0078 - val_mean_squared_error: 8.5555e-05 - val_root_mean_squared_error: 0.0092 - val_coefficient_of_determination: 0.7619
# Epoch 4/12
# 138/138 [==============================] - 37s 268ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 5.0979e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046 - val_mean_squared_error: 3.9568e-05 - val_root_mean_squared_error: 0.0063 - val_coefficient_of_determination: 0.9024
# Epoch 5/12
# 138/138 [==============================] - 37s 265ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - mean_squared_error: 5.3096e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050 - val_mean_squared_error: 4.2443e-05 - val_root_mean_squared_error: 0.0065 - val_coefficient_of_determination: 0.8967
# Epoch 6/12
# 138/138 [==============================] - 39s 279ms/step - loss: 0.0012 - mean_absolute_error: 0.0012 - mean_squared_error: 4.6803e-06 - root_mean_squared_error: 0.0022 - coefficient_of_determination: 0.9999 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048 - val_mean_squared_error: 3.9854e-05 - val_root_mean_squared_error: 0.0063 - val_coefficient_of_determination: 0.9036
# Epoch 7/12
# 138/138 [==============================] - 36s 257ms/step - loss: 0.0014 - mean_absolute_error: 0.0014 - mean_squared_error: 5.4456e-06 - root_mean_squared_error: 0.0023 - coefficient_of_determination: 0.9999 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 3.4510e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9200
# Epoch 8/12
# 138/138 [==============================] - 34s 244ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 4.6730e-06 - root_mean_squared_error: 0.0022 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 3.4198e-05 - val_root_mean_squared_error: 0.0058 - val_coefficient_of_determination: 0.9188
# Epoch 9/12
# 138/138 [==============================] - 37s 270ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 4.6807e-06 - root_mean_squared_error: 0.0022 - coefficient_of_determination: 0.9999 - val_loss: 0.0069 - val_mean_absolute_error: 0.0069 - val_mean_squared_error: 6.7342e-05 - val_root_mean_squared_error: 0.0082 - val_coefficient_of_determination: 0.8158
# Epoch 10/12
# 138/138 [==============================] - 37s 271ms/step - loss: 0.0011 - mean_absolute_error: 0.0011 - mean_squared_error: 3.9955e-06 - root_mean_squared_error: 0.0020 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 3.4113e-05 - val_root_mean_squared_error: 0.0058 - val_coefficient_of_determination: 0.9183
# Epoch 11/12
# 138/138 [==============================] - 36s 263ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 4.9301e-06 - root_mean_squared_error: 0.0022 - coefficient_of_determination: 0.9999 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045 - val_mean_squared_error: 3.5263e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9167
# Epoch 12/12
# 138/138 [==============================] - 37s 265ms/step - loss: 0.0013 - mean_absolute_error: 0.0013 - mean_squared_error: 4.5389e-06 - root_mean_squared_error: 0.0021 - coefficient_of_determination: 0.9999 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050 - val_mean_squared_error: 4.0477e-05 - val_root_mean_squared_error: 0.0064 - val_coefficient_of_determination: 0.8986
# Epoch 1/8
# 138/138 [==============================] - 36s 263ms/step - loss: 9.0710e-04 - mean_absolute_error: 9.0710e-04 - mean_squared_error: 3.1058e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047 - val_mean_squared_error: 3.7260e-05 - val_root_mean_squared_error: 0.0061 - val_coefficient_of_determination: 0.9083
# Epoch 2/8
# 138/138 [==============================] - 36s 260ms/step - loss: 8.9480e-04 - mean_absolute_error: 8.9480e-04 - mean_squared_error: 3.0426e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047 - val_mean_squared_error: 3.6503e-05 - val_root_mean_squared_error: 0.0060 - val_coefficient_of_determination: 0.9108
# Epoch 3/8
# 138/138 [==============================] - 35s 255ms/step - loss: 8.8506e-04 - mean_absolute_error: 8.8506e-04 - mean_squared_error: 3.0653e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045 - val_mean_squared_error: 3.4921e-05 - val_root_mean_squared_error: 0.0059 - val_coefficient_of_determination: 0.9152
# Epoch 4/8
# 138/138 [==============================] - 36s 264ms/step - loss: 8.7577e-04 - mean_absolute_error: 8.7577e-04 - mean_squared_error: 2.9773e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 4.6686e-05 - val_root_mean_squared_error: 0.0068 - val_coefficient_of_determination: 0.8798
# Epoch 5/8
# 138/138 [==============================] - 36s 263ms/step - loss: 8.8844e-04 - mean_absolute_error: 8.8844e-04 - mean_squared_error: 3.0696e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051 - val_mean_squared_error: 4.1155e-05 - val_root_mean_squared_error: 0.0064 - val_coefficient_of_determination: 0.8969
# Epoch 6/8
# 138/138 [==============================] - 35s 252ms/step - loss: 8.9530e-04 - mean_absolute_error: 8.9530e-04 - mean_squared_error: 3.0842e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 3.0075e-05 - val_root_mean_squared_error: 0.0055 - val_coefficient_of_determination: 0.9281
# Epoch 7/8
# 138/138 [==============================] - 35s 254ms/step - loss: 8.9613e-04 - mean_absolute_error: 8.9613e-04 - mean_squared_error: 3.0803e-06 - root_mean_squared_error: 0.0018 - coefficient_of_determination: 0.9999 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 3.3210e-05 - val_root_mean_squared_error: 0.0058 - val_coefficient_of_determination: 0.9199
# Epoch 8/8
# 138/138 [==============================] - 36s 259ms/step - loss: 8.7116e-04 - mean_absolute_error: 8.7116e-04 - mean_squared_error: 2.9712e-06 - root_mean_squared_error: 0.0017 - coefficient_of_determination: 0.9999 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048 - val_mean_squared_error: 3.7873e-05 - val_root_mean_squared_error: 0.0062 - val_coefficient_of_determination: 0.9061

# %% [markdown]
# ### Predict on Test Data

# %%
y_hat = model.predict(X_test)
# Out:
# 2022-08-18 15:15:34.086318: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 2400 num_cores: 16 environment { key: "cpu_instruction_set" value: "SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 16777216 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 4/4 [==============================] - 1s 79ms/step

# %% [markdown]
# ### Unscale Data

# %%
# Undo normalisation
y_test = (y_test * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
y_hat = (y_hat * anotherScaler.data_range_[0]) + anotherScaler.data_min_[0]
# Undo standardisation
y_test = (y_test * scaler.scale_[0]) + scaler.mean_[0]
y_hat = (y_hat * scaler.scale_[0]) + scaler.mean_[0]

# %% [markdown]
# ### Plot Prediction

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_hat, color='red', label="Predicted DJIA Open Price ($)")
plt.plot(y_test, color='blue', label="Actual DJIA Open Price ($)")
plt.title('DJIA Open Price Prediction')
# plt.xticks(np.arange(dates.shape[0]), dates)
xLabel = "Days since " + splitDate
plt.xlabel(xLabel)
plt.ylabel('DJIA Open Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
totalLoss = np.concatenate([historyOne.history['loss'], historyTwo.history['loss'], historyThree.history['loss']])
totaValLoss = np.concatenate([historyOne.history['val_loss'], historyTwo.history['val_loss'], historyThree.history['val_loss']])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(totalLoss, color='red')
plt.axvspan(0, numEpochsOne, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(numEpochsOne, numEpochsOne+numEpochsTwo, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(numEpochsOne+numEpochsTwo, numEpochsOne+numEpochsTwo+numEpochsThree, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, numEpochsOne+numEpochsTwo+numEpochsThree-1)
plt.xticks([2*i for i in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)], [(2*j)+1 for j in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(totaValLoss, color='red')
plt.axvspan(0, numEpochsOne, facecolor='black', alpha=0.6, label="LR = 0.01")
plt.axvspan(numEpochsOne, numEpochsOne+numEpochsTwo, facecolor='black', alpha=0.4, label="LR = 0.001")
plt.axvspan(numEpochsOne+numEpochsTwo, numEpochsOne+numEpochsTwo+numEpochsThree, facecolor='black', alpha=0.2, label="LR = 0.0001")
plt.xlim(0, numEpochsOne+numEpochsTwo+numEpochsThree-1)
plt.xticks([2*i for i in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)], [(2*j)+1 for j in range((numEpochsOne+numEpochsTwo+numEpochsThree)//2)])
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Validation Loss")
plt.legend()

plt.show()

# %%
mae = historyThree.history['mean_absolute_error']
mse = historyThree.history['mean_squared_error']
rmse = historyThree.history['root_mean_squared_error']
r2 = historyThree.history['coefficient_of_determination']

print('Mean Absolute Error (MAE): ' + str(mae[-1]))
print('Mean Squared Error (MSE): ' + str(mse[-1]))
print('Root Mean Squared Error (RMSE): ' + str(rmse[-1]))
print('Coefficient of Determination (R2): ' + str(r2[-1]))
# Out:
# Mean Absolute Error (MAE): 0.0008711569826118648
# Mean Squared Error (MSE): 2.9711643492191797e-06
# Root Mean Squared Error (RMSE): 0.0017237066058441997
# Coefficient of Determination (R2): 0.9999433755874634

# %%
valmae = historyThree.history['val_mean_absolute_error']
valmse = historyThree.history['val_mean_squared_error']
valrmse = historyThree.history['val_root_mean_squared_error']
valr2 = historyThree.history['val_coefficient_of_determination']

print('Validation Mean Absolute Error (MAE): ' + str(valmae[-1]))
print('Validation Mean Squared Error (MSE): ' + str(valmse[-1]))
print('Validation Root Mean Squared Error (RMSE): ' + str(valrmse[-1]))
print('Validation Coefficient of Determination (R2): ' + str(valr2[-1]))
# Out:
# Validation Mean Absolute Error (MAE): 0.00481722317636013
# Validation Mean Squared Error (MSE): 3.787330933846533e-05
# Validation Root Mean Squared Error (RMSE): 0.006154129281640053
# Validation Coefficient of Determination (R2): 0.9061235189437866

# %% [markdown]
# ### Trading Strategy

# %%
initialBalance = 1000000
actionThreshold = 0.01
sentimentInfluence = 0.005
betProportion = 1

# Random strategy
controlBalance = initialBalance
controlOwnedShares = 0
controlBet = controlBalance / betProportion
controlBuyOrders = 0
controlSellOrders = 0

# Trading the price predictions
balance = initialBalance
ownedShares = 0
bet = balance / betProportion
buyOrders = 0
sellOrders = 0

def Buy(price, bet, balance, ownedShares):
    if (balance > 0):
            numShares = 0
            if (balance >= bet):
                numShares = bet / price
                balance -= bet
                ownedShares += numShares
            else:
                numShares = balance / price
                balance = 0
                ownedShares += numShares
            # print("BUY - " + str(numShares) + " shares at $" + str(price))
            bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

def Sell(price, bet, balance, ownedShares):
    if (ownedShares > 0):
        numShares = bet / price
        if (ownedShares >= numShares):
            balance += bet
            ownedShares -= numShares
            # print("SELL - " + str(numShares) + " shares at $" + str(price))
        else:
            value = ownedShares * price
            balance += value
            ownedShares = 0
            # print("SELL - " + str(ownedShares) + " shares at $" + str(price))
        bet = (balance + (ownedShares * price)) / betProportion
    return bet, balance, ownedShares

# Random trading strategy
for i in range(len(y_hat)-1):
    if (randint(0, 1) == 0): # ! Buy
        controlBet, controlBalance, controlOwnedShares = Buy(y_test[i], controlBet, controlBalance, controlOwnedShares)
    else: # ! Sell
        controlBet, controlBalance, controlOwnedShares = Sell(y_test[i], controlBet, controlBalance, controlOwnedShares)

# Trading strategy based on price prediction
for i in range(len(y_hat)-1):
    
    currentPrice = y_test[i]
    predictedPrice = y_hat[i+1]
    difference = predictedPrice - currentPrice
    percentageChange = difference / currentPrice

    # No sentiment
    if (abs(percentageChange) < actionThreshold): # ! Hold
        pass
    elif (currentPrice < predictedPrice): # ! Buy
        bet, balance, ownedShares = Buy(y_test[i], bet, balance, ownedShares)
    elif (currentPrice > predictedPrice): # ! Sell
        bet, balance, ownedShares = Sell(y_test[i], bet, balance, ownedShares)

controlTotalShareValue = controlOwnedShares * y_test[-1]
controlFinalBalance = controlBalance + controlTotalShareValue
controlProfit = controlFinalBalance-initialBalance
controlBalancePercentageChange = ((controlFinalBalance-initialBalance)/initialBalance) * 100

totalShareValue = ownedShares * y_test[-1]
finalBalance = balance + totalShareValue
profit = finalBalance-initialBalance
balancePercentageChange = ((finalBalance-initialBalance)/initialBalance) * 100

pricePercentageChange = ((y_test[-1]-y_test[0])/y_test[0]) * 100

print("----------------------------------------------------------------")

print("Trading over " + str(y_hat.shape[0]) + " days")
print("Initial Balance: $" + str(initialBalance))

print("----------------------------------------------------------------")

print("Random Trading Strategy")
# print("Final Balance: $" + str(controlFinalBalance))
print("Profit: $" + str(controlProfit))
print("Balance Percentage Change: " + str(controlBalancePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Buying on day one and holding")
print("Profit: $" + str(initialBalance * (pricePercentageChange/100)))
print("Balance Percentage Change: " + str(pricePercentageChange) + "%")

print("----------------------------------------------------------------")

print("Trading strategy based on price predictions")
# print("Final Balance: $" + str(finalBalance))
print("Profit: $" + str(profit))
print("Balance Percentage Change: " + str(balancePercentageChange) + "%")

print("----------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------
# Trading over 125 days
# Initial Balance: $1000000
# ----------------------------------------------------------------
# Random Trading Strategy
# Profit: $134938.68039354845
# Balance Percentage Change: 13.493868039354846%
# ----------------------------------------------------------------
# Buying on day one and holding
# Profit: $162509.80005976406
# Balance Percentage Change: 16.250980005976405%
# ----------------------------------------------------------------
# Trading strategy based on price predictions
# Profit: $203510.25991751906
# Balance Percentage Change: 20.351025991751907%
# ----------------------------------------------------------------
